# %% [markdown]
# # Sentiment Analysis using twitter data
#
# Simple Deep Neural Network, that predicts tweet sentiment. The model can be greatly improved using various <br/>
# word vectorization techniques and Recurrent Neural Networks.

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
from sklearn.model_selection import train_test_split
import tflearn as tflearn
from nltk.corpus import stopwords
import preprocessor as p
import re
import numpy as np
from sklearn import preprocessing
import tensorflow as tf

# %%
test_path = "./data/twitter_test.txt"
training_path = "./data/twitter_data.txt"

def all_stop_words():
    stop_words = stopwords.words('english')
    add_stopwords = [",", "*" , ")" , "(" ,".","theres","know","one","though","vinci","ive","da","book","im","went",
                    "potter","brokeback","mountain","harry","code","mission","impossible","movie","movies","i","ya",
                    "yet","yall"]
    for w in add_stopwords:
        stop_words.append(w)
    return stop_words


stop_words = all_stop_words()
def training_data_df(path):
    
    training_data = open(path,mode='r')
    training_array =[]
    for d in training_data:
        training_dict = {}
        sent_tweet_array = d.split('\t')
        training_dict['tweet'] = sent_tweet_array[1].lower()
        training_dict['cleaned_tweet'] =remove_stop_words(sent_tweet_array[1].lower())
        training_dict['positive'] =int(sent_tweet_array[0])
        training_array.append(training_dict)
    training_df = pd.DataFrame(training_array)
    return training_df

def sentiment(sentiment_prob):
    if sentiment_prob[0]>sentiment_prob[1]:
        return "positive"
    return "negative"

def remove_stop_words(tweet_text):
    tweet_text = re.sub(r'[?|$|.|!]',r'',tweet_text)
    tweet_text = re.sub(r'[^a-zA-Z0-9 ]',r'',tweet_text)
    result = ""
    for word in tweet_text.split():            
        result = result +" "+word.lower()

    return result.lstrip()

def get_word_frequency(tweet_list):
    word_dict = {} 
    result_array=[]
    for tw in tweet_list:
        for word in tw.split():
            if word in word_dict.keys():
                word_dict[word] = word_dict[word]+1
                continue
            word_dict[word] = 1
    for k in word_dict.keys():
        result_array.append({'word':k, 'count':word_dict[k]})
    return pd.DataFrame(result_array,columns=['count','word'])


def common_pos_words(df_data):
    return common_words_filter(df_data,1)

def common_neg_words(df_data):
    return common_words_filter(df_data,0)

def common_words_filter(df_data,sent):
    pos_tweet =df_data[df_data["positive"] ==sent]
    all_tweets = pos_tweet["tweet"].str.cat(sep='|')
    common_words=[]
    for pos_tw in pos_tweet["tweet"]:
        for tw in all_tweets.split('|'):
            if pos_tw == tw:
                continue
            tw_list = list(tw.split())
            pos_list = list(pos_tw.split())
            inter = list(set(tw_list).intersection(pos_list))
            for word in inter:
                if word not in common_words:
                    common_words.append(word)
    return common_words

# %%
training_data = training_data_df(training_path)
# test_data = training_data_df(test_path)
training_data["neg"] = training_data["positive"].apply(lambda x: 0 if x==1 else 1)
vect = CountVectorizer(stop_words=all_stop_words())
print("All data:",training_data.shape[0])
# print("Test data:",test_data.shape[0])
# Out:
# All data: 7087

# %%
training_data.head(10)
# Out:
#                                        cleaned_tweet  positive  \
# 0                           i feeel like aaa reetard         0
# 1             the da vinci code book is just awesome         1
# 2  this was the first clive cussler ive ever read...         1
# 3                    i liked the da vinci code a lot         1
# 4                    i liked the da vinci code a lot         1
# 5  i liked the da vinci code but it ultimatly did...         1
# 6  thats not even an exaggeration and at midnight...         1
# 7  i loved the da vinci code but now i want somet...         1
# 8  i thought da vinci code was great same with ki...         1
# 9         the da vinci code is actually a good movie         1
#
#                                                tweet  neg
# 0                         i feeel like aaa reetard\n    1
# 1          the da vinci code book is just awesome.\n    0
# 2  this was the first clive cussler i've ever rea...    0
# 3                 i liked the da vinci code a lot.\n    0
# 4                 i liked the da vinci code a lot.\n    0
# 5  i liked the da vinci code but it ultimatly did...    0
# 6  that's not even an exaggeration ) and at midni...    0
# 7  i loved the da vinci code, but now i want some...    0
# 8  i thought da vinci code was great, same with k...    0
# 9    the da vinci code is actually a good movie...\n    0

# %%
training_data = training_data[['positive','neg','cleaned_tweet', 'tweet']]
training_data.values
# Out:
# array([[0, 1, 'i feeel like aaa reetard', 'i feeel like aaa reetard\n'],
#        [1, 0, 'the da vinci code book is just awesome',
#         'the da vinci code book is just awesome.\n'],
#        [1, 0,
#         'this was the first clive cussler ive ever read but even books like relic and da vinci code were more plausible than this',
#         "this was the first clive cussler i've ever read, but even books like relic, and da vinci code were more plausible than this.\n"],
#        ...,
#        [0, 1,
#         'as i sit here watching the mtv movie awards i am reminded of how much i despised the movie brokeback mountain',
#         'as i sit here, watching the mtv movie awards, i am reminded of how much i despised the movie brokeback mountain.\n'],
#        [0, 1, 'ok brokeback mountain is such a horrible movie',
#         'ok brokeback mountain is such a horrible movie.\n'],
#        [0, 1, 'oh and brokeback mountain was a terrible movie',
#         'oh, and brokeback mountain was a terrible movie.\n']], dtype=object)

# %% [markdown]
# ### One-hot Encode

# %%
vect.fit(training_data["cleaned_tweet"])
word_matrix = vect.transform(training_data["cleaned_tweet"]).toarray()
print(word_matrix.shape)
# Out:
# (7087, 2206)

# %%
num_features = word_matrix.shape[1]
print("Total features: ",num_features)
classes = training_data.values[:,:2]
# Out:
# Total features:  2206

# %%
trX,testX,trY,testY = train_test_split(word_matrix,classes)   
print("Training data:",trX.shape[0])
print("Test data:",testX.shape[0])
# Out:
# Training data: 5315
# Test data: 1772

# %%
print(vect.inverse_transform(testX))
# Out:
# [array(['and', 'code', 'da', 'for', 'google', 'music', 'my', 'sucked',
#        'the', 'urls', 'use', 'vinci'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['and', 'awesome', 'both', 'impossible', 'last', 'mission', 'movies',
#        'stand', 'the', 'were'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'harry', 'hates', 'knows', 'not',
#        'potter', 'want', 'what'],
#       dtype='<U62'), array(['25', 'code', 'da', 'heard', 'much', 'only', 'soo', 'stars',
#        'sucked', 'vinci'],
#       dtype='<U62'), array(['am', 'as', 'awards', 'brokeback', 'despised', 'here', 'how',
#        'mountain', 'movie', 'mtv', 'much', 'of', 'reminded', 'sit', 'the',
#        'watching'],
#       dtype='<U62'), array(['daniel', 'fucking', 'harry', 'hate', 'needs', 'potter', 'slap',
#        'that', 'wotshisface'],
#       dtype='<U62'), array(['an', 'awesome', 'code', 'da', 'movie', 'vinci', 'was'],
#       dtype='<U62'), array(['fandom', 'for', 'gift', 'harry', 'het', 'id', 'in', 'is', 'love',
#        'nc17', 'potter', 'requested', 'sivullinen', 'some', 'this', 'who'],
#       dtype='<U62'), array(['and', 'bye', 'harry', 'ok', 'potter', 'quiz', 'sucks', 'this'],
#       dtype='<U62'), array(['brokeback', 'depressing', 'mountain', 'really', 'so', 'was'],
#       dtype='<U62'), array(['am', 'because', 'but', 'character', 'dies', 'harry', 'hate', 'it',
#        'likes', 'main', 'not', 'of', 'person', 'potter', 'that', 'the',
#        'type', 'when'],
#       dtype='<U62'), array(['brokeback', 'fucking', 'horrible', 'is', 'mountain'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['and', 'brokeback', 'is', 'mountain', 'movie', 'oh', 'terrible'],
#       dtype='<U62'), array(['an', 'awesome', 'code', 'da', 'movie', 'vinci', 'was'],
#       dtype='<U62'), array(['absolutely', 'awesome', 'code', 'da', 'the', 'vinci', 'was'],
#       dtype='<U62'), array(['and', 'code', 'da', 'friday', 'hung', 'kelsie', 'out', 'saw',
#        'sucked', 'the', 'vinci', 'we', 'went', 'with'],
#       dtype='<U62'), array(['impossible', 'mission', 'rocks'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['brokeback', 'depressing', 'is', 'mountain', 'so'],
#       dtype='<U62'), array(['harry', 'like', 'lot', 'potter', 'too'],
#       dtype='<U62'), array(['because', 'impossible', 'know', 'like', 'mission', 'movies',
#        'never', 'on', 'right', 'side', 'the', 'whos', 'you'],
#       dtype='<U62'), array(['excellent', 'impossible', 'mission', 'was'],
#       dtype='<U62'), array(['absolutely', 'awesome', 'code', 'da', 'the', 'vinci', 'was'],
#       dtype='<U62'), array(['code', 'da', 'love', 'lubb', 'luv', 'the', 'vinci'],
#       dtype='<U62'), array(['also', 'as', 'book', 'can', 'catcher', 'count', 'eyre', 'harry',
#        'if', 'in', 'jane', 'love', 'potter', 'series', 'suicides', 'that',
#        'the', 'tye', 'virgin', 'yeah', 'you'],
#       dtype='<U62'), array(['beans', 'harry', 'hate', 'jelly', 'potter'],
#       dtype='<U62'), array(['and', 'brokeback', 'is', 'mountain', 'movie', 'oh', 'terrible'],
#       dtype='<U62'), array(['harry', 'hookup', 'miss', 'potter', 'the'],
#       dtype='<U62'), array(['and', 'as', 'cleaning', 'dash', 'felicia', 'felicias', 'freakin',
#        'grabs', 'impossible', 'is', 'keys', 'like', 'mission', 'mom', 'my',
#        'out', 'so', 'table', 'the', 'we'],
#       dtype='<U62'), array(['brokeback', 'depressing', 'ever', 'have', 'into', 'is', 'most',
#        'mountain', 'movie', 'seen', 'snuck', 'the', 'then', 'which'],
#       dtype='<U62'), array(['brokeback', 'loved', 'man', 'mountain'],
#       dtype='<U62'), array(['33', 'an', 'awesome', 'brokeback', 'mountain', 'movie', 'was'],
#       dtype='<U62'), array(['and', 'brokeback', 'is', 'mountain', 'movie', 'oh', 'terrible'],
#       dtype='<U62'), array(['and', 'brokeback', 'is', 'mountain', 'movie', 'oh', 'terrible'],
#       dtype='<U62'), array(['first', 'impossible', 'liked', 'mission', 'the'],
#       dtype='<U62'), array(['absolutely', 'brokeback', 'hated', 'mountain'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['am', 'because', 'but', 'character', 'dies', 'harry', 'hate', 'it',
#        'likes', 'main', 'not', 'of', 'person', 'potter', 'that', 'the',
#        'type', 'when'],
#       dtype='<U62'), array(['harry', 'like', 'potter', 'too'],
#       dtype='<U62'), array(['code', 'da', 'loved', 'the', 'vinci'],
#       dtype='<U62'), array(['harry', 'movies', 'potter', 'really', 'suck', 'these'],
#       dtype='<U62'), array(['brokeback', 'dudeee', 'loved', 'mountain'],
#       dtype='<U62'), array(['and', 'are', 'because', 'begin', 'better', 'harry', 'hate', 'it',
#        'just', 'material', 'movies', 'much', 'out', 'outshines', 'plain',
#        'potter', 'reading', 'stupid', 'the', 'there', 'think', 'to', 'with'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'harry', 'if',
#        'is', 'potter', 'says'],
#       dtype='<U62'), array(['impossible', 'like', 'mission'],
#       dtype='<U62'), array(['and', 'as', 'cleaning', 'dash', 'felicia', 'felicias', 'freakin',
#        'grabs', 'impossible', 'is', 'keys', 'like', 'mission', 'mom', 'my',
#        'out', 'so', 'table', 'the', 'we'],
#       dtype='<U62'), array(['absolutely', 'awesome', 'code', 'da', 'the', 'vinci', 'was'],
#       dtype='<U62'), array(['25', 'code', 'da', 'heard', 'much', 'only', 'soo', 'stars',
#        'sucked', 'vinci'],
#       dtype='<U62'), array(['and', 'awesome', 'both', 'impossible', 'last', 'mission', 'movies',
#        'stand', 'the', 'were'],
#       dtype='<U62'), array(['and', 'brokeback', 'mountain', 'movie', 'oh', 'terrible', 'was'],
#       dtype='<U62'), array(['by', 'code', 'da', 'just', 'know', 'letting', 'sucked', 'the',
#        'vinci', 'way', 'you'],
#       dtype='<U62'), array(['be', 'code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['first', 'impossible', 'liked', 'mission', 'the'],
#       dtype='<U62'), array(['and', 'be', 'because', 'community', 'friends', 'good', 'harry',
#        'joining', 'like', 'make', 'potter', 'really', 'same', 'so',
#        'start', 'that', 'the', 'things', 'this', 'thought', 'to', 'who',
#        'would'],
#       dtype='<U62'), array(['and', 'as', 'escapades', 'impossible', 'kate', 'kirsten', 'leah',
#        'love', 'mission', 'tom', 'well'],
#       dtype='<U62'), array(['an', 'awesome', 'brokeback', 'mountain', 'movie', 'was'],
#       dtype='<U62'), array(['impossible', 'mission', 'rocks'],
#       dtype='<U62'), array(['about', 'being', 'brokeback', 'dads', 'mountain', 'my', 'stupid'],
#       dtype='<U62'), array(['brokeback', 'depressing', 'extremely', 'mountain', 'was'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'harry', 'if',
#        'is', 'potter', 'says'],
#       dtype='<U62'), array(['evil', 'harry', 'is', 'my', 'point', 'potter'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['harry', 'movies', 'potter', 'really', 'suck', 'these'],
#       dtype='<U62'), array(['an', 'awesome', 'code', 'da', 'movie', 'vinci', 'was'],
#       dtype='<U62'), array(['impossible', 'mission', 'rocks'],
#       dtype='<U62'), array(['harry', 'hate', 'potter'],
#       dtype='<U62'), array(['harry', 'movies', 'potter', 'really', 'suck', 'these'],
#       dtype='<U62'), array(['and', 'brokeback', 'is', 'mountain', 'movie', 'oh', 'terrible'],
#       dtype='<U62'), array(['awesome', 'brokeback', 'mountain', 'so', 'was'],
#       dtype='<U62'), array(['harry', 'like', 'potter', 'too'],
#       dtype='<U62'), array(['and', 'as', 'cleaning', 'dash', 'felicia', 'felicias', 'freakin',
#        'grabs', 'impossible', 'is', 'keys', 'like', 'mission', 'mom', 'my',
#        'out', 'so', 'table', 'the', 'we'],
#       dtype='<U62'), array(['beautiful', 'brokeback', 'mountain', 'was'],
#       dtype='<U62'), array(['bitch', 'coz', 'down', 'goin', 'hella', 'hill', 'impossible',
#        'into', 'is', 'like', 'mission', 'reality', 'said', 'silent',
#        'that', 'turned', 'was', 'which', 'why'],
#       dtype='<U62'), array(['daniel', 'fucking', 'harry', 'hate', 'needs', 'potter', 'slap',
#        'that', 'wotshisface'],
#       dtype='<U62'), array(['and', 'be', 'because', 'but', 'fun', 'harry', 'here', 'is', 'it',
#        'love', 'much', 'people', 'place', 'potter', 'really', 'serious',
#        'so', 'still', 'take', 'to', 'want', 'where'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'the', 'vinci'],
#       dtype='<U62'), array(['brokeback', 'dudeee', 'loved', 'mountain'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'brokeback', 'either', 'great',
#        'homosexuality', 'is', 'its', 'love', 'more', 'mountain', 'or',
#        'that', 'think'],
#       dtype='<U62'), array(['good', 'if', 'impossible', 'like', 'mission', 'movie', 'of',
#        'sort', 'spy', 'that', 'thing', 'unpredictable', 'was', 'you'],
#       dtype='<U62'), array(['harry', 'like', 'potter', 'too'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'brokeback', 'either', 'great',
#        'homosexuality', 'is', 'its', 'love', 'more', 'mountain', 'or',
#        'that', 'think'],
#       dtype='<U62'), array(['and', 'be', 'because', 'but', 'fun', 'harry', 'here', 'is', 'it',
#        'love', 'much', 'people', 'place', 'potter', 'really', 'serious',
#        'so', 'still', 'take', 'to', 'want', 'where'],
#       dtype='<U62'), array(['code', 'da', 'love', 'lubb', 'luv', 'the', 'vinci'],
#       dtype='<U62'), array(['are', 'code', 'da', 'how', 'it', 'know', 'love', 'much', 'people',
#        'the', 'vinci', 'who', 'worth'],
#       dtype='<U62'), array(['absolutely', 'awesome', 'code', 'da', 'the', 'vinci', 'was'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['as', 'code', 'da', 'desperately', 'film', 'lovethe', 'to', 'vinci',
#        'wanted'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['code', 'da', 'love', 'the', 'vinci'],
#       dtype='<U62'), array(['and', 'code', 'combining', 'da', 'from', 'gary', 'gin', 'opinion',
#        'review', 'sucks', 'the', 'vinci', 'zen'],
#       dtype='<U62'), array(['bitch', 'coz', 'down', 'goin', 'hella', 'hill', 'impossible',
#        'into', 'is', 'like', 'mission', 'reality', 'said', 'silent',
#        'that', 'turned', 'was', 'which', 'why'],
#       dtype='<U62'), array(['and', 'are', 'because', 'begin', 'better', 'harry', 'hate', 'it',
#        'just', 'material', 'movies', 'much', 'out', 'outshines', 'plain',
#        'potter', 'reading', 'stupid', 'the', 'there', 'think', 'to', 'with'],
#       dtype='<U62'), array(['and', 'black', 'gay', 'guy', 'harry', 'hate', 'its', 'one', 'only',
#        'potter', 'retarted', 'stupid', 'theres'],
#       dtype='<U62'), array(['all', 'at', 'better', 'camp', 'cool', 'experience', 'hide',
#        'impossible', 'is', 'it', 'land', 'mission', 'places', 'pretty',
#        'setting', 'ten', 'the', 'though', 'times', 'to', 'want', 'was',
#        'which', 'with', 'you'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['awesomest', 'books', 'code', 'da', 'ever', 'is', 'ive', 'most',
#        'of', 'one', 'read', 'still', 'the', 'vinci'],
#       dtype='<U62'), array(['and', 'awesome', 'both', 'impossible', 'last', 'mission', 'movies',
#        'stand', 'the', 'were'],
#       dtype='<U62'), array(['brokeback', 'fucking', 'horrible', 'is', 'mountain'],
#       dtype='<U62'), array(['also', 'as', 'book', 'can', 'catcher', 'count', 'eyre', 'harry',
#        'if', 'in', 'jane', 'love', 'potter', 'series', 'suicides', 'that',
#        'the', 'tye', 'virgin', 'yeah', 'you'],
#       dtype='<U62'), array(['and', 'bye', 'harry', 'ok', 'potter', 'quiz', 'sucks', 'this'],
#       dtype='<U62'), array(['actual', 'an', 'and', 'dance', 'evil', 'for', 'halloween', 'harry',
#        'jack', 'just', 'lol', 'need', 'night', 'now', 'of', 'potter',
#        'ripper', 'the'],
#       dtype='<U62'), array(['am', 'because', 'but', 'character', 'dies', 'harry', 'hate', 'it',
#        'likes', 'main', 'not', 'of', 'person', 'potter', 'that', 'the',
#        'type', 'when'],
#       dtype='<U62'), array(['acne', 'and', 'brokeback', 'got', 'hes', 'likeyeah', 'love',
#        'mountain'],
#       dtype='<U62'), array(['and', 'as', 'escapades', 'impossible', 'kate', 'kirsten', 'leah',
#        'love', 'mission', 'tom', 'well'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['an', 'awesome', 'code', 'da', 'movie', 'vinci', 'was'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['beautiful', 'brokeback', 'mountain', 'was'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['be', 'code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['did', 'dont', 'fact', 'harry', 'if', 'know', 'like', 'more',
#        'online', 'or', 'potter', 'quizzes', 'sucks', 'that', 'the', 'you'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['be', 'code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['and', 'as', 'cleaning', 'dash', 'felicia', 'felicias', 'freakin',
#        'grabs', 'impossible', 'is', 'keys', 'like', 'mission', 'mom', 'my',
#        'out', 'so', 'table', 'the', 'we'],
#       dtype='<U62'), array(['am', 'because', 'but', 'character', 'dies', 'harry', 'hate', 'it',
#        'likes', 'main', 'not', 'of', 'person', 'potter', 'that', 'the',
#        'type', 'when'],
#       dtype='<U62'), array(['about', 'being', 'brokeback', 'dads', 'mountain', 'my', 'stupid'],
#       dtype='<U62'), array(['and', 'code', 'combining', 'da', 'from', 'gary', 'gin', 'opinion',
#        'review', 'sucks', 'the', 'vinci', 'zen'],
#       dtype='<U62'), array(['awesome', 'impossible', 'mission', 'was'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['boring', 'brokeback', 'mountain', 'was'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'harry', 'hates', 'knows', 'not',
#        'potter', 'want', 'what'],
#       dtype='<U62'), array(['are', 'code', 'da', 'how', 'it', 'know', 'love', 'much', 'people',
#        'the', 'vinci', 'who', 'worth'],
#       dtype='<U62'), array(['brokeback', 'fucking', 'horrible', 'is', 'mountain'],
#       dtype='<U62'), array(['awesome', 'brokeback', 'mountain', 'so', 'was'],
#       dtype='<U62'), array(['harry', 'like', 'potter', 'too'],
#       dtype='<U62'), array(['and', 'are', 'because', 'begin', 'better', 'harry', 'hate', 'it',
#        'just', 'material', 'movies', 'much', 'out', 'outshines', 'plain',
#        'potter', 'reading', 'stupid', 'the', 'there', 'think', 'to', 'with'],
#       dtype='<U62'), array(['and', 'being', 'bonkers', 'for', 'impossible', 'love', 'mission',
#        'sentry', 'station'],
#       dtype='<U62'), array(['and', 'are', 'because', 'begin', 'better', 'harry', 'hate', 'it',
#        'just', 'material', 'movies', 'much', 'out', 'outshines', 'plain',
#        'potter', 'reading', 'stupid', 'the', 'there', 'think', 'to', 'with'],
#       dtype='<U62'), array(['as', 'code', 'da', 'desperately', 'film', 'lovethe', 'to', 'vinci',
#        'wanted'],
#       dtype='<U62'), array(['about', 'brokeback', 'life', 'mountain', 'real', 'shows',
#        'stories', 'stupid', 'talk', 'talking'],
#       dtype='<U62'), array(['and', 'at', 'bobbypin', 'brokeback', 'cool', 'cowboy', 'hat',
#        'head', 'helped', 'insanely', 'jokes', 'laughed', 'me', 'mountain',
#        'my', 'she', 'stupid', 'to'],
#       dtype='<U62'), array(['code', 'da', 'sucked', 'vinci'],
#       dtype='<U62'), array(['and', 'as', 'cleaning', 'dash', 'felicia', 'felicias', 'freakin',
#        'grabs', 'impossible', 'is', 'keys', 'like', 'mission', 'mom', 'my',
#        'out', 'so', 'table', 'the', 'we'],
#       dtype='<U62'), array(['does', 'harry', 'is', 'it', 'just', 'me', 'or', 'potter', 'suck'],
#       dtype='<U62'), array(['code', 'da', 'down', 'left', 'right', 'suck', 'up', 'vinci'],
#       dtype='<U62'), array(['am', 'and', 'because', 'book', 'claiming', 'down', 'drain', 'evil',
#        'going', 'harry', 'is', 'of', 'people', 'potter', 'reading', 'sick',
#        'someone', 'soooooo', 'that', 'the', 'world'],
#       dtype='<U62'), array(['and', 'brokeback', 'is', 'mountain', 'movie', 'oh', 'terrible'],
#       dtype='<U62'), array(['and', 'as', 'cleaning', 'dash', 'felicia', 'felicias', 'freakin',
#        'grabs', 'impossible', 'is', 'keys', 'like', 'mission', 'mom', 'my',
#        'out', 'so', 'table', 'the', 'we'],
#       dtype='<U62'), array(['brokeback', 'loved', 'man', 'mountain'],
#       dtype='<U62'), array(['also', 'awesome', 'book', 'books', 'brown', 'by', 'code', 'da',
#        'dan', 'got', 'is', 'other', 'really', 'the', 'two', 'vinci', 'you'],
#       dtype='<U62'), array(['and', 'at', 'bobbypin', 'brokeback', 'cool', 'cowboy', 'hat',
#        'head', 'helped', 'insanely', 'jokes', 'laughed', 'me', 'mountain',
#        'my', 'she', 'stupid', 'to'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'harry', 'hates', 'knows', 'not',
#        'potter', 'want', 'what'],
#       dtype='<U62'), array(['canceled', 'day', 'harry', 'or', 'postponed', 'potter', 'rather',
#        'so', 'sucks', 'was', 'which'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'harry', 'hates', 'knows', 'not',
#        'potter', 'want', 'what'],
#       dtype='<U62'), array(['and', 'be', 'because', 'community', 'friends', 'good', 'harry',
#        'joining', 'like', 'make', 'potter', 'really', 'same', 'so',
#        'start', 'that', 'the', 'things', 'this', 'thought', 'to', 'who',
#        'would'],
#       dtype='<U62'), array(['and', 'brokeback', 'mountain', 'movie', 'oh', 'terrible', 'was'],
#       dtype='<U62'), array(['acne', 'and', 'brokeback', 'got', 'hes', 'likeyeah', 'love',
#        'mountain'],
#       dtype='<U62'), array(['again', 'am', 'awesome', 'because', 'going', 'harry', 'is', 'one',
#        'potter', 'reading', 'series', 'start', 'story', 'that', 'the', 'to'],
#       dtype='<U62'), array(['am', 'because', 'but', 'character', 'dies', 'harry', 'hate', 'it',
#        'likes', 'main', 'not', 'of', 'person', 'potter', 'that', 'the',
#        'type', 'when'],
#       dtype='<U62'), array(['and', 'code', 'combining', 'da', 'from', 'gary', 'gin', 'opinion',
#        'review', 'sucks', 'the', 'vinci', 'zen'],
#       dtype='<U62'), array(['all', 'and', 'crystal', 'god', 'harry', 'hate', 'im', 'into', 'my',
#        'not', 'oh', 'potter', 'really', 'scene', 'this', 'was'],
#       dtype='<U62'), array(['and', 'be', 'because', 'but', 'fun', 'harry', 'here', 'is', 'it',
#        'love', 'much', 'people', 'place', 'potter', 'really', 'serious',
#        'so', 'still', 'take', 'to', 'want', 'where'],
#       dtype='<U62'), array(['am', 'because', 'but', 'character', 'dies', 'harry', 'hate', 'it',
#        'likes', 'main', 'not', 'of', 'person', 'potter', 'that', 'the',
#        'type', 'when'],
#       dtype='<U62'), array(['brokeback', 'dudeee', 'loved', 'mountain'],
#       dtype='<U62'), array(['and', 'code', 'combining', 'da', 'from', 'gary', 'gin', 'opinion',
#        'review', 'sucks', 'the', 'vinci', 'zen'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'the', 'vinci'],
#       dtype='<U62'), array(['and', 'brokeback', 'like', 'mountain'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['brokeback', 'fucking', 'horrible', 'is', 'mountain'],
#       dtype='<U62'), array(['and', 'brokeback', 'love', 'mean', 'mountain'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['code', 'da', 'god', 'has', 'hate', 'sense', 'someone', 'thank',
#        'the', 'vinci'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'the', 'vinci'],
#       dtype='<U62'), array(['absolutely', 'awesome', 'code', 'da', 'the', 'vinci', 'was'],
#       dtype='<U62'), array(['daniel', 'fucking', 'harry', 'hate', 'needs', 'potter', 'slap',
#        'that', 'wotshisface'],
#       dtype='<U62'), array(['and', 'beautiful', 'brokeback', 'changes', 'film', 'is',
#        'mountain', 'nothing', 'still', 'that'],
#       dtype='<U62'), array(['brokeback', 'depressing', 'ever', 'have', 'into', 'is', 'most',
#        'mountain', 'movie', 'seen', 'snuck', 'the', 'then', 'which'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['code', 'da', 'love', 'the', 'vinci'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['as', 'code', 'da', 'desperately', 'film', 'lovethe', 'to', 'vinci',
#        'wanted'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'brokeback', 'either', 'great',
#        'homosexuality', 'is', 'its', 'love', 'more', 'mountain', 'or',
#        'that', 'think'],
#       dtype='<U62'), array(['and', 'brokeback', 'mountain', 'movie', 'oh', 'terrible', 'was'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['carsgood', 'codesucked', 'da', 'for', 'hank', 'hedgegood', 'its',
#        'libresucked', 'moments', 'nacho', 'over', 'smokinghad', 'the',
#        'vinci', 'x3good', 'you'],
#       dtype='<U62'), array(['code', 'da', 'love', 'lubb', 'luv', 'the', 'vinci'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'brokeback', 'either', 'great',
#        'homosexuality', 'is', 'its', 'love', 'more', 'mountain', 'or',
#        'that', 'think'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'the', 'vinci'],
#       dtype='<U62'), array(['code', 'da', 'sucked', 'vinci'],
#       dtype='<U62'), array(['excellent', 'impossible', 'mission', 'was'],
#       dtype='<U62'), array(['awesome', 'harrison', 'iii', 'impossible', 'mission', 'said',
#        'that', 'was'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['and', 'but', 'enjoyed', 'impossible', 'involving', 'it', 'loathed',
#        'mission', 'one', 'really', 'this', 'was'],
#       dtype='<U62'), array(['and', 'as', 'escapades', 'impossible', 'kate', 'kirsten', 'leah',
#        'love', 'mission', 'tom', 'well'],
#       dtype='<U62'), array(['and', 'as', 'cleaning', 'dash', 'felicia', 'felicias', 'freakin',
#        'grabs', 'impossible', 'is', 'keys', 'like', 'mission', 'mom', 'my',
#        'out', 'so', 'table', 'the', 'we'],
#       dtype='<U62'), array(['25', 'code', 'da', 'heard', 'much', 'only', 'soo', 'stars',
#        'sucked', 'vinci'],
#       dtype='<U62'), array(['bitch', 'coz', 'down', 'goin', 'hella', 'hill', 'impossible',
#        'into', 'is', 'like', 'mission', 'reality', 'said', 'silent',
#        'that', 'turned', 'was', 'which', 'why'],
#       dtype='<U62'), array(['be', 'blame', 'but', 'chunnel', 'fears', 'for', 'impossible',
#        'mission', 'my', 'of', 'regardless', 'scared', 'some', 'think',
#        'would'],
#       dtype='<U62'), array(['and', 'brokeback', 'mountain', 'movie', 'oh', 'terrible', 'was'],
#       dtype='<U62'), array(['are', 'code', 'da', 'how', 'it', 'know', 'love', 'much', 'people',
#        'the', 'vinci', 'who', 'worth'],
#       dtype='<U62'), array(['also', 'as', 'book', 'can', 'catcher', 'count', 'eyre', 'harry',
#        'if', 'in', 'jane', 'love', 'potter', 'series', 'suicides', 'that',
#        'the', 'tye', 'virgin', 'yeah', 'you'],
#       dtype='<U62'), array(['awesome', 'cant', 'code', 'da', 'it', 'read', 'the', 'to', 'vinci',
#        'wait', 'was'],
#       dtype='<U62'), array(['and', 'bye', 'harry', 'ok', 'potter', 'quiz', 'sucks', 'this'],
#       dtype='<U62'), array(['impossible', 'mission', 'rocks'],
#       dtype='<U62'), array(['harry', 'hate', 'potter', 'to', 'used'],
#       dtype='<U62'), array(['also', 'and', 'evil', 'for', 'harry', 'hate', 'is', 'kids', 'of',
#        'one', 'people', 'potter', 'read', 'shes', 'that', 'these',
#        'thinks', 'this', 'to', 'what', 'witchcraft'],
#       dtype='<U62'), array(['awesome', 'cant', 'code', 'da', 'it', 'read', 'the', 'to', 'vinci',
#        'wait', 'was'],
#       dtype='<U62'), array(['code', 'da', 'hated', 'the', 'vinci'],
#       dtype='<U62'), array(['code', 'da', 'love', 'the', 'vinci'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['as', 'avatar', 'harry', 'if', 'its', 'love', 'much', 'one',
#        'potter', 'theres', 'thing'],
#       dtype='<U62'), array(['excellent', 'impossible', 'mission', 'was'],
#       dtype='<U62'), array(['and', 'deep', 'harry', 'is', 'love', 'of', 'one', 'potter',
#        'profound', 'story', 'the'],
#       dtype='<U62'), array(['about', 'being', 'brokeback', 'dads', 'mountain', 'my', 'stupid'],
#       dtype='<U62'), array(['also', 'as', 'book', 'can', 'catcher', 'count', 'eyre', 'harry',
#        'if', 'in', 'jane', 'love', 'potter', 'series', 'suicides', 'that',
#        'the', 'tye', 'virgin', 'yeah', 'you'],
#       dtype='<U62'), array(['does', 'harry', 'is', 'it', 'just', 'me', 'or', 'potter', 'suck'],
#       dtype='<U62'), array(['brokeback', 'hated', 'have', 'mountain', 'say', 'though', 'to'],
#       dtype='<U62'), array(['besides', 'brokeback', 'crap', 'mountain', 'stupid', 'that'],
#       dtype='<U62'), array(['brokeback', 'mountain', 'sucks', 'too'],
#       dtype='<U62'), array(['code', 'conclusion', 'da', 'draw', 'hate', 'isnt', 'may',
#        'reading', 'review', 'that', 'the', 'this', 'true', 'vinci',
#        'which', 'you'],
#       dtype='<U62'), array(['absolutely', 'awesome', 'code', 'da', 'the', 'vinci', 'was'],
#       dtype='<U62'), array(['am', 'because', 'but', 'character', 'dies', 'harry', 'hate', 'it',
#        'likes', 'main', 'not', 'of', 'person', 'potter', 'that', 'the',
#        'type', 'when'],
#       dtype='<U62'), array(['brokeback', 'loved', 'mountain'],
#       dtype='<U62'), array(['as', 'code', 'da', 'expected', 'sucked', 'vinci'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['an', 'awesome', 'code', 'da', 'movie', 'vinci', 'was'],
#       dtype='<U62'), array(['brokeback', 'horrible', 'is', 'mountain', 'movie', 'ok', 'such'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'vinci'],
#       dtype='<U62'), array(['awesome', 'impossible', 'mission', 'though', 'was'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'brokeback', 'either', 'great',
#        'homosexuality', 'is', 'its', 'love', 'more', 'mountain', 'or',
#        'that', 'think'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['brokeback', 'horrible', 'is', 'mountain', 'movie', 'ok', 'such'],
#       dtype='<U62'), array(['be', 'code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['first', 'impossible', 'loved', 'mission', 'the'],
#       dtype='<U62'), array(['and', 'brokeback', 'mountain', 'movie', 'oh', 'terrible', 'was'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['does', 'harry', 'is', 'it', 'just', 'me', 'or', 'potter', 'suck'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['am', 'as', 'awards', 'brokeback', 'despised', 'here', 'how',
#        'mountain', 'movie', 'mtv', 'much', 'of', 'reminded', 'sit', 'the',
#        'watching'],
#       dtype='<U62'), array(['and', 'brokeback', 'mountain', 'movie', 'oh', 'terrible', 'was'],
#       dtype='<U62'), array(['aching', 'and', 'around', 'blonds', 'cock', 'down', 'draco',
#        'dragged', 'groaning', 'harry', 'him', 'hips', 'his', 'into',
#        'making', 'malfoy', 'noises', 'panting', 'past', 'potter',
#        'rockhard', 'sucked', 'the', 'throat', 'trousers', 'vigor',
#        'whimpering', 'with'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'the', 'vinci'],
#       dtype='<U62'), array(['after', 'bit', 'decided', 'iii', 'impossible', 'little', 'mission',
#        'see', 'sucked', 'that', 'to', 'we', 'which'],
#       dtype='<U62'), array(['awesome', 'brokeback', 'mountain', 'so', 'was'],
#       dtype='<U62'), array(['big', 'code', 'da', 'sucked', 'the', 'time', 'vinci'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'the', 'vinci'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'harry', 'if',
#        'is', 'potter', 'says'],
#       dtype='<U62'), array(['and', 'at', 'bobbypin', 'brokeback', 'cool', 'cowboy', 'hat',
#        'head', 'helped', 'insanely', 'jokes', 'laughed', 'me', 'mountain',
#        'my', 'she', 'stupid', 'to'],
#       dtype='<U62'), array(['code', 'da', 'sucked', 'vinci'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'vinci'],
#       dtype='<U62'), array(['and', 'book', 'but', 'fan', 'fanfic', 'harry', 'hp', 'im', 'not',
#        'of', 'philosophers', 'potter', 'rowling', 'stone', 'strangely',
#        'the'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['board', 'books', 'campaign', 'education', 'evil', 'from',
#        'georgia', 'harry', 'hogwarts', 'hogwash', 'libraries', 'listens',
#        'mothers', 'of', 'potter', 'rid', 'school', 'the', 'those', 'to'],
#       dtype='<U62'), array(['boring', 'brokeback', 'mountain', 'was'],
#       dtype='<U62'), array(['awesome', 'impossible', 'mission', 'was'],
#       dtype='<U62'), array(['and', 'by', 'harry', 'headmistresss', 'highly', 'inappropriate',
#        'melandry', 'nc17', 'of', 'office', 'potter', 'the', 'use'],
#       dtype='<U62'), array(['and', 'be', 'because', 'community', 'friends', 'good', 'harry',
#        'joining', 'like', 'make', 'potter', 'really', 'same', 'so',
#        'start', 'that', 'the', 'things', 'this', 'thought', 'to', 'who',
#        'would'],
#       dtype='<U62'), array(['code', 'da', 'down', 'left', 'right', 'suck', 'up', 'vinci'],
#       dtype='<U62'), array(['harry', 'hate', 'potter'],
#       dtype='<U62'), array(['also', 'anime', 'food', 'friends', 'harry', 'like', 'manga',
#        'movies', 'music', 'potter', 'reading', 'xd'],
#       dtype='<U62'), array(['an', 'code', 'da', 'in', 'kinda', 'okay', 'saw', 'sucked', 'the',
#        'vinci', 'way', 'we', 'which'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'harry', 'hates', 'knows', 'not',
#        'potter', 'want', 'what'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['bitch', 'coz', 'down', 'goin', 'hella', 'hill', 'impossible',
#        'into', 'is', 'like', 'mission', 'reality', 'said', 'silent',
#        'that', 'turned', 'was', 'which', 'why'],
#       dtype='<U62'), array(['aching', 'and', 'around', 'blonds', 'cock', 'down', 'draco',
#        'dragged', 'groaning', 'harry', 'him', 'hips', 'his', 'into',
#        'making', 'malfoy', 'noises', 'panting', 'past', 'potter',
#        'rockhard', 'sucked', 'the', 'throat', 'trousers', 'vigor',
#        'whimpering', 'with'],
#       dtype='<U62'), array(['and', 'even', 'hoffman', 'impossible', 'is', 'mission', 'movie',
#        'pegg', 'phillip', 'seymour', 'shitty', 'simon', 'so'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['impossible', 'mission', 'rocks'],
#       dtype='<U62'), array(['about', 'being', 'brokeback', 'dads', 'mountain', 'my', 'stupid'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['am', 'as', 'awards', 'brokeback', 'despised', 'here', 'how',
#        'mountain', 'movie', 'mtv', 'much', 'of', 'reminded', 'sit', 'the',
#        'watching'],
#       dtype='<U62'), array(['are', 'code', 'da', 'how', 'it', 'know', 'love', 'much', 'people',
#        'the', 'vinci', 'who', 'worth'],
#       dtype='<U62'), array(['impossible', 'mission', 'rocks'],
#       dtype='<U62'), array(['and', 'at', 'bobbypin', 'brokeback', 'cool', 'cowboy', 'hat',
#        'head', 'helped', 'insanely', 'jokes', 'laughed', 'me', 'mountain',
#        'my', 'she', 'stupid', 'to'],
#       dtype='<U62'), array(['brokeback', 'hated', 'mountain', 'soooo'],
#       dtype='<U62'), array(['and', 'brokeback', 'is', 'mountain', 'movie', 'oh', 'terrible'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'harry', 'hates', 'knows', 'not',
#        'potter', 'want', 'what'],
#       dtype='<U62'), array(['code', 'da', 'love', 'the', 'vinci'],
#       dtype='<U62'), array(['brokeback', 'depressing', 'ever', 'have', 'into', 'is', 'most',
#        'mountain', 'movie', 'seen', 'snuck', 'the', 'then', 'which'],
#       dtype='<U62'), array(['brokeback', 'dudeee', 'loved', 'mountain'],
#       dtype='<U62'), array(['code', 'da', 'love', 'the', 'vinci'],
#       dtype='<U62'), array(['correct', 'impossible', 'lousy', 'mission', 'movie', 'my',
#        'prediction', 'was'],
#       dtype='<U62'), array(['and', 'but', 'cruise', 'cuz', 'go', 'hate', 'impossible', 'may',
#        'mission', 'movies', 'new', 'one', 'see', 'think', 'this', 'tom'],
#       dtype='<U62'), array(['about', 'cringe', 'film', 'for', 'horrible', 'impossible', 'it',
#        'john', 'lost', 'made', 'me', 'mission', 'respect', 'so', 'that',
#        'think', 'was', 'whenever', 'woo'],
#       dtype='<U62'), array(['beautiful', 'brokeback', 'mountain', 'was'],
#       dtype='<U62'), array(['30', 'amazing', 'and', 'code', 'da', 'go', 'is', 'left', 'pages',
#        'the', 'to', 'vinci'],
#       dtype='<U62'), array(['be', 'code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'brokeback', 'either', 'great',
#        'homosexuality', 'is', 'its', 'love', 'more', 'mountain', 'or',
#        'that', 'think'],
#       dtype='<U62'), array(['as', 'code', 'da', 'desperately', 'film', 'lovethe', 'to', 'vinci',
#        'wanted'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'the', 'vinci', 'was'],
#       dtype='<U62'), array(['brokeback', 'depressing', 'ever', 'have', 'into', 'is', 'most',
#        'mountain', 'movie', 'seen', 'snuck', 'the', 'then', 'which'],
#       dtype='<U62'), array(['code', 'da', 'loved', 'the', 'vinci'],
#       dtype='<U62'), array(['and', 'being', 'bonkers', 'for', 'impossible', 'love', 'mission',
#        'sentry', 'station'],
#       dtype='<U62'), array(['excellent', 'impossible', 'mission', 'was'],
#       dtype='<U62'), array(['christmas', 'for', 'harry', 'like', 'potter', 'scarf', 'type',
#        'would'],
#       dtype='<U62'), array(['excellent', 'impossible', 'mission', 'was'],
#       dtype='<U62'), array(['and', 'deep', 'harry', 'is', 'love', 'of', 'one', 'potter',
#        'profound', 'story', 'the'],
#       dtype='<U62'), array(['are', 'code', 'da', 'how', 'it', 'know', 'love', 'much', 'people',
#        'the', 'vinci', 'who', 'worth'],
#       dtype='<U62'), array(['25', 'code', 'da', 'heard', 'much', 'only', 'soo', 'stars',
#        'sucked', 'vinci'],
#       dtype='<U62'), array(['and', 'black', 'gay', 'guy', 'harry', 'hate', 'its', 'one', 'only',
#        'potter', 'retarted', 'stupid', 'theres'],
#       dtype='<U62'), array(['and', 'deep', 'harry', 'is', 'love', 'of', 'one', 'potter',
#        'profound', 'story', 'the'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'the', 'vinci'],
#       dtype='<U62'), array(['brokeback', 'dudeee', 'loved', 'mountain'],
#       dtype='<U62'), array(['acne', 'and', 'brokeback', 'got', 'hes', 'likeyeah', 'love',
#        'mountain'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'brokeback', 'either', 'great',
#        'homosexuality', 'is', 'its', 'love', 'more', 'mountain', 'or',
#        'that', 'think'],
#       dtype='<U62'), array(['by', 'code', 'da', 'just', 'know', 'letting', 'sucked', 'the',
#        'vinci', 'way', 'you'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'the', 'vinci'],
#       dtype='<U62'), array(['about', 'being', 'brokeback', 'dads', 'mountain', 'my', 'stupid'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'brokeback', 'either', 'great',
#        'homosexuality', 'is', 'its', 'love', 'more', 'mountain', 'or',
#        'that', 'think'],
#       dtype='<U62'), array(['bitch', 'coz', 'down', 'goin', 'hella', 'hill', 'impossible',
#        'into', 'is', 'like', 'mission', 'reality', 'said', 'silent',
#        'that', 'turned', 'was', 'which', 'why'],
#       dtype='<U62'), array(['awesome', 'brokeback', 'mountain', 'so', 'was'],
#       dtype='<U62'), array(['as', 'code', 'da', 'desperately', 'film', 'lovethe', 'to', 'vinci',
#        'wanted'],
#       dtype='<U62'), array(['harry', 'movies', 'potter', 'really', 'suck', 'these'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'vinci'],
#       dtype='<U62'), array(['and', 'deep', 'harry', 'is', 'love', 'of', 'one', 'potter',
#        'profound', 'story', 'the'],
#       dtype='<U62'), array(['by', 'code', 'da', 'just', 'know', 'letting', 'sucked', 'the',
#        'vinci', 'way', 'you'],
#       dtype='<U62'), array(['aching', 'and', 'around', 'blonds', 'cock', 'down', 'draco',
#        'dragged', 'groaning', 'harry', 'him', 'hips', 'his', 'into',
#        'making', 'malfoy', 'noises', 'panting', 'past', 'potter',
#        'rockhard', 'sucked', 'the', 'throat', 'trousers', 'vigor',
#        'whimpering', 'with'],
#       dtype='<U62'), array(['harry', 'hate', 'potter'],
#       dtype='<U62'), array(['and', 'bye', 'harry', 'ok', 'potter', 'quiz', 'sucks', 'this'],
#       dtype='<U62'), array(['brokeback', 'fucking', 'horrible', 'is', 'mountain'],
#       dtype='<U62'), array(['brokeback', 'depressing', 'mountain', 'really', 'so', 'was'],
#       dtype='<U62'), array(['awesome', 'by', 'code', 'da', 'just', 'read', 'the', 'vinci',
#        'was', 'way', 'which'],
#       dtype='<U62'), array(['ago', 'coming', 'few', 'from', 'harry', 'hours', 'just', 'person',
#        'potter', 'said', 'sucks', 'that', 'the', 'this', 'who'],
#       dtype='<U62'), array(['brokeback', 'depressing', 'ever', 'have', 'into', 'is', 'most',
#        'mountain', 'movie', 'seen', 'snuck', 'the', 'then', 'which'],
#       dtype='<U62'), array(['and', 'be', 'because', 'but', 'fun', 'harry', 'here', 'is', 'it',
#        'love', 'much', 'people', 'place', 'potter', 'really', 'serious',
#        'so', 'still', 'take', 'to', 'want', 'where'],
#       dtype='<U62'), array(['and', 'awesome', 'both', 'impossible', 'last', 'mission', 'movies',
#        'stand', 'the', 'were'],
#       dtype='<U62'), array(['and', 'code', 'da', 'friday', 'hung', 'kelsie', 'out', 'saw',
#        'sucked', 'the', 'vinci', 'we', 'went', 'with'],
#       dtype='<U62'), array(['dumbass', 'evil', 'harry', 'if', 'is', 'potter', 'really', 'think',
#        'you', 'youre'],
#       dtype='<U62'), array(['harry', 'movies', 'potter', 'really', 'suck', 'these'],
#       dtype='<U62'), array(['code', 'da', 'liked', 'lot', 'the', 'vinci'],
#       dtype='<U62'), array(['an', 'awesome', 'code', 'da', 'movie', 'vinci', 'was'],
#       dtype='<U62'), array(['also', 'and', 'code', 'da', 'loved', 'read', 'right', 'the',
#        'their', 'to', 'vinci'],
#       dtype='<U62'), array(['acne', 'and', 'brokeback', 'got', 'hes', 'likeyeah', 'love',
#        'mountain'],
#       dtype='<U62'), array(['big', 'code', 'da', 'sucked', 'the', 'time', 'vinci'],
#       dtype='<U62'), array(['an', 'awesome', 'brokeback', 'mountain', 'movie', 'was'],
#       dtype='<U62'), array(['am', 'as', 'awards', 'brokeback', 'despised', 'here', 'how',
#        'mountain', 'movie', 'mtv', 'much', 'of', 'reminded', 'sit', 'the',
#        'watching'],
#       dtype='<U62'), array(['brokeback', 'horrible', 'mountain', 'movie', 'was'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'vinci'],
#       dtype='<U62'), array(['harry', 'hate', 'potter'],
#       dtype='<U62'), array(['code', 'da', 'love', 'lubb', 'luv', 'the', 'vinci'],
#       dtype='<U62'), array(['code', 'da', 'sucked', 'vinci'],
#       dtype='<U62'), array(['brokeback', 'fucking', 'horrible', 'is', 'mountain'],
#       dtype='<U62'), array(['audrey', 'but', 'code', 'da', 'for', 'hate', 'may', 'movie', 'see',
#        'tautou', 'the', 'vinci'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['and', 'awesome', 'both', 'impossible', 'last', 'mission', 'movies',
#        'stand', 'the', 'were'],
#       dtype='<U62'), array(['but', 'harry', 'hate', 'it', 'love', 'me', 'now', 'potter',
#        'right', 'siss', 'watching', 'younger'],
#       dtype='<U62'), array(['first', 'impossible', 'liked', 'mission', 'the'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['harry', 'like', 'potter', 'too'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['first', 'impossible', 'liked', 'mission', 'the'],
#       dtype='<U62'), array(['harry', 'movies', 'potter', 'really', 'suck', 'these'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'the', 'vinci'],
#       dtype='<U62'), array(['but', 'impossible', 'mission', 'sucks'],
#       dtype='<U62'), array(['fanfiction', 'harry', 'im', 'of', 'potter', 'sick'],
#       dtype='<U62'), array(['about', 'being', 'brokeback', 'dads', 'mountain', 'my', 'stupid'],
#       dtype='<U62'), array(['and', 'brokeback', 'is', 'mountain', 'movie', 'oh', 'terrible'],
#       dtype='<U62'), array(['and', 'brokeback', 'is', 'mountain', 'movie', 'oh', 'terrible'],
#       dtype='<U62'), array(['are', 'code', 'da', 'how', 'it', 'know', 'love', 'much', 'people',
#        'the', 'vinci', 'who', 'worth'],
#       dtype='<U62'), array(['and', 'bye', 'harry', 'ok', 'potter', 'quiz', 'sucks', 'this'],
#       dtype='<U62'), array(['does', 'harry', 'is', 'it', 'just', 'me', 'or', 'potter', 'suck'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['and', 'as', 'brokeback', 'capote', 'is', 'it', 'love', 'mountain',
#        'much', 'shame', 'such', 'that', 'transamerica'],
#       dtype='<U62'), array(['and', 'brokeback', 'mountain', 'movie', 'oh', 'terrible', 'was'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['because', 'harry', 'love', 'potter'],
#       dtype='<U62'), array(['and', 'code', 'da', 'friday', 'hung', 'kelsie', 'out', 'saw',
#        'sucked', 'the', 'vinci', 'we', 'went', 'with'],
#       dtype='<U62'), array(['beautiful', 'brokeback', 'mountain', 'was'],
#       dtype='<U62'), array(['acne', 'and', 'brokeback', 'got', 'hes', 'likeyeah', 'love',
#        'mountain'],
#       dtype='<U62'), array(['am', 'as', 'awards', 'brokeback', 'despised', 'here', 'how',
#        'mountain', 'movie', 'mtv', 'much', 'of', 'reminded', 'sit', 'the',
#        'watching'],
#       dtype='<U62'), array(['an', 'awesome', 'code', 'da', 'movie', 'vinci', 'was'],
#       dtype='<U62'), array(['as', 'code', 'da', 'desperately', 'film', 'lovethe', 'to', 'vinci',
#        'wanted'],
#       dtype='<U62'), array(['and', 'brokeback', 'mountain', 'movie', 'oh', 'terrible', 'was'],
#       dtype='<U62'), array(['acne', 'and', 'brokeback', 'got', 'hes', 'likeyeah', 'love',
#        'mountain'],
#       dtype='<U62'), array(['be', 'code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['because', 'impossible', 'know', 'like', 'mission', 'movies',
#        'never', 'on', 'right', 'side', 'the', 'whos', 'you'],
#       dtype='<U62'), array(['harry', 'hate', 'potter'],
#       dtype='<U62'), array(['be', 'code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['brokeback', 'depressing', 'mountain', 'really', 'so', 'was'],
#       dtype='<U62'), array(['and', 'bye', 'harry', 'ok', 'potter', 'quiz', 'sucks', 'this'],
#       dtype='<U62'), array(['harry', 'movies', 'potter', 'really', 'suck', 'these'],
#       dtype='<U62'), array(['after', 'egg', 'from', 'godawful', 'impossible', 'john', 'laid',
#        'major', 'mission', 'the', 'woo'],
#       dtype='<U62'), array(['brokeback', 'dudeee', 'loved', 'mountain'],
#       dtype='<U62'), array(['brokeback', 'but', 'feeling', 'immensely', 'is', 'moralistic',
#        'mountain', 'never', 'tragic', 'wellexecuted'],
#       dtype='<U62'), array(['harry', 'hate', 'potter'],
#       dtype='<U62'), array(['an', 'excellent', 'impossible', 'is', 'mission', 'movie'],
#       dtype='<U62'), array(['and', 'as', 'escapades', 'impossible', 'kate', 'kirsten', 'leah',
#        'love', 'mission', 'tom', 'well'],
#       dtype='<U62'), array(['and', 'bye', 'harry', 'ok', 'potter', 'quiz', 'sucks', 'this'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['brokeback', 'dudeee', 'loved', 'mountain'],
#       dtype='<U62'), array(['brokeback', 'but', 'even', 'halfway', 'im', 'is', 'mountain',
#        'movie', 'not', 'terrible', 'think', 'this', 'through'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['impossible', 'mission', 'rocks'],
#       dtype='<U62'), array(['beautiful', 'brokeback', 'mountain', 'was'],
#       dtype='<U62'), array(['and', 'deep', 'harry', 'is', 'love', 'of', 'one', 'potter',
#        'profound', 'story', 'the'],
#       dtype='<U62'), array(['25', 'code', 'da', 'heard', 'much', 'only', 'soo', 'stars',
#        'sucked', 'vinci'],
#       dtype='<U62'), array(['absolutely', 'awesome', 'code', 'da', 'the', 'vinci', 'was'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['does', 'harry', 'is', 'it', 'just', 'me', 'or', 'potter', 'suck'],
#       dtype='<U62'), array(['harry', 'like', 'potter', 'too'],
#       dtype='<U62'), array(['awesome', 'impossible', 'mission', 'was'],
#       dtype='<U62'), array(['anyway', 'brokeback', 'love', 'mountain', 'thats', 'why'],
#       dtype='<U62'), array(['am', 'as', 'awards', 'brokeback', 'despised', 'here', 'how',
#        'mountain', 'movie', 'mtv', 'much', 'of', 'reminded', 'sit', 'the',
#        'watching'],
#       dtype='<U62'), array(['am', 'because', 'but', 'character', 'dies', 'harry', 'hate', 'it',
#        'likes', 'main', 'not', 'of', 'person', 'potter', 'that', 'the',
#        'type', 'when'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['code', 'da', 'heard', 'sucks', 'the', 'vinci'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['and', 'bye', 'harry', 'ok', 'potter', 'quiz', 'sucks', 'this'],
#       dtype='<U62'), array(['awesome', 'brokeback', 'mountain', 'so', 'was'],
#       dtype='<U62'), array(['code', 'da', 'sucked', 'the', 'vinci'],
#       dtype='<U62'), array(['absolutely', 'awesome', 'code', 'da', 'the', 'vinci', 'was'],
#       dtype='<U62'), array(['aroundthe', 'boring', 'center', 'cobequid', 'health', 'howmission',
#        'iii', 'impossible', 'is', 'new', 'nice', 'really', 'second',
#        'soooooooo', 'the', 'time'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['daniel', 'fucking', 'harry', 'hate', 'needs', 'potter', 'slap',
#        'that', 'wotshisface'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'the', 'vinci'],
#       dtype='<U62'), array(['also', 'as', 'book', 'can', 'catcher', 'count', 'eyre', 'harry',
#        'if', 'in', 'jane', 'love', 'potter', 'series', 'suicides', 'that',
#        'the', 'tye', 'virgin', 'yeah', 'you'],
#       dtype='<U62'), array(['and', 'awesome', 'both', 'impossible', 'last', 'mission', 'movies',
#        'stand', 'the', 'were'],
#       dtype='<U62'), array(['and', 'bye', 'harry', 'ok', 'potter', 'quiz', 'sucks', 'this'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'brokeback', 'either', 'great',
#        'homosexuality', 'is', 'its', 'love', 'more', 'mountain', 'or',
#        'that', 'think'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['impossible', 'mission', 'rocks'],
#       dtype='<U62'), array(['and', 'deep', 'harry', 'is', 'love', 'of', 'one', 'potter',
#        'profound', 'story', 'the'],
#       dtype='<U62'), array(['and', 'awesome', 'both', 'impossible', 'last', 'mission', 'movies',
#        'stand', 'the', 'were'],
# ...
#        'mountain', 'much', 'need', 'see', 'sucks', 'to'],
#       dtype='<U62'), array(['code', 'da', 'love', 'the', 'vinci'],
#       dtype='<U62'), array(['impossible', 'mission', 'sucks'],
#       dtype='<U62'), array(['and', 'brokeback', 'mountain', 'movie', 'oh', 'terrible', 'was'],
#       dtype='<U62'), array(['be', 'childrens', 'criticized', 'evil', 'example', 'for', 'good',
#        'harry', 'might', 'most', 'obviouslyis', 'of', 'often',
#        'oversimplifying', 'perhaps', 'potter', 'struggle', 'textsfantasy',
#        'the', 'this', 'vs'],
#       dtype='<U62'), array(['acne', 'and', 'brokeback', 'got', 'hes', 'likeyeah', 'love',
#        'mountain'],
#       dtype='<U62'), array(['awesome', 'brokeback', 'mountain', 'so', 'was'],
#       dtype='<U62'), array(['aching', 'and', 'around', 'blonds', 'cock', 'down', 'draco',
#        'dragged', 'groaning', 'harry', 'him', 'hips', 'his', 'into',
#        'making', 'malfoy', 'noises', 'panting', 'past', 'potter',
#        'rockhard', 'sucked', 'the', 'throat', 'trousers', 'vigor',
#        'whimpering', 'with'],
#       dtype='<U62'), array(['harry', 'hate', 'potter'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'vinci'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['about', 'being', 'brokeback', 'dads', 'mountain', 'my', 'stupid'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['code', 'da', 'love', 'lubb', 'luv', 'the', 'vinci'],
#       dtype='<U62'), array(['code', 'da', 'sucked', 'vinci'],
#       dtype='<U62'), array(['are', 'code', 'da', 'how', 'it', 'know', 'love', 'much', 'people',
#        'the', 'vinci', 'who', 'worth'],
#       dtype='<U62'), array(['and', 'code', 'da', 'didnt', 'get', 'have', 'jenn', 'later',
#        'maybe', 'money', 'no', 'now', 'overslept', 'see', 'so', 'sucked',
#        'the', 'though', 'to', 'vinci', 'which', 'yeah'],
#       dtype='<U62'), array(['and', 'as', 'cleaning', 'dash', 'felicia', 'felicias', 'freakin',
#        'grabs', 'impossible', 'is', 'keys', 'like', 'mission', 'mom', 'my',
#        'out', 'so', 'table', 'the', 'we'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'vinci'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['at', 'be', 'going', 'harry', 'ill', 'is', 'lol', 'potter', 'suck',
#        'suncoast', 'to', 'weekend', 'which', 'working'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['harry', 'like', 'potter', 'too'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['and', 'as', 'escapades', 'impossible', 'kate', 'kirsten', 'leah',
#        'love', 'mission', 'tom', 'well'],
#       dtype='<U62'), array(['harry', 'hate', 'potter'],
#       dtype='<U62'), array(['code', 'da', 'suck', 'vinci', 'will'],
#       dtype='<U62'), array(['impossible', 'mission', 'rocks'],
#       dtype='<U62'), array(['am', 'as', 'awards', 'brokeback', 'despised', 'here', 'how',
#        'mountain', 'movie', 'mtv', 'much', 'of', 'reminded', 'sit', 'the',
#        'watching'],
#       dtype='<U62'), array(['and', 'code', 'combining', 'da', 'from', 'gary', 'gin', 'opinion',
#        'review', 'sucks', 'the', 'vinci', 'zen'],
#       dtype='<U62'), array(['and', 'awesome', 'both', 'impossible', 'last', 'mission', 'movies',
#        'stand', 'the', 'were'],
#       dtype='<U62'), array(['and', 'brokeback', 'is', 'mountain', 'movie', 'oh', 'terrible'],
#       dtype='<U62'), array(['and', 'black', 'gay', 'guy', 'harry', 'hate', 'its', 'one', 'only',
#        'potter', 'retarted', 'stupid', 'theres'],
#       dtype='<U62'), array(['audrey', 'but', 'code', 'da', 'for', 'hate', 'may', 'movie', 'see',
#        'tautou', 'the', 'vinci'],
#       dtype='<U62'), array(['code', 'da', 'love', 'lubb', 'luv', 'the', 'vinci'],
#       dtype='<U62'), array(['and', 'be', 'because', 'community', 'friends', 'good', 'harry',
#        'joining', 'like', 'make', 'potter', 'really', 'same', 'so',
#        'start', 'that', 'the', 'things', 'this', 'thought', 'to', 'who',
#        'would'],
#       dtype='<U62'), array(['and', 'be', 'because', 'community', 'friends', 'good', 'harry',
#        'joining', 'like', 'make', 'potter', 'really', 'same', 'so',
#        'start', 'that', 'the', 'things', 'this', 'thought', 'to', 'who',
#        'would'],
#       dtype='<U62'), array(['code', 'da', 'love', 'lubb', 'luv', 'the', 'vinci'],
#       dtype='<U62'), array(['impossible', 'mission', 'rocks'],
#       dtype='<U62'), array(['acne', 'and', 'brokeback', 'got', 'hes', 'likeyeah', 'love',
#        'mountain'],
#       dtype='<U62'), array(['and', 'be', 'because', 'but', 'fun', 'harry', 'here', 'is', 'it',
#        'love', 'much', 'people', 'place', 'potter', 'really', 'serious',
#        'so', 'still', 'take', 'to', 'want', 'where'],
#       dtype='<U62'), array(['harry', 'like', 'potter', 'too'],
#       dtype='<U62'), array(['acne', 'and', 'brokeback', 'got', 'hes', 'likeyeah', 'love',
#        'mountain'],
#       dtype='<U62'), array(['about', 'being', 'brokeback', 'dads', 'mountain', 'my', 'stupid'],
#       dtype='<U62'), array(['brokeback', 'mountain', 'stupid'],
#       dtype='<U62'), array(['gonna', 'hoot', 'impossible', 'like', 'mission', 'or', 'watch',
#        'were'],
#       dtype='<U62'), array(['big', 'code', 'da', 'sucked', 'the', 'time', 'vinci'],
#       dtype='<U62'), array(['harry', 'hate', 'potter'],
#       dtype='<U62'), array(['aching', 'and', 'around', 'blonds', 'cock', 'down', 'draco',
#        'dragged', 'groaning', 'harry', 'him', 'hips', 'his', 'into',
#        'making', 'malfoy', 'noises', 'panting', 'past', 'potter',
#        'rockhard', 'sucked', 'the', 'throat', 'trousers', 'vigor',
#        'whimpering', 'with'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'harry', 'if',
#        'is', 'potter', 'says'],
#       dtype='<U62'), array(['and', 'as', 'cleaning', 'dash', 'felicia', 'felicias', 'freakin',
#        'grabs', 'impossible', 'is', 'keys', 'like', 'mission', 'mom', 'my',
#        'out', 'so', 'table', 'the', 'we'],
#       dtype='<U62'), array(['big', 'code', 'da', 'sucked', 'the', 'time', 'vinci'],
#       dtype='<U62'), array(['brokeback', 'mountain', 'sucked'],
#       dtype='<U62'), array(['and', 'brokeback', 'is', 'mountain', 'movie', 'oh', 'terrible'],
#       dtype='<U62'), array(['first', 'impossible', 'liked', 'mission', 'the'],
#       dtype='<U62'), array(['brokeback', 'hate', 'mountain'],
#       dtype='<U62'), array(['balls', 'big', 'code', 'da', 'donkey', 'sucked', 'the', 'vinci'],
#       dtype='<U62'), array(['am', 'brokeback', 'in', 'mountain', 'only', 'person', 'sucked',
#        'the', 'thought', 'who', 'world'],
#       dtype='<U62'), array(['and', 'code', 'da', 'friday', 'hung', 'kelsie', 'out', 'saw',
#        'sucked', 'the', 'vinci', 'we', 'went', 'with'],
#       dtype='<U62'), array(['brokeback', 'depressing', 'ever', 'have', 'into', 'is', 'most',
#        'mountain', 'movie', 'seen', 'snuck', 'the', 'then', 'which'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['an', 'awesome', 'book', 'code', 'da', 'is', 'such', 'the', 'vinci'],
#       dtype='<U62'), array(['and', 'black', 'gay', 'guy', 'harry', 'hate', 'its', 'one', 'only',
#        'potter', 'retarted', 'stupid', 'theres'],
#       dtype='<U62'), array(['code', 'da', 'sucked', 'vinci'],
#       dtype='<U62'), array(['boring', 'brokeback', 'mountain', 'was'],
#       dtype='<U62'), array(['and', 'code', 'da', 'friday', 'hung', 'kelsie', 'out', 'saw',
#        'sucked', 'the', 'vinci', 'we', 'went', 'with'],
#       dtype='<U62'), array(['bitch', 'coz', 'down', 'goin', 'hella', 'hill', 'impossible',
#        'into', 'is', 'like', 'mission', 'reality', 'said', 'silent',
#        'that', 'turned', 'was', 'which', 'why'],
#       dtype='<U62'), array(['brokeback', 'hate', 'mountain'],
#       dtype='<U62'), array(['absolutely', 'awesome', 'code', 'da', 'the', 'vinci', 'was'],
#       dtype='<U62'), array(['impossible', 'mission', 'rocks'],
#       dtype='<U62'), array(['brokeback', 'loved', 'mountain', 'omg'],
#       dtype='<U62'), array(['almost', 'america', 'as', 'code', 'da', 'hating', 'love', 'much',
#        'supporting', 'the', 'vinci'],
#       dtype='<U62'), array(['brokeback', 'horrible', 'is', 'mountain', 'movie', 'ok', 'such'],
#       dtype='<U62'), array(['does', 'harry', 'is', 'it', 'just', 'me', 'or', 'potter', 'suck'],
#       dtype='<U62'), array(['also', 'as', 'book', 'can', 'catcher', 'count', 'eyre', 'harry',
#        'if', 'in', 'jane', 'love', 'potter', 'series', 'suicides', 'that',
#        'the', 'tye', 'virgin', 'yeah', 'you'],
#       dtype='<U62'), array(['and', 'chronicles', 'disney', 'harry', 'hate', 'lords', 'narnia',
#        'of', 'potter', 'ring', 'the'],
#       dtype='<U62'), array(['am', 'as', 'awards', 'brokeback', 'despised', 'here', 'how',
#        'mountain', 'movie', 'mtv', 'much', 'of', 'reminded', 'sit', 'the',
#        'watching'],
#       dtype='<U62'), array(['and', 'but', 'forgotten', 'great', 'had', 'harry', 'is', 'it',
#        'level', 'low', 'potter', 'reading', 'sorcerers', 'stone', 'the',
#        'what'],
#       dtype='<U62'), array(['an', 'awesome', 'code', 'da', 'movie', 'vinci', 'was'],
#       dtype='<U62'), array(['code', 'da', 'love', 'the', 'vinci'],
#       dtype='<U62'), array(['again', 'am', 'awesome', 'because', 'going', 'harry', 'is', 'one',
#        'potter', 'reading', 'series', 'start', 'story', 'that', 'the', 'to'],
#       dtype='<U62'), array(['and', 'because', 'brokeback', 'characters', 'gay', 'hated', 'main',
#        'mountain', 'not', 'the', 'were'],
#       dtype='<U62'), array(['and', 'brokeback', 'mountain', 'movie', 'oh', 'terrible', 'was'],
#       dtype='<U62'), array(['and', 'awful', 'awkward', 'be', 'brokeback', 'might', 'mountain',
#        'pretty', 'rent', 'think', 'together'],
#       dtype='<U62'), array(['and', 'bye', 'harry', 'ok', 'potter', 'quiz', 'sucks', 'this'],
#       dtype='<U62'), array(['and', 'code', 'combining', 'da', 'from', 'gary', 'gin', 'opinion',
#        'review', 'sucks', 'the', 'vinci', 'zen'],
#       dtype='<U62'), array(['amazing', 'an', 'and', 'at', 'buy', 'code', 'course', 'da', 'even',
#        'exaggeration', 'is', 'midnight', 'not', 'of', 'thats', 'the', 'to',
#        'vinci', 'walmart', 'we', 'went', 'which'],
#       dtype='<U62'), array(['and', 'bye', 'harry', 'ok', 'potter', 'quiz', 'sucks', 'this'],
#       dtype='<U62'), array(['and', 'code', 'combining', 'da', 'from', 'gary', 'gin', 'opinion',
#        'review', 'sucks', 'the', 'vinci', 'zen'],
#       dtype='<U62'), array(['first', 'impossible', 'liked', 'mission', 'the'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['does', 'harry', 'is', 'it', 'just', 'me', 'or', 'potter', 'suck'],
#       dtype='<U62'), array(['daniel', 'fucking', 'harry', 'hate', 'needs', 'potter', 'slap',
#        'that', 'wotshisface'],
#       dtype='<U62'), array(['and', 'code', 'da', 'love', 'too', 'vinci'],
#       dtype='<U62'), array(['code', 'da', 'sucked', 'vinci'],
#       dtype='<U62'), array(['by', 'code', 'da', 'just', 'know', 'letting', 'sucked', 'the',
#        'vinci', 'way', 'you'],
#       dtype='<U62'), array(['am', 'as', 'awards', 'brokeback', 'despised', 'here', 'how',
#        'mountain', 'movie', 'mtv', 'much', 'of', 'reminded', 'sit', 'the',
#        'watching'],
#       dtype='<U62'), array(['an', 'awesome', 'book', 'code', 'da', 'is', 'the', 'vinci'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'vinci'],
#       dtype='<U62'), array(['code', 'da', 'sucked', 'vinci'],
#       dtype='<U62'), array(['daniel', 'fucking', 'harry', 'hate', 'needs', 'potter', 'slap',
#        'that', 'wotshisface'],
#       dtype='<U62'), array(['and', 'being', 'bonkers', 'for', 'impossible', 'love', 'mission',
#        'sentry', 'station'],
#       dtype='<U62'), array(['and', 'black', 'gay', 'guy', 'harry', 'hate', 'its', 'one', 'only',
#        'potter', 'retarted', 'stupid', 'theres'],
#       dtype='<U62'), array(['also', 'harry', 'potter', 'sexy'],
#       dtype='<U62'), array(['harry', 'movies', 'potter', 'really', 'suck', 'these'],
#       dtype='<U62'), array(['and', 'brokeback', 'mountain', 'movie', 'oh', 'terrible', 'was'],
#       dtype='<U62'), array(['25', 'code', 'da', 'heard', 'much', 'only', 'soo', 'stars',
#        'sucked', 'vinci'],
#       dtype='<U62'), array(['aching', 'and', 'around', 'blonds', 'cock', 'down', 'draco',
#        'dragged', 'groaning', 'harry', 'him', 'hips', 'his', 'into',
#        'making', 'malfoy', 'noises', 'panting', 'past', 'potter',
#        'rockhard', 'sucked', 'the', 'throat', 'trousers', 'vigor',
#        'whimpering', 'with'],
#       dtype='<U62'), array(['and', 'code', 'combining', 'da', 'from', 'gary', 'gin', 'opinion',
#        'review', 'sucks', 'the', 'vinci', 'zen'],
#       dtype='<U62'), array(['brokeback', 'depressing', 'ever', 'have', 'into', 'is', 'most',
#        'mountain', 'movie', 'seen', 'snuck', 'the', 'then', 'which'],
#       dtype='<U62'), array(['absolutely', 'awesome', 'code', 'da', 'the', 'vinci', 'was'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'brokeback', 'either', 'great',
#        'homosexuality', 'is', 'its', 'love', 'more', 'mountain', 'or',
#        'that', 'think'],
#       dtype='<U62'), array(['code', 'da', 'know', 'loved', 'the', 'too', 'vinci'],
#       dtype='<U62'), array(['code', 'da', 'love', 'the', 'vinci'],
#       dtype='<U62'), array(['awesome', 'brokeback', 'mountain', 'so', 'was'],
#       dtype='<U62'), array(['because', 'impossible', 'know', 'like', 'mission', 'movies',
#        'never', 'on', 'right', 'side', 'the', 'whos', 'you'],
#       dtype='<U62'), array(['and', 'awesome', 'both', 'impossible', 'last', 'mission', 'movies',
#        'stand', 'the', 'were'],
#       dtype='<U62'), array(['code', 'da', 'does', 'suck', 'vinci'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['btw', 'code', 'da', 'sucks', 'the', 'vinci'],
#       dtype='<U62'), array(['and', 'as', 'cleaning', 'dash', 'felicia', 'felicias', 'freakin',
#        'grabs', 'impossible', 'is', 'keys', 'like', 'mission', 'mom', 'my',
#        'out', 'so', 'table', 'the', 'we'],
#       dtype='<U62'), array(['and', 'be', 'because', 'but', 'fun', 'harry', 'here', 'is', 'it',
#        'love', 'much', 'people', 'place', 'potter', 'really', 'serious',
#        'so', 'still', 'take', 'to', 'want', 'where'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['impossible', 'mission', 'rocks'],
#       dtype='<U62'), array(['and', 'brokeback', 'is', 'mountain', 'movie', 'oh', 'terrible'],
#       dtype='<U62'), array(['admiring', 'biggie', 'collection', 'harry', 'his', 'it', 'no',
#        'planned', 'potter', 'sisters', 'so', 'waited', 'was', 'while'],
#       dtype='<U62'), array(['daniel', 'fucking', 'harry', 'hate', 'needs', 'potter', 'slap',
#        'that', 'wotshisface'],
#       dtype='<U62'), array(['and', 'be', 'because', 'community', 'friends', 'good', 'harry',
#        'joining', 'like', 'make', 'potter', 'really', 'same', 'so',
#        'start', 'that', 'the', 'things', 'this', 'thought', 'to', 'who',
#        'would'],
#       dtype='<U62'), array(['and', 'bye', 'harry', 'ok', 'potter', 'quiz', 'sucks', 'this'],
#       dtype='<U62'), array(['code', 'da', 'hated', 'vinci'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'the', 'vinci'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['about', 'being', 'brokeback', 'dads', 'mountain', 'my', 'stupid'],
#       dtype='<U62'), array(['because', 'impossible', 'know', 'like', 'mission', 'movies',
#        'never', 'on', 'right', 'side', 'the', 'whos', 'you'],
#       dtype='<U62'), array(['books', 'harry', 'love', 'personally', 'potter', 'reading'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62')]

# %%
print(vect.inverse_transform(trX))
# Out:
# [array(['aching', 'and', 'around', 'blonds', 'cock', 'down', 'draco',
#        'dragged', 'groaning', 'harry', 'him', 'hips', 'his', 'into',
#        'making', 'malfoy', 'noises', 'panting', 'past', 'potter',
#        'rockhard', 'sucked', 'the', 'throat', 'trousers', 'vigor',
#        'whimpering', 'with'],
#       dtype='<U62'), array(['big', 'code', 'da', 'sucked', 'the', 'time', 'vinci'],
#       dtype='<U62'), array(['brokeback', 'depressing', 'mountain', 'really', 'so', 'was'],
#       dtype='<U62'), array(['and', 'brokeback', 'is', 'mountain', 'movie', 'oh', 'terrible'],
#       dtype='<U62'), array(['brokeback', 'fucking', 'horrible', 'is', 'mountain'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'the', 'vinci'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'harry', 'hates', 'knows', 'not',
#        'potter', 'want', 'what'],
#       dtype='<U62'), array(['code', 'da', 'love', 'the', 'vinci'],
#       dtype='<U62'), array(['and', 'brokeback', 'is', 'mountain', 'movie', 'oh', 'terrible'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'vinci'],
#       dtype='<U62'), array(['brokeback', 'horrible', 'is', 'mountain', 'movie', 'ok', 'such'],
#       dtype='<U62'), array(['and', 'awesome', 'both', 'impossible', 'last', 'mission', 'movies',
#        'stand', 'the', 'were'],
#       dtype='<U62'), array(['brokeback', 'depressing', 'mountain', 'really', 'so', 'was'],
#       dtype='<U62'), array(['boring', 'brokeback', 'mountain', 'was'],
#       dtype='<U62'), array(['about', 'being', 'brokeback', 'dads', 'mountain', 'my', 'stupid'],
#       dtype='<U62'), array(['first', 'impossible', 'liked', 'mission', 'the'],
#       dtype='<U62'), array(['an', 'awesome', 'code', 'da', 'movie', 'vinci', 'was'],
#       dtype='<U62'), array(['again', 'am', 'awesome', 'because', 'going', 'harry', 'is', 'one',
#        'potter', 'reading', 'series', 'start', 'story', 'that', 'the', 'to'],
#       dtype='<U62'), array(['about', 'and', 'be', 'because', 'book', 'community', 'discuss',
#        'harry', 'it', 'love', 'of', 'other', 'part', 'people', 'potter',
#        'that', 'theories', 'this', 'to', 'want', 'with'],
#       dtype='<U62'), array(['and', 'awesome', 'he', 'hot', 'impossible', 'in', 'is', 'mission'],
#       dtype='<U62'), array(['brokeback', 'mountain', 'much', 'pretty', 'sucked'],
#       dtype='<U62'), array(['an', 'awesome', 'code', 'da', 'is', 'movie', 'vinci'],
#       dtype='<U62'), array(['awesome', 'brokeback', 'mountain', 'so', 'was'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['code', 'da', 'loved', 'the', 'vinci'],
#       dtype='<U62'), array(['excellent', 'impossible', 'mission', 'was'],
#       dtype='<U62'), array(['and', 'brokeback', 'mountain', 'movie', 'oh', 'terrible', 'was'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'brokeback', 'either', 'great',
#        'homosexuality', 'is', 'its', 'love', 'more', 'mountain', 'or',
#        'that', 'think'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'harry', 'hates', 'knows', 'not',
#        'potter', 'want', 'what'],
#       dtype='<U62'), array(['gonna', 'hoot', 'impossible', 'like', 'mission', 'or', 'watch',
#        'were'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'the', 'vinci'],
#       dtype='<U62'), array(['code', 'da', 'love', 'the', 'vinci'],
#       dtype='<U62'), array(['25', 'code', 'da', 'heard', 'much', 'only', 'soo', 'stars',
#        'sucked', 'vinci'],
#       dtype='<U62'), array(['and', 'black', 'gay', 'guy', 'harry', 'hate', 'its', 'one', 'only',
#        'potter', 'retarted', 'stupid', 'theres'],
#       dtype='<U62'), array(['also', 'as', 'book', 'can', 'catcher', 'count', 'eyre', 'harry',
#        'if', 'in', 'jane', 'love', 'potter', 'series', 'suicides', 'that',
#        'the', 'tye', 'virgin', 'yeah', 'you'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'harry', 'if',
#        'is', 'potter', 'says'],
#       dtype='<U62'), array(['awesome', 'impossible', 'mission', 'was'],
#       dtype='<U62'), array(['acne', 'and', 'brokeback', 'got', 'hes', 'likeyeah', 'love',
#        'mountain'],
#       dtype='<U62'), array(['and', 'at', 'bobbypin', 'brokeback', 'cool', 'cowboy', 'hat',
#        'head', 'helped', 'insanely', 'jokes', 'laughed', 'me', 'mountain',
#        'my', 'she', 'stupid', 'to'],
#       dtype='<U62'), array(['brokeback', 'fucking', 'horrible', 'is', 'mountain'],
#       dtype='<U62'), array(['enjoyed', 'every', 'film', 'first', 'harry', 'have', 'much',
#        'potter', 'should', 'state', 'that', 'very'],
#       dtype='<U62'), array(['actually', 'brokeback', 'loved', 'mountain'],
#       dtype='<U62'), array(['and', 'are', 'because', 'begin', 'better', 'harry', 'hate', 'it',
#        'just', 'material', 'movies', 'much', 'out', 'outshines', 'plain',
#        'potter', 'reading', 'stupid', 'the', 'there', 'think', 'to', 'with'],
#       dtype='<U62'), array(['does', 'harry', 'is', 'it', 'just', 'me', 'or', 'potter', 'suck'],
#       dtype='<U62'), array(['brokeback', 'horrible', 'is', 'mountain', 'movie', 'ok', 'such'],
#       dtype='<U62'), array(['and', 'awesome', 'both', 'impossible', 'last', 'mission', 'movies',
#        'stand', 'the', 'were'],
#       dtype='<U62'), array(['harry', 'movies', 'potter', 'really', 'suck', 'these'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['and', 'black', 'gay', 'guy', 'harry', 'hate', 'its', 'one', 'only',
#        'potter', 'retarted', 'stupid', 'theres'],
#       dtype='<U62'), array(['also', 'as', 'book', 'can', 'catcher', 'count', 'eyre', 'harry',
#        'if', 'in', 'jane', 'love', 'potter', 'series', 'suicides', 'that',
#        'the', 'tye', 'virgin', 'yeah', 'you'],
#       dtype='<U62'), array(['first', 'impossible', 'liked', 'mission', 'the'],
#       dtype='<U62'), array(['harry', 'hate', 'potter'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'the', 'vinci'],
#       dtype='<U62'), array(['brokeback', 'dudeee', 'loved', 'mountain'],
#       dtype='<U62'), array(['am', 'because', 'but', 'character', 'dies', 'harry', 'hate', 'it',
#        'likes', 'main', 'not', 'of', 'person', 'potter', 'that', 'the',
#        'type', 'when'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['as', 'code', 'da', 'desperately', 'film', 'lovethe', 'to', 'vinci',
#        'wanted'],
#       dtype='<U62'), array(['believe', 'calledharry', 'cant', 'cried', 'facebook', 'group',
#        'my', 'potter', 'roommate', 'sucks', 'theres', 'when'],
#       dtype='<U62'), array(['bitch', 'coz', 'down', 'goin', 'hella', 'hill', 'impossible',
#        'into', 'is', 'like', 'mission', 'reality', 'said', 'silent',
#        'that', 'turned', 'was', 'which', 'why'],
#       dtype='<U62'), array(['code', 'da', 'down', 'left', 'right', 'suck', 'up', 'vinci'],
#       dtype='<U62'), array(['about', 'being', 'brokeback', 'dads', 'mountain', 'my', 'stupid'],
#       dtype='<U62'), array(['aching', 'and', 'around', 'blonds', 'cock', 'down', 'draco',
#        'dragged', 'groaning', 'harry', 'him', 'hips', 'his', 'into',
#        'making', 'malfoy', 'noises', 'panting', 'past', 'potter',
#        'rockhard', 'sucked', 'the', 'throat', 'trousers', 'vigor',
#        'whimpering', 'with'],
#       dtype='<U62'), array(['all', 'and', 'exception', 'impossible', 'is', 'love', 'mission',
#        'movies', 'no', 'one', 'the', 'this'],
#       dtype='<U62'), array(['brokeback', 'horrible', 'is', 'mountain', 'movie', 'ok', 'such'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['am', 'as', 'awards', 'brokeback', 'despised', 'here', 'how',
#        'mountain', 'movie', 'mtv', 'much', 'of', 'reminded', 'sit', 'the',
#        'watching'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'brokeback', 'either', 'great',
#        'homosexuality', 'is', 'its', 'love', 'more', 'mountain', 'or',
#        'that', 'think'],
#       dtype='<U62'), array(['harry', 'movies', 'potter', 'really', 'suck', 'these'],
#       dtype='<U62'), array(['by', 'code', 'da', 'just', 'know', 'letting', 'sucked', 'the',
#        'vinci', 'way', 'you'],
#       dtype='<U62'), array(['also', 'brokeback', 'can', 'depressing', 'ever', 'have', 'is',
#        'most', 'mountain', 'movie', 'much', 'pretty', 'say', 'seen',
#        'that', 'the'],
#       dtype='<U62'), array(['an', 'awesome', 'brokeback', 'mountain', 'movie', 'was'],
#       dtype='<U62'), array(['awesome', 'impossible', 'mission', 'three', 'was'],
#       dtype='<U62'), array(['beautiful', 'brokeback', 'friday', 'is', 'mountain', 'see', 'to',
#        'went', 'which'],
#       dtype='<U62'), array(['and', 'brokeback', 'is', 'mountain', 'movie', 'oh', 'terrible'],
#       dtype='<U62'), array(['first', 'impossible', 'liked', 'mission', 'the'],
#       dtype='<U62'), array(['amazing', 'brokeback', 'is', 'mountain'],
#       dtype='<U62'), array(['boring', 'brokeback', 'mountain', 'was'],
#       dtype='<U62'), array(['brokeback', 'horrible', 'is', 'mountain', 'movie', 'ok', 'such'],
#       dtype='<U62'), array(['and', 'brokeback', 'mountain', 'movie', 'oh', 'terrible', 'was'],
#       dtype='<U62'), array(['be', 'code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['about', 'being', 'brokeback', 'dads', 'mountain', 'my', 'stupid'],
#       dtype='<U62'), array(['about', 'being', 'brokeback', 'dads', 'mountain', 'my', 'stupid'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['harry', 'hate', 'potter'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['brokeback', 'horrible', 'is', 'mountain', 'movie', 'ok', 'such'],
#       dtype='<U62'), array(['harry', 'hate', 'potter'],
#       dtype='<U62'), array(['actual', 'and', 'for', 'given', 'impossible', 'mission', 'movie',
#        'on', 'other', 'our', 'realized', 'side', 'the', 'then', 'theyd',
#        'tickets', 'us', 'was', 'we', 'wrong'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'harry', 'if',
#        'is', 'potter', 'says'],
#       dtype='<U62'), array(['bitch', 'coz', 'down', 'goin', 'hella', 'hill', 'impossible',
#        'into', 'is', 'like', 'mission', 'reality', 'said', 'silent',
#        'that', 'turned', 'was', 'which', 'why'],
#       dtype='<U62'), array(['because', 'impossible', 'know', 'like', 'mission', 'movies',
#        'never', 'on', 'right', 'side', 'the', 'whos', 'you'],
#       dtype='<U62'), array(['and', 'blogbacklinksnippet', 'blogbacklinktitle', 'closet', 'come',
#        'impossible', 'making', 'mission', 'movies', 'of', 'out', 'please',
#        'stop', 'terrible', 'the', 'those'],
#       dtype='<U62'), array(['awful', 'brokeback', 'cow', 'emomound', 'goth', 'mountain', 'of',
#        'on', 'or', 'shatteredspine', 'shit', 'that', 'the', 'twist'],
#       dtype='<U62'), array(['as', 'code', 'da', 'desperately', 'film', 'lovethe', 'to', 'vinci',
#        'wanted'],
#       dtype='<U62'), array(['boring', 'brokeback', 'mountain', 'was'],
#       dtype='<U62'), array(['ass', 'code', 'da', 'major', 'sucks', 'vinci'],
#       dtype='<U62'), array(['and', 'appeals', 'arenas', 'bridget', 'chick', 'code', 'da', 'did',
#        'enjoy', 'explore', 'few', 'genre', 'has', 'idea', 'into', 'it',
#        'jones', 'lit', 'loved', 'me', 'of', 'one', 'so', 'takes', 'that',
#        'the', 'this', 'to', 'vinci', 'well', 'yet'],
#       dtype='<U62'), array(['beautiful', 'brokeback', 'mountain', 'was'],
#       dtype='<U62'), array(['code', 'da', 'down', 'left', 'right', 'suck', 'up', 'vinci'],
#       dtype='<U62'), array(['brokeback', 'loved', 'man', 'mountain'],
#       dtype='<U62'), array(['code', 'da', 'love', 'lubb', 'luv', 'the', 'vinci'],
#       dtype='<U62'), array(['and', 'being', 'bonkers', 'for', 'impossible', 'love', 'mission',
#        'sentry', 'station'],
#       dtype='<U62'), array(['and', 'be', 'because', 'but', 'fun', 'harry', 'here', 'is', 'it',
#        'love', 'much', 'people', 'place', 'potter', 'really', 'serious',
#        'so', 'still', 'take', 'to', 'want', 'where'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'harry', 'if',
#        'is', 'potter', 'says'],
#       dtype='<U62'), array(['and', 'code', 'da', 'friday', 'hung', 'kelsie', 'out', 'saw',
#        'sucked', 'the', 'vinci', 'we', 'went', 'with'],
#       dtype='<U62'), array(['and', 'black', 'gay', 'guy', 'harry', 'hate', 'its', 'one', 'only',
#        'potter', 'retarted', 'stupid', 'theres'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'vinci'],
#       dtype='<U62'), array(['and', 'code', 'combining', 'da', 'from', 'gary', 'gin', 'opinion',
#        'review', 'sucks', 'the', 'vinci', 'zen'],
#       dtype='<U62'), array(['are', 'code', 'da', 'how', 'it', 'know', 'love', 'much', 'people',
#        'the', 'vinci', 'who', 'worth'],
#       dtype='<U62'), array(['and', 'bye', 'harry', 'ok', 'potter', 'quiz', 'sucks', 'this'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['and', 'are', 'awesome', 'code', 'davinci', 'impossible', 'mission',
#        'the'],
#       dtype='<U62'), array(['impossible', 'mission', 'rocks'],
#       dtype='<U62'), array(['does', 'harry', 'is', 'it', 'just', 'me', 'or', 'potter', 'suck'],
#       dtype='<U62'), array(['brokeback', 'depressing', 'even', 'ever', 'is', 'most', 'mountain',
#        'movies', 'of', 'one', 'the', 'though'],
#       dtype='<U62'), array(['code', 'da', 'love', 'the', 'vinci'],
#       dtype='<U62'), array(['and', 'at', 'bobbypin', 'brokeback', 'cool', 'cowboy', 'hat',
#        'head', 'helped', 'insanely', 'jokes', 'laughed', 'me', 'mountain',
#        'my', 'she', 'stupid', 'to'],
#       dtype='<U62'), array(['about', 'being', 'brokeback', 'dads', 'mountain', 'my', 'stupid'],
#       dtype='<U62'), array(['and', 'be', 'because', 'but', 'fun', 'harry', 'here', 'is', 'it',
#        'love', 'much', 'people', 'place', 'potter', 'really', 'serious',
#        'so', 'still', 'take', 'to', 'want', 'where'],
#       dtype='<U62'), array(['again', 'am', 'awesome', 'because', 'going', 'harry', 'is', 'one',
#        'potter', 'reading', 'series', 'start', 'story', 'that', 'the', 'to'],
#       dtype='<U62'), array(['and', 'as', 'brokeback', 'horrible', 'just', 'luck', 'mountain',
#        'movies', 'my', 'such', 'watched', 'we'],
#       dtype='<U62'), array(['beautiful', 'brokeback', 'film', 'is', 'mountain'],
#       dtype='<U62'), array(['be', 'code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['code', 'da', 'hey', 'loved', 'the', 'vinci'],
#       dtype='<U62'), array(['and', 'being', 'bonkers', 'for', 'impossible', 'love', 'mission',
#        'sentry', 'station'],
#       dtype='<U62'), array(['actually', 'brokeback', 'mountain', 'movie', 'really', 'terrible',
#        'the', 'thursday', 'was', 'which'],
#       dtype='<U62'), array(['harry', 'movies', 'potter', 'really', 'suck', 'these'],
#       dtype='<U62'), array(['and', 'being', 'bonkers', 'for', 'impossible', 'love', 'mission',
#        'sentry', 'station'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['harry', 'movies', 'potter', 'really', 'suck', 'these'],
#       dtype='<U62'), array(['harry', 'like', 'potter', 'too'],
#       dtype='<U62'), array(['anyway', 'bout', 'ever', 'impossible', 'is', 'it', 'mission',
#        'most', 'movie', 'no', 'of', 'point', 'so', 'talkin', 'the',
#        'theres', 'worthless'],
#       dtype='<U62'), array(['brokeback', 'depressing', 'mountain', 'really', 'so', 'was'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['and', 'gun', 'however', 'impossible', 'love', 'mission', 'top'],
#       dtype='<U62'), array(['exciting', 'impossible', 'is', 'mission'],
#       dtype='<U62'), array(['25', 'code', 'da', 'heard', 'much', 'only', 'soo', 'stars',
#        'sucked', 'vinci'],
#       dtype='<U62'), array(['first', 'impossible', 'liked', 'mission', 'the'],
#       dtype='<U62'), array(['brokeback', 'dudeee', 'loved', 'mountain'],
#       dtype='<U62'), array(['by', 'code', 'da', 'just', 'know', 'letting', 'sucked', 'the',
#        'vinci', 'way', 'you'],
#       dtype='<U62'), array(['and', 'as', 'escapades', 'impossible', 'kate', 'kirsten', 'leah',
#        'love', 'mission', 'tom', 'well'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['also', 'as', 'book', 'can', 'catcher', 'count', 'eyre', 'harry',
#        'if', 'in', 'jane', 'love', 'potter', 'series', 'suicides', 'that',
#        'the', 'tye', 'virgin', 'yeah', 'you'],
#       dtype='<U62'), array(['after', 'awesome', 'fucking', 'impossible', 'is', 'mission',
#        'still', 'two', 'viewings'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'vinci'],
#       dtype='<U62'), array(['about', 'absurd', 'ban', 'book', 'classes', 'controversy',
#        'gaither', 'harry', 'in', 'is', 'marcia', 'possible', 'potter',
#        'react', 'says', 'teaches', 'the', 'to', 'who', 'wiccanism',
#        'wiccans'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'harry', 'if',
#        'is', 'potter', 'says'],
#       dtype='<U62'), array(['about', 'harry', 'it', 'love', 'much', 'not', 'potter', 'series',
#        'talk', 'the', 'though', 'to', 'too', 'try'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'harry', 'if',
#        'is', 'potter', 'says'],
#       dtype='<U62'), array(['and', 'deep', 'harry', 'is', 'love', 'of', 'one', 'potter',
#        'profound', 'story', 'the'],
#       dtype='<U62'), array(['and', 'as', 'cleaning', 'dash', 'felicia', 'felicias', 'freakin',
#        'grabs', 'impossible', 'is', 'keys', 'like', 'mission', 'mom', 'my',
#        'out', 'so', 'table', 'the', 'we'],
#       dtype='<U62'), array(['daniel', 'fucking', 'harry', 'hate', 'needs', 'potter', 'slap',
#        'that', 'wotshisface'],
#       dtype='<U62'), array(['brokeback', 'didnt', 'glad', 'im', 'mountain', 'stupid', 'that',
#        'win'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['brokeback', 'dudeee', 'loved', 'mountain'],
#       dtype='<U62'), array(['and', 'bye', 'harry', 'ok', 'potter', 'quiz', 'sucks', 'this'],
#       dtype='<U62'), array(['be', 'code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['awesome', 'brokeback', 'mountain', 'so', 'was'],
#       dtype='<U62'), array(['aching', 'and', 'around', 'blonds', 'cock', 'down', 'draco',
#        'dragged', 'groaning', 'harry', 'him', 'hips', 'his', 'into',
#        'making', 'malfoy', 'noises', 'panting', 'past', 'potter',
#        'rockhard', 'sucked', 'the', 'throat', 'trousers', 'vigor',
#        'whimpering', 'with'],
#       dtype='<U62'), array(['about', 'allegory', 'and', 'anything', 'are', 'bible', 'deluded',
#        'evil', 'far', 'go', 'harry', 'if', 'into', 'is', 'less', 'loose',
#        'my', 'of', 'people', 'potter', 'rant', 'than', 'the', 'these',
#        'they', 'think', 'too', 'why', 'wont'],
#       dtype='<U62'), array(['and', 'code', 'combining', 'da', 'from', 'gary', 'gin', 'opinion',
#        'review', 'sucks', 'the', 'vinci', 'zen'],
#       dtype='<U62'), array(['and', 'be', 'because', 'but', 'fun', 'harry', 'here', 'is', 'it',
#        'love', 'much', 'people', 'place', 'potter', 'really', 'serious',
#        'so', 'still', 'take', 'to', 'want', 'where'],
#       dtype='<U62'), array(['awesome', 'but', 'iii', 'impossible', 'is', 'mission'],
#       dtype='<U62'), array(['aching', 'and', 'around', 'blonds', 'cock', 'down', 'draco',
#        'dragged', 'groaning', 'harry', 'him', 'hips', 'his', 'into',
#        'making', 'malfoy', 'noises', 'panting', 'past', 'potter',
#        'rockhard', 'sucked', 'the', 'throat', 'trousers', 'vigor',
#        'whimpering', 'with'],
#       dtype='<U62'), array(['and', 'black', 'gay', 'guy', 'harry', 'hate', 'its', 'one', 'only',
#        'potter', 'retarted', 'stupid', 'theres'],
#       dtype='<U62'), array(['code', 'da', 'down', 'left', 'right', 'suck', 'up', 'vinci'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'harry', 'if',
#        'is', 'potter', 'says'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['brokeback', 'depressing', 'mountain', 'really', 'so', 'was'],
#       dtype='<U62'), array(['as', 'code', 'da', 'desperately', 'film', 'lovethe', 'to', 'vinci',
#        'wanted'],
#       dtype='<U62'), array(['and', 'being', 'bonkers', 'for', 'impossible', 'love', 'mission',
#        'sentry', 'station'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['and', 'be', 'grow', 'harry', 'him', 'ill', 'liked', 'potter',
#        'see', 'sorry', 'to', 'up'],
#       dtype='<U62'), array(['be', 'code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['because', 'impossible', 'know', 'like', 'mission', 'movies',
#        'never', 'on', 'right', 'side', 'the', 'whos', 'you'],
#       dtype='<U62'), array(['after', 'again', 'being', 'brokeback', 'clean', 'depressing',
#        'have', 'insurance', 'is', 'messy', 'mountain', 'out', 'room',
#        'runs', 'soon', 'still', 'the', 'though', 'van'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['brokeback', 'horrible', 'is', 'mountain', 'movie', 'ok', 'such'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['brokeback', 'dudeee', 'loved', 'mountain'],
#       dtype='<U62'), array(['an', 'awesome', 'brokeback', 'mountain', 'movie', 'was'],
#       dtype='<U62'), array(['25', 'code', 'da', 'heard', 'much', 'only', 'soo', 'stars',
#        'sucked', 'vinci'],
#       dtype='<U62'), array(['are', 'code', 'da', 'how', 'it', 'know', 'love', 'much', 'people',
#        'the', 'vinci', 'who', 'worth'],
#       dtype='<U62'), array(['acne', 'and', 'brokeback', 'got', 'hes', 'likeyeah', 'love',
#        'mountain'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['anyway', 'brokeback', 'love', 'mountain', 'thats', 'why'],
#       dtype='<U62'), array(['awesome', 'be', 'going', 'impossible', 'is', 'mission', 'so',
#        'this', 'to', 'year'],
#       dtype='<U62'), array(['because', 'impossible', 'know', 'like', 'mission', 'movies',
#        'never', 'on', 'right', 'side', 'the', 'whos', 'you'],
#       dtype='<U62'), array(['an', 'awesome', 'code', 'da', 'movie', 'vinci', 'was'],
#       dtype='<U62'), array(['first', 'impossible', 'liked', 'mission', 'the'],
#       dtype='<U62'), array(['code', 'da', 'love', 'the', 'vinci'],
#       dtype='<U62'), array(['beautiful', 'brokeback', 'mountain', 'was'],
#       dtype='<U62'), array(['code', 'da', 'down', 'left', 'right', 'suck', 'up', 'vinci'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['and', 'brokeback', 'is', 'mountain', 'movie', 'oh', 'terrible'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['and', 'be', 'because', 'community', 'friends', 'good', 'harry',
#        'joining', 'like', 'make', 'potter', 'really', 'same', 'so',
#        'start', 'that', 'the', 'things', 'this', 'thought', 'to', 'who',
#        'would'],
#       dtype='<U62'), array(['first', 'impossible', 'liked', 'mission', 'the'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['first', 'impossible', 'liked', 'mission', 'the'],
#       dtype='<U62'), array(['absolutely', 'already', 'as', 'can', 'harry', 'love', 'potter',
#        'tell', 'you'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['code', 'da', 'love', 'the', 'vinci'],
#       dtype='<U62'), array(['absolutely', 'awesome', 'code', 'da', 'the', 'vinci', 'was'],
#       dtype='<U62'), array(['harry', 'hate', 'potter'],
#       dtype='<U62'), array(['and', 'deep', 'harry', 'is', 'love', 'of', 'one', 'potter',
#        'profound', 'story', 'the'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['code', 'da', 'loved', 'the', 'vinci'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['beautiful', 'brokeback', 'is', 'mountain', 'movie'],
#       dtype='<U62'), array(['and', 'black', 'gay', 'guy', 'harry', 'hate', 'its', 'one', 'only',
#        'potter', 'retarted', 'stupid', 'theres'],
#       dtype='<U62'), array(['brokeback', 'loved', 'man', 'mountain'],
#       dtype='<U62'), array(['absolutely', 'an', 'awesome', 'iii', 'impossible', 'is', 'mission',
#        'movie', 'possum'],
#       dtype='<U62'), array(['brokeback', 'but', 'lousy', 'mountain', 'movie', 'really', 'was'],
#       dtype='<U62'), array(['again', 'am', 'awesome', 'because', 'going', 'harry', 'is', 'one',
#        'potter', 'reading', 'series', 'start', 'story', 'that', 'the', 'to'],
#       dtype='<U62'), array(['harry', 'movies', 'potter', 'really', 'suck', 'these'],
#       dtype='<U62'), array(['brokeback', 'loved', 'man', 'mountain'],
#       dtype='<U62'), array(['harry', 'movies', 'potter', 'really', 'suck', 'these'],
#       dtype='<U62'), array(['aching', 'and', 'around', 'blonds', 'cock', 'down', 'draco',
#        'dragged', 'groaning', 'harry', 'him', 'hips', 'his', 'into',
#        'making', 'malfoy', 'noises', 'panting', 'past', 'potter',
#        'rockhard', 'sucked', 'the', 'throat', 'trousers', 'vigor',
#        'whimpering', 'with'],
#       dtype='<U62'), array(['acne', 'and', 'brokeback', 'got', 'hes', 'likeyeah', 'love',
#        'mountain'],
#       dtype='<U62'), array(['and', 'bye', 'harry', 'ok', 'potter', 'quiz', 'sucks', 'this'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'harry', 'if',
#        'is', 'potter', 'says'],
#       dtype='<U62'), array(['and', 'because', 'case', 'dragons', 'eragons', 'harry', 'in',
#        'like', 'potter'],
#       dtype='<U62'), array(['brokeback', 'depressing', 'ever', 'have', 'into', 'is', 'most',
#        'mountain', 'movie', 'seen', 'snuck', 'the', 'then', 'which'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['an', 'awesome', 'code', 'da', 'movie', 'vinci', 'was'],
#       dtype='<U62'), array(['brokeback', 'for', 'just', 'mountain', 'movie', 'record',
#        'terrible', 'the', 'was'],
#       dtype='<U62'), array(['and', 'are', 'because', 'begin', 'better', 'harry', 'hate', 'it',
#        'just', 'material', 'movies', 'much', 'out', 'outshines', 'plain',
#        'potter', 'reading', 'stupid', 'the', 'there', 'think', 'to', 'with'],
#       dtype='<U62'), array(['harry', 'movies', 'potter', 'really', 'suck', 'these'],
#       dtype='<U62'), array(['back', 'harry', 'potter', 'want'],
#       dtype='<U62'), array(['brokeback', 'loved', 'man', 'mountain'],
#       dtype='<U62'), array(['also', 'and', 'before', 'book', 'come', 'enjoy', 'harry', 'movie',
#        'new', 'out', 'potter', 'really', 'rereading', 'right', 'series',
#        'the'],
#       dtype='<U62'), array(['brokeback', 'fucking', 'horrible', 'is', 'mountain'],
#       dtype='<U62'), array(['code', 'da', 'hoover', 'like', 'sucked', 'the', 'vinci'],
#       dtype='<U62'), array(['as', 'code', 'da', 'desperately', 'film', 'lovethe', 'to', 'vinci',
#        'wanted'],
#       dtype='<U62'), array(['brokeback', 'horrible', 'is', 'mountain', 'movie', 'ok', 'such'],
#       dtype='<U62'), array(['first', 'impossible', 'liked', 'mission', 'the'],
#       dtype='<U62'), array(['and', 'brokeback', 'mountain', 'movie', 'oh', 'terrible', 'was'],
#       dtype='<U62'), array(['and', 'be', 'because', 'community', 'friends', 'good', 'harry',
#        'joining', 'like', 'make', 'potter', 'really', 'same', 'so',
#        'start', 'that', 'the', 'things', 'this', 'thought', 'to', 'who',
#        'would'],
#       dtype='<U62'), array(['impossible', 'mission', 'rocks'],
#       dtype='<U62'), array(['and', 'be', 'because', 'but', 'fun', 'harry', 'here', 'is', 'it',
#        'love', 'much', 'people', 'place', 'potter', 'really', 'serious',
#        'so', 'still', 'take', 'to', 'want', 'where'],
#       dtype='<U62'), array(['code', 'da', 'down', 'left', 'right', 'suck', 'up', 'vinci'],
#       dtype='<U62'), array(['code', 'consumed', 'in', 'meat', 'new', 'over', 'placebroke',
#        'quick', 'smoked', 'suckedlove', 'the', 'updatehavent', 'vinci',
#        'weekda', 'weekhavent'],
#       dtype='<U62'), array(['code', 'da', 'love', 'the', 'vinci'],
#       dtype='<U62'), array(['first', 'impossible', 'liked', 'mission', 'the'],
#       dtype='<U62'), array(['25', 'code', 'da', 'heard', 'much', 'only', 'soo', 'stars',
#        'sucked', 'vinci'],
#       dtype='<U62'), array(['harry', 'like', 'potter', 'too'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'harry', 'hates', 'knows', 'not',
#        'potter', 'want', 'what'],
#       dtype='<U62'), array(['first', 'impossible', 'liked', 'mission', 'the'],
#       dtype='<U62'), array(['code', 'da', 'hear', 'sucks', 'the', 'vinci'],
#       dtype='<U62'), array(['and', 'awesome', 'both', 'impossible', 'last', 'mission', 'movies',
#        'stand', 'the', 'were'],
#       dtype='<U62'), array(['ass', 'code', 'da', 'kick', 'loved', 'movie', 'the', 'vinci', 'was'],
#       dtype='<U62'), array(['and', 'deep', 'harry', 'is', 'love', 'of', 'one', 'potter',
#        'profound', 'story', 'the'],
#       dtype='<U62'), array(['impossible', 'mission', 'sucked', 'three'],
#       dtype='<U62'), array(['does', 'harry', 'is', 'it', 'just', 'me', 'or', 'potter', 'suck'],
#       dtype='<U62'), array(['and', 'deep', 'harry', 'is', 'love', 'of', 'one', 'potter',
#        'profound', 'story', 'the'],
#       dtype='<U62'), array(['and', 'brokeback', 'mountain', 'movie', 'oh', 'terrible', 'was'],
#       dtype='<U62'), array(['beautiful', 'brokeback', 'mountain', 'was'],
#       dtype='<U62'), array(['brokeback', 'horrible', 'is', 'mountain', 'movie', 'ok', 'such'],
#       dtype='<U62'), array(['anatomy', 'and', 'both', 'greys', 'harry', 'love', 'potter', 'we'],
#       dtype='<U62'), array(['brokeback', 'horrible', 'is', 'mountain', 'movie', 'ok', 'such'],
#       dtype='<U62'), array(['impossible', 'mission', 'rocks'],
#       dtype='<U62'), array(['and', 'be', 'because', 'community', 'friends', 'good', 'harry',
#        'joining', 'like', 'make', 'potter', 'really', 'same', 'so',
#        'start', 'that', 'the', 'things', 'this', 'thought', 'to', 'who',
#        'would'],
#       dtype='<U62'), array(['absolutely', 'awesome', 'code', 'da', 'the', 'vinci', 'was'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'vinci'],
#       dtype='<U62'), array(['awesome', 'impossible', 'mission', 'note', 'on', 'side', 'was'],
#       dtype='<U62'), array(['impossible', 'mission', 'rocks'],
#       dtype='<U62'), array(['are', 'code', 'da', 'how', 'it', 'know', 'love', 'much', 'people',
#        'the', 'vinci', 'who', 'worth'],
#       dtype='<U62'), array(['but', 'code', 'da', 'go', 'id', 'love', 'next', 'not', 'probably',
#        'see', 'to', 'vinci', 'week'],
#       dtype='<U62'), array(['am', 'as', 'awards', 'brokeback', 'despised', 'here', 'how',
#        'mountain', 'movie', 'mtv', 'much', 'of', 'reminded', 'sit', 'the',
#        'watching'],
#       dtype='<U62'), array(['code', 'da', 'love', 'lubb', 'luv', 'the', 'vinci'],
#       dtype='<U62'), array(['big', 'code', 'da', 'sucked', 'the', 'time', 'vinci'],
#       dtype='<U62'), array(['and', 'deep', 'harry', 'is', 'love', 'of', 'one', 'potter',
#        'profound', 'story', 'the'],
#       dtype='<U62'), array(['bitch', 'coz', 'down', 'goin', 'hella', 'hill', 'impossible',
#        'into', 'is', 'like', 'mission', 'reality', 'said', 'silent',
#        'that', 'turned', 'was', 'which', 'why'],
#       dtype='<U62'), array(['first', 'impossible', 'liked', 'mission', 'the'],
#       dtype='<U62'), array(['and', 'are', 'at', 'big', 'books', 'decent', 'enough', 'glad',
#        'got', 'harry', 'kids', 'know', 'potter', 'reading', 'that', 'the',
#        'they', 'thick', 've', 'you'],
#       dtype='<U62'), array(['bitch', 'coz', 'down', 'goin', 'hella', 'hill', 'impossible',
#        'into', 'is', 'like', 'mission', 'reality', 'said', 'silent',
#        'that', 'turned', 'was', 'which', 'why'],
#       dtype='<U62'), array(['first', 'impossible', 'liked', 'mission', 'the'],
#       dtype='<U62'), array(['all', 'am', 'attached', 'awesome', 'be', 'better', 'catch',
#        'clarksville', 'do', 'have', 'ill', 'impossible', 'in', 'mission',
#        'most', 'movies', 'nothing', 'of', 'pretty', 'since', 'summer',
#        'sure', 'the', 'to', 'trailers', 'were', 'which', 'will'],
#       dtype='<U62'), array(['because', 'impossible', 'know', 'like', 'mission', 'movies',
#        'never', 'on', 'right', 'side', 'the', 'whos', 'you'],
#       dtype='<U62'), array(['code', 'da', 'love', 'the', 'vinci'],
#       dtype='<U62'), array(['and', 'deep', 'harry', 'is', 'love', 'of', 'one', 'potter',
#        'profound', 'story', 'the'],
#       dtype='<U62'), array(['and', 'be', 'because', 'community', 'friends', 'good', 'harry',
#        'joining', 'like', 'make', 'potter', 'really', 'same', 'so',
#        'start', 'that', 'the', 'things', 'this', 'thought', 'to', 'who',
#        'would'],
#       dtype='<U62'), array(['bitch', 'coz', 'down', 'goin', 'hella', 'hill', 'impossible',
#        'into', 'is', 'like', 'mission', 'reality', 'said', 'silent',
#        'that', 'turned', 'was', 'which', 'why'],
#       dtype='<U62'), array(['code', 'da', 'love', 'the', 'vinci'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'brokeback', 'either', 'great',
#        'homosexuality', 'is', 'its', 'love', 'more', 'mountain', 'or',
#        'that', 'think'],
#       dtype='<U62'), array(['and', 'as', 'cleaning', 'dash', 'felicia', 'felicias', 'freakin',
#        'grabs', 'impossible', 'is', 'keys', 'like', 'mission', 'mom', 'my',
#        'out', 'so', 'table', 'the', 'we'],
#       dtype='<U62'), array(['be', 'code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['because', 'impossible', 'know', 'like', 'mission', 'movies',
#        'never', 'on', 'right', 'side', 'the', 'whos', 'you'],
#       dtype='<U62'), array(['daniel', 'fucking', 'harry', 'hate', 'needs', 'potter', 'slap',
#        'that', 'wotshisface'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['and', 'brokeback', 'mountain', 'movie', 'oh', 'terrible', 'was'],
#       dtype='<U62'), array(['enjoy', 'harry', 'potter', 'reading'],
#       dtype='<U62'), array(['harry', 'movies', 'potter', 'really', 'suck', 'these'],
#       dtype='<U62'), array(['brokeback', 'fucking', 'horrible', 'is', 'mountain'],
#       dtype='<U62'), array(['and', 'bye', 'harry', 'ok', 'potter', 'quiz', 'sucks', 'this'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'the', 'vinci'],
#       dtype='<U62'), array(['boring', 'brokeback', 'mountain', 'was'],
#       dtype='<U62'), array(['harry', 'like', 'potter', 'too'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'harry', 'hates', 'knows', 'not',
#        'potter', 'want', 'what'],
#       dtype='<U62'), array(['an', 'awesome', 'code', 'da', 'movie', 'vinci', 'was'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['code', 'da', 'down', 'left', 'right', 'suck', 'up', 'vinci'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['about', 'ass', 'hear', 'how', 'if', 'iii', 'impossible', 'mission',
#        'more', 'much', 'one', 'or', 'sucks', 'thing', 'tomkat'],
#       dtype='<U62'), array(['beautiful', 'brokeback', 'mountain', 'was'],
#       dtype='<U62'), array(['and', 'as', 'cleaning', 'dash', 'felicia', 'felicias', 'freakin',
#        'grabs', 'impossible', 'is', 'keys', 'like', 'mission', 'mom', 'my',
#        'out', 'so', 'table', 'the', 'we'],
#       dtype='<U62'), array(['actors', 'at', 'boring', 'brokeback', 'cute', 'had', 'least',
#        'mountain', 'one', 'show', 'super', 'the', 'they', 'was', 'well'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['first', 'impossible', 'liked', 'mission', 'the'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['does', 'harry', 'is', 'it', 'just', 'me', 'or', 'potter', 'suck'],
#       dtype='<U62'), array(['an', 'and', 'awesome', 'bro', 'daddy', 'did', 'exelent', 'first',
#        'for', 'game', 'got', 'had', 'he', 'impossible', 'in', 'jamie',
#        'job', 'lil', 'mission', 'my', 'she', 'so', 'speaker', 'ten', 'the',
#        'ticket', 'tied', 'was', 'with'],
#       dtype='<U62'), array(['brokeback', 'fucking', 'horrible', 'is', 'mountain'],
#       dtype='<U62'), array(['an', 'awesome', 'characterization', 'effects', 'film', 'great',
#        'impossible', 'mission', 'the', 'was', 'were'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'the', 'vinci'],
#       dtype='<U62'), array(['code', 'da', 'love', 'the', 'vinci'],
#       dtype='<U62'), array(['by', 'code', 'da', 'just', 'know', 'letting', 'sucked', 'the',
#        'vinci', 'way', 'you'],
#       dtype='<U62'), array(['gonna', 'hoot', 'impossible', 'like', 'mission', 'or', 'watch',
#        'were'],
#       dtype='<U62'), array(['absolutely', 'awesome', 'code', 'da', 'the', 'vinci', 'was'],
#       dtype='<U62'), array(['because', 'impossible', 'know', 'like', 'mission', 'movies',
#        'never', 'on', 'right', 'side', 'the', 'whos', 'you'],
#       dtype='<U62'), array(['enjoyed', 'good', 'harry', 'potter', 'sawyer', 'suppose', 'tom',
#        'too', 'was'],
#       dtype='<U62'), array(['brokeback', 'depressing', 'mountain', 'really', 'so', 'was'],
#       dtype='<U62'), array(['and', 'code', 'da', 'friday', 'hung', 'kelsie', 'out', 'saw',
#        'sucked', 'the', 'vinci', 'we', 'went', 'with'],
#       dtype='<U62'), array(['am', 'because', 'but', 'character', 'dies', 'harry', 'hate', 'it',
#        'likes', 'main', 'not', 'of', 'person', 'potter', 'that', 'the',
#        'type', 'when'],
#       dtype='<U62'), array(['be', 'code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['brokeback', 'depressing', 'ever', 'have', 'into', 'is', 'most',
#        'mountain', 'movie', 'seen', 'snuck', 'the', 'then', 'which'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'harry', 'if',
#        'is', 'potter', 'says'],
#       dtype='<U62'), array(['and', 'awesome', 'code', 'da', 'far', 'is', 'so', 'that', 'the',
#        'vinci'],
#       dtype='<U62'), array(['and', 'bye', 'harry', 'ok', 'potter', 'quiz', 'sucks', 'this'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['and', 'brokeback', 'is', 'mountain', 'movie', 'oh', 'terrible'],
#       dtype='<U62'), array(['awesome', 'cant', 'code', 'da', 'it', 'read', 'the', 'to', 'vinci',
#        'wait', 'was'],
#       dtype='<U62'), array(['aching', 'and', 'around', 'blonds', 'cock', 'down', 'draco',
#        'dragged', 'groaning', 'harry', 'him', 'hips', 'his', 'into',
#        'making', 'malfoy', 'noises', 'panting', 'past', 'potter',
#        'rockhard', 'sucked', 'the', 'throat', 'trousers', 'vigor',
#        'whimpering', 'with'],
#       dtype='<U62'), array(['finally', 'for', 'freakin', 'hahaha', 'impossible', 'is',
#        'mission', 'my', 'over', 'search', 'shoes', 'stupid', 'think',
#        'those'],
#       dtype='<U62'), array(['impossible', 'mission', 'rocks'],
#       dtype='<U62'), array(['and', 'awesome', 'both', 'impossible', 'last', 'mission', 'movies',
#        'stand', 'the', 'were'],
#       dtype='<U62'), array(['also', 'impossible', 'liked', 'mission'],
#       dtype='<U62'), array(['awesome', 'harry', 'is', 'potter'],
#       dtype='<U62'), array(['absurd', 'are', 'but', 'code', 'da', 'it', 'lot', 'loved', 'most',
#        'of', 'questions', 'raises', 'the', 'theological', 'very', 'vinci',
#        'which'],
#       dtype='<U62'), array(['harry', 'movies', 'potter', 'really', 'suck', 'these'],
#       dtype='<U62'), array(['anyway', 'brokeback', 'love', 'mountain', 'thats', 'why'],
#       dtype='<U62'), array(['am', 'as', 'awards', 'brokeback', 'despised', 'here', 'how',
#        'mountain', 'movie', 'mtv', 'much', 'of', 'reminded', 'sit', 'the',
#        'watching'],
#       dtype='<U62'), array(['and', 'harry', 'like', 'potter'],
#       dtype='<U62'), array(['does', 'harry', 'is', 'it', 'just', 'me', 'or', 'potter', 'suck'],
#       dtype='<U62'), array(['code', 'da', 'love', 'lubb', 'luv', 'the', 'vinci'],
#       dtype='<U62'), array(['daniel', 'fucking', 'harry', 'hate', 'needs', 'potter', 'slap',
#        'that', 'wotshisface'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['harry', 'hate', 'potter'],
#       dtype='<U62'), array(['big', 'code', 'da', 'sucked', 'the', 'time', 'vinci'],
#       dtype='<U62'), array(['and', 'bye', 'harry', 'ok', 'potter', 'quiz', 'sucks', 'this'],
#       dtype='<U62'), array(['code', 'da', 'heard', 'sucked', 'the', 'vinci'],
#       dtype='<U62'), array(['and', 'code', 'da', 'friday', 'hung', 'kelsie', 'out', 'saw',
#        'sucked', 'the', 'vinci', 'we', 'went', 'with'],
#       dtype='<U62'), array(['acne', 'and', 'brokeback', 'got', 'hes', 'likeyeah', 'love',
#        'mountain'],
#       dtype='<U62'), array(['because', 'impossible', 'know', 'like', 'mission', 'movies',
#        'never', 'on', 'right', 'side', 'the', 'whos', 'you'],
#       dtype='<U62'), array(['bad', 'because', 'doing', 'feel', 'films', 'go', 'hate', 'his',
#        'im', 'impossible', 'in', 'it', 'like', 'mission', 'money',
#        'pocket', 'putting', 'really', 'see', 'since', 'so', 'that',
#        'theater', 'them', 'though', 'when'],
#       dtype='<U62'), array(['bitch', 'coz', 'down', 'goin', 'hella', 'hill', 'impossible',
#        'into', 'is', 'like', 'mission', 'reality', 'said', 'silent',
#        'that', 'turned', 'was', 'which', 'why'],
#       dtype='<U62'), array(['afterwards', 'and', 'ashamed', 'beautiful', 'brokeback', 'film',
#        'five', 'for', 'full', 'im', 'minutes', 'mountain', 'say', 'see',
#        'to', 'truly', 'was', 'we', 'went', 'wept', 'which'],
#       dtype='<U62'), array(['brokeback', 'horrible', 'is', 'mountain', 'movie', 'ok', 'such'],
#       dtype='<U62'), array(['code', 'da', 'sucked', 'vinci'],
#       dtype='<U62'), array(['and', 'are', 'because', 'begin', 'better', 'harry', 'hate', 'it',
#        'just', 'material', 'movies', 'much', 'out', 'outshines', 'plain',
#        'potter', 'reading', 'stupid', 'the', 'there', 'think', 'to', 'with'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['an', 'awesome', 'code', 'da', 'movie', 'vinci', 'was'],
#       dtype='<U62'), array(['absolutely', 'awesome', 'code', 'da', 'the', 'vinci', 'was'],
#       dtype='<U62'), array(['code', 'da', 'love', 'the', 'vinci'],
#       dtype='<U62'), array(['brokeback', 'liked', 'mountain', 'really', 'so'],
#       dtype='<U62'), array(['brokeback', 'mountain', 'sucked'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'brokeback', 'either', 'great',
#        'homosexuality', 'is', 'its', 'love', 'more', 'mountain', 'or',
#        'that', 'think'],
#       dtype='<U62'), array(['700', 'again', 'and', 'code', 'da', 'is', 'it', 'like', 'made',
#        'million', 'movie', 'shitty', 'super', 'the', 'then', 'vinci'],
#       dtype='<U62'), array(['an', 'awesome', 'code', 'da', 'movie', 'vinci', 'was'],
#       dtype='<U62'), array(['because', 'impossible', 'know', 'like', 'mission', 'movies',
#        'never', 'on', 'right', 'side', 'the', 'whos', 'you'],
#       dtype='<U62'), array(['beautiful', 'brokeback', 'carefully', 'done', 'is', 'mountain',
#        'movie', 'that'],
#       dtype='<U62'), array(['and', 'deep', 'harry', 'is', 'love', 'of', 'one', 'potter',
#        'profound', 'story', 'the'],
#       dtype='<U62'), array(['brokeback', 'depressing', 'mountain', 'really', 'so', 'was'],
#       dtype='<U62'), array(['harry', 'hate', 'potter'],
#       dtype='<U62'), array(['code', 'da', 'gasp', 'love', 'the', 'vinci'],
#       dtype='<U62'), array(['btw', 'code', 'da', 'sucks', 'the', 'vinci'],
#       dtype='<U62'), array(['brokeback', 'horrible', 'is', 'mountain', 'movie', 'ok', 'such'],
#       dtype='<U62'), array(['brokeback', 'fucking', 'horrible', 'is', 'mountain'],
#       dtype='<U62'), array(['and', 'code', 'combining', 'da', 'from', 'gary', 'gin', 'opinion',
#        'review', 'sucks', 'the', 'vinci', 'zen'],
#       dtype='<U62'), array(['and', 'brokeback', 'is', 'mountain', 'movie', 'oh', 'terrible'],
#       dtype='<U62'), array(['first', 'impossible', 'liked', 'mission', 'the'],
#       dtype='<U62'), array(['about', 'being', 'brokeback', 'dads', 'mountain', 'my', 'stupid'],
#       dtype='<U62'), array(['because', 'impossible', 'know', 'like', 'mission', 'movies',
#        'never', 'on', 'right', 'side', 'the', 'whos', 'you'],
#       dtype='<U62'), array(['an', 'awesome', 'brokeback', 'mountain', 'movie', 'was'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['and', 'as', 'escapades', 'impossible', 'kate', 'kirsten', 'leah',
#        'love', 'mission', 'tom', 'well'],
#       dtype='<U62'), array(['brokeback', 'horrible', 'is', 'mountain', 'movie', 'ok', 'such'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'vinci'],
#       dtype='<U62'), array(['brokeback', 'depressing', 'id', 'is', 'just', 'like', 'mountain',
#        'movie', 'say', 'that', 'to', 'very'],
#       dtype='<U62'), array(['and', 'being', 'bonkers', 'for', 'impossible', 'love', 'mission',
#        'sentry', 'station'],
#       dtype='<U62'), array(['and', 'as', 'cleaning', 'dash', 'felicia', 'felicias', 'freakin',
#        'grabs', 'impossible', 'is', 'keys', 'like', 'mission', 'mom', 'my',
#        'out', 'so', 'table', 'the', 'we'],
#       dtype='<U62'), array(['and', 'being', 'bonkers', 'for', 'impossible', 'love', 'mission',
#        'sentry', 'station'],
#       dtype='<U62'), array(['as', 'cock', 'exquisite', 'felt', 'had', 'harry', 'having', 'his',
#        'nearly', 'none', 'of', 'potter', 'still', 'sucking', 'that'],
#       dtype='<U62'), array(['and', 'as', 'escapades', 'impossible', 'kate', 'kirsten', 'leah',
#        'love', 'mission', 'tom', 'well'],
#       dtype='<U62'), array(['anyway', 'brokeback', 'love', 'mountain', 'thats', 'why'],
#       dtype='<U62'), array(['because', 'impossible', 'know', 'like', 'mission', 'movies',
#        'never', 'on', 'right', 'side', 'the', 'whos', 'you'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['boring', 'impossible', 'mission', 'quite', 'was'],
#       dtype='<U62'), array(['an', 'awesome', 'brokeback', 'mountain', 'movie', 'was'],
#       dtype='<U62'), array(['daniel', 'fucking', 'harry', 'hate', 'needs', 'potter', 'slap',
#        'that', 'wotshisface'],
#       dtype='<U62'), array(['does', 'harry', 'is', 'it', 'just', 'me', 'or', 'potter', 'suck'],
#       dtype='<U62'), array(['code', 'da', 'sucked', 'vinci'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'harry', 'if',
#        'is', 'potter', 'says'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['and', 'awesome', 'both', 'impossible', 'last', 'mission', 'movies',
#        'stand', 'the', 'were'],
#       dtype='<U62'), array(['big', 'code', 'da', 'sucked', 'the', 'time', 'vinci'],
#       dtype='<U62'), array(['awesome', 'cant', 'code', 'da', 'it', 'read', 'the', 'to', 'vinci',
#        'wait', 'was'],
#       dtype='<U62'), array(['after', 'asleep', 'big', 'brokeback', 'cold', 'fell', 'freezing',
#        'its', 'mountain', 'nearly', 'sucks', 'the', 'there', 'time', 'up',
#        'watching', 'which'],
#       dtype='<U62'), array(['does', 'harry', 'is', 'it', 'just', 'me', 'or', 'potter', 'suck'],
#       dtype='<U62'), array(['excellent', 'impossible', 'mission', 'was'],
#       dtype='<U62'), array(['and', 'are', 'because', 'begin', 'better', 'harry', 'hate', 'it',
#        'just', 'material', 'movies', 'much', 'out', 'outshines', 'plain',
# ...
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'vinci'],
#       dtype='<U62'), array(['and', 'bye', 'harry', 'ok', 'potter', 'quiz', 'sucks', 'this'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['coloured', 'harry', 'love', 'potter', 'too', 'your'],
#       dtype='<U62'), array(['brokeback', 'horrible', 'is', 'mountain', 'movie', 'ok', 'such'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'brokeback', 'either', 'great',
#        'homosexuality', 'is', 'its', 'love', 'more', 'mountain', 'or',
#        'that', 'think'],
#       dtype='<U62'), array(['and', 'deep', 'harry', 'is', 'love', 'of', 'one', 'potter',
#        'profound', 'story', 'the'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['boring', 'impossible', 'is', 'mission', 'so'],
#       dtype='<U62'), array(['beautiful', 'brokeback', 'is', 'mountain'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'harry', 'if',
#        'is', 'potter', 'says'],
#       dtype='<U62'), array(['crap', 'holy', 'impossible', 'loved', 'mission'],
#       dtype='<U62'), array(['code', 'da', 'love', 'lubb', 'luv', 'the', 'vinci'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['and', 'awesome', 'both', 'impossible', 'last', 'mission', 'movies',
#        'stand', 'the', 'were'],
#       dtype='<U62'), array(['awesome', 'cant', 'code', 'da', 'it', 'read', 'the', 'to', 'vinci',
#        'wait', 'was'],
#       dtype='<U62'), array(['and', 'black', 'gay', 'guy', 'harry', 'hate', 'its', 'one', 'only',
#        'potter', 'retarted', 'stupid', 'theres'],
#       dtype='<U62'), array(['again', 'am', 'awesome', 'because', 'going', 'harry', 'is', 'one',
#        'potter', 'reading', 'series', 'start', 'story', 'that', 'the', 'to'],
#       dtype='<U62'), array(['am', 'as', 'awards', 'brokeback', 'despised', 'here', 'how',
#        'mountain', 'movie', 'mtv', 'much', 'of', 'reminded', 'sit', 'the',
#        'watching'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['and', 'beautiful', 'beyond', 'code', 'course', 'da', 'deals',
#        'inspired', 'is', 'it', 'novel', 'of', 'that', 'the', 'tome',
#        'unauthorized', 'vinci', 'what', 'with'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['and', 'brokeback', 'is', 'mountain', 'movie', 'oh', 'terrible'],
#       dtype='<U62'), array(['again', 'am', 'awesome', 'because', 'going', 'harry', 'is', 'one',
#        'potter', 'reading', 'series', 'start', 'story', 'that', 'the', 'to'],
#       dtype='<U62'), array(['and', 'be', 'because', 'but', 'fun', 'harry', 'here', 'is', 'it',
#        'love', 'much', 'people', 'place', 'potter', 'really', 'serious',
#        'so', 'still', 'take', 'to', 'want', 'where'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['7th', 'deciding', 'go', 'harry', 'how', 'potter', 'the', 'to',
#        'want'],
#       dtype='<U62'), array(['excellent', 'impossible', 'mission', 'was'],
#       dtype='<U62'), array(['impossible', 'mission', 'rocks'],
#       dtype='<U62'), array(['anyways', 'but', 'dont', 'funny', 'harry', 'how', 'is', 'pic',
#        'potter', 'sucks', 'that', 'understand'],
#       dtype='<U62'), array(['and', 'brokeback', 'is', 'mountain', 'movie', 'oh', 'terrible'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'brokeback', 'either', 'great',
#        'homosexuality', 'is', 'its', 'love', 'more', 'mountain', 'or',
#        'that', 'think'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'the', 'vinci'],
#       dtype='<U62'), array(['awesome', 'harry', 'is', 'picture', 'potter', 'the'],
#       dtype='<U62'), array(['and', 'code', 'combining', 'da', 'from', 'gary', 'gin', 'opinion',
#        'review', 'sucks', 'the', 'vinci', 'zen'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'the', 'vinci'],
#       dtype='<U62'), array(['and', 'black', 'gay', 'guy', 'harry', 'hate', 'its', 'one', 'only',
#        'potter', 'retarted', 'stupid', 'theres'],
#       dtype='<U62'), array(['aaa', 'feeel', 'like', 'reetard'],
#       dtype='<U62'), array(['bad', 'because', 'code', 'da', 'hard', 'heard', 'howard', 'is',
#        'like', 'pretty', 'ron', 'sucked', 'too', 'vinci', 'which'],
#       dtype='<U62'), array(['code', 'da', 'sucked', 'vinci'],
#       dtype='<U62'), array(['awesome', 'book', 'code', 'da', 'is', 'just', 'the', 'vinci'],
#       dtype='<U62'), array(['am', 'as', 'awards', 'brokeback', 'despised', 'here', 'how',
#        'mountain', 'movie', 'mtv', 'much', 'of', 'reminded', 'sit', 'the',
#        'watching'],
#       dtype='<U62'), array(['by', 'code', 'da', 'just', 'know', 'letting', 'sucked', 'the',
#        'vinci', 'way', 'you'],
#       dtype='<U62'), array(['already', 'impossible', 'loved', 'mission', 'movies', 'the'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['25', 'code', 'da', 'heard', 'much', 'only', 'soo', 'stars',
#        'sucked', 'vinci'],
#       dtype='<U62'), array(['acne', 'and', 'brokeback', 'got', 'hes', 'likeyeah', 'love',
#        'mountain'],
#       dtype='<U62'), array(['again', 'am', 'awesome', 'because', 'going', 'harry', 'is', 'one',
#        'potter', 'reading', 'series', 'start', 'story', 'that', 'the', 'to'],
#       dtype='<U62'), array(['am', 'because', 'but', 'character', 'dies', 'harry', 'hate', 'it',
#        'likes', 'main', 'not', 'of', 'person', 'potter', 'that', 'the',
#        'type', 'when'],
#       dtype='<U62'), array(['and', 'at', 'bobbypin', 'brokeback', 'cool', 'cowboy', 'hat',
#        'head', 'helped', 'insanely', 'jokes', 'laughed', 'me', 'mountain',
#        'my', 'she', 'stupid', 'to'],
#       dtype='<U62'), array(['and', 'friends', 'harry', 'love', 'making', 'potter'],
#       dtype='<U62'), array(['because', 'impossible', 'know', 'like', 'mission', 'movies',
#        'never', 'on', 'right', 'side', 'the', 'whos', 'you'],
#       dtype='<U62'), array(['as', 'clickfive', 'harry', 'hate', 'love', 'much', 'potter'],
#       dtype='<U62'), array(['gonna', 'hoot', 'impossible', 'like', 'mission', 'or', 'watch',
#        'were'],
#       dtype='<U62'), array(['am', 'because', 'but', 'character', 'dies', 'harry', 'hate', 'it',
#        'likes', 'main', 'not', 'of', 'person', 'potter', 'that', 'the',
#        'type', 'when'],
#       dtype='<U62'), array(['am', 'as', 'awards', 'brokeback', 'despised', 'here', 'how',
#        'mountain', 'movie', 'mtv', 'much', 'of', 'reminded', 'sit', 'the',
#        'watching'],
#       dtype='<U62'), array(['and', 'awesome', 'both', 'impossible', 'last', 'mission', 'movies',
#        'stand', 'the', 'were'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['code', 'da', 'saw', 'sucked', 'vinci', 'we', 'which'],
#       dtype='<U62'), array(['and', 'first', 'hated', 'iii', 'impossible', 'mission', 'never',
#        'one', 'saw', 'second', 'the'],
#       dtype='<U62'), array(['awesome', 'baby', 'iii', 'impossible', 'it', 'mission', 'pretty',
#        'was', 'watched', 'with'],
#       dtype='<U62'), array(['code', 'da', 'down', 'left', 'right', 'suck', 'up', 'vinci'],
#       dtype='<U62'), array(['boycott', 'cruise', 'evil', 'impossibletom', 'is', 'mission'],
#       dtype='<U62'), array(['code', 'da', 'sucked', 'thirdlythe', 'vinci'],
#       dtype='<U62'), array(['code', 'da', 'down', 'left', 'right', 'suck', 'up', 'vinci'],
#       dtype='<U62'), array(['boring', 'brokeback', 'mountain', 'was'],
#       dtype='<U62'), array(['and', 'black', 'gay', 'guy', 'harry', 'hate', 'its', 'one', 'only',
#        'potter', 'retarted', 'stupid', 'theres'],
#       dtype='<U62'), array(['by', 'code', 'da', 'just', 'know', 'letting', 'sucked', 'the',
#        'vinci', 'way', 'you'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['286', 'awesome', 'book', 'but', 'code', 'course', 'da', 'figure',
#        'is', 'of', 'on', 'out', 'page', 'that', 'vinci', 'will', 'you'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['afterschool', 'and', 'at', 'ate', 'awesome', 'emily', 'finished',
#        'for', 'iii', 'impossible', 'it', 'margaritas', 'mission', 'my',
#        'relaxed', 'tests', 'then', 'to', 'up', 'was', 'watch', 'we',
#        'went', 'which', 'while'],
#       dtype='<U62'), array(['code', 'da', 'hate', 'really', 'the', 'vinci'],
#       dtype='<U62'), array(['am', 'because', 'but', 'character', 'dies', 'harry', 'hate', 'it',
#        'likes', 'main', 'not', 'of', 'person', 'potter', 'that', 'the',
#        'type', 'when'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['awesome', 'harry', 'potters'],
#       dtype='<U62'), array(['boring', 'brokeback', 'mountain', 'was'],
#       dtype='<U62'), array(['and', 'awesome', 'both', 'impossible', 'last', 'mission', 'movies',
#        'stand', 'the', 'were'],
#       dtype='<U62'), array(['and', 'at', 'bobbypin', 'brokeback', 'cool', 'cowboy', 'hat',
#        'head', 'helped', 'insanely', 'jokes', 'laughed', 'me', 'mountain',
#        'my', 'she', 'stupid', 'to'],
#       dtype='<U62'), array(['beautiful', 'brokeback', 'mountain', 'was'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['big', 'code', 'da', 'sucked', 'the', 'time', 'vinci'],
#       dtype='<U62'), array(['and', 'as', 'escapades', 'impossible', 'kate', 'kirsten', 'leah',
#        'love', 'mission', 'tom', 'well'],
#       dtype='<U62'), array(['around', 'brokeback', 'depressing', 'is', 'just', 'mountain',
#        'saw', 'second', 'the', 'then', 'time', 'we', 'which'],
#       dtype='<U62'), array(['because', 'impossible', 'know', 'like', 'mission', 'movies',
#        'never', 'on', 'right', 'side', 'the', 'whos', 'you'],
#       dtype='<U62'), array(['bitch', 'coz', 'down', 'goin', 'hella', 'hill', 'impossible',
#        'into', 'is', 'like', 'mission', 'reality', 'said', 'silent',
#        'that', 'turned', 'was', 'which', 'why'],
#       dtype='<U62'), array(['an', 'awesome', 'code', 'da', 'movie', 'vinci', 'was'],
#       dtype='<U62'), array(['code', 'da', 'down', 'left', 'right', 'suck', 'up', 'vinci'],
#       dtype='<U62'), array(['and', 'be', 'because', 'community', 'friends', 'good', 'harry',
#        'joining', 'like', 'make', 'potter', 'really', 'same', 'so',
#        'start', 'that', 'the', 'things', 'this', 'thought', 'to', 'who',
#        'would'],
#       dtype='<U62'), array(['acne', 'and', 'brokeback', 'got', 'hes', 'likeyeah', 'love',
#        'mountain'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'the', 'vinci'],
#       dtype='<U62'), array(['harry', 'like', 'potter', 'too'],
#       dtype='<U62'), array(['book', 'code', 'compared', 'da', 'especially', 'heard', 'sucks',
#        'that', 'the', 'to', 'vinci'],
#       dtype='<U62'), array(['beautiful', 'brokeback', 'film', 'is', 'mountain'],
#       dtype='<U62'), array(['and', 'brokeback', 'mountain', 'movie', 'oh', 'terrible', 'was'],
#       dtype='<U62'), array(['bookda', 'code', 'luv', 'the', 'vinci'],
#       dtype='<U62'), array(['harry', 'hate', 'potter'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'the', 'vinci'],
#       dtype='<U62'), array(['and', 'being', 'bonkers', 'for', 'impossible', 'love', 'mission',
#        'sentry', 'station'],
#       dtype='<U62'), array(['about', 'being', 'brokeback', 'dads', 'mountain', 'my', 'stupid'],
#       dtype='<U62'), array(['by', 'code', 'da', 'just', 'know', 'letting', 'sucked', 'the',
#        'vinci', 'way', 'you'],
#       dtype='<U62'), array(['harry', 'love', 'potter'],
#       dtype='<U62'), array(['am', 'because', 'but', 'character', 'dies', 'harry', 'hate', 'it',
#        'likes', 'main', 'not', 'of', 'person', 'potter', 'that', 'the',
#        'type', 'when'],
#       dtype='<U62'), array(['and', 'brokeback', 'mountain', 'movie', 'oh', 'terrible', 'was'],
#       dtype='<U62'), array(['and', 'awesome', 'both', 'impossible', 'last', 'mission', 'movies',
#        'stand', 'the', 'were'],
#       dtype='<U62'), array(['an', 'awesome', 'impossible', 'mission', 'movie', 'was'],
#       dtype='<U62'), array(['and', 'deep', 'harry', 'is', 'love', 'of', 'one', 'potter',
#        'profound', 'story', 'the'],
#       dtype='<U62'), array(['anyway', 'brokeback', 'love', 'mountain', 'thats', 'why'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'vinci'],
#       dtype='<U62'), array(['impossible', 'mission', 'rocks'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'is', 'vinci'],
#       dtype='<U62'), array(['brokeback', 'depressing', 'mountain', 'was'],
#       dtype='<U62'), array(['aching', 'and', 'around', 'blonds', 'cock', 'down', 'draco',
#        'dragged', 'groaning', 'harry', 'him', 'hips', 'his', 'into',
#        'making', 'malfoy', 'noises', 'panting', 'past', 'potter',
#        'rockhard', 'sucked', 'the', 'throat', 'trousers', 'vigor',
#        'whimpering', 'with'],
#       dtype='<U62'), array(['bitch', 'coz', 'down', 'goin', 'hella', 'hill', 'impossible',
#        'into', 'is', 'like', 'mission', 'reality', 'said', 'silent',
#        'that', 'turned', 'was', 'which', 'why'],
#       dtype='<U62'), array(['code', 'da', 'hoover', 'like', 'sucked', 'the', 'vinci'],
#       dtype='<U62'), array(['an', 'awesome', 'code', 'da', 'movie', 'vinci', 'was'],
#       dtype='<U62'), array(['and', 'awesome', 'bday', 'impossible', 'just', 'little', 'mission',
#        'party', 'saw', 'so', 'to', 'vics', 'was', 'went', 'which'],
#       dtype='<U62'), array(['be', 'cool', 'harry', 'potter', 'scar', 'the', 'would'],
#       dtype='<U62'), array(['about', 'being', 'brokeback', 'dads', 'mountain', 'my', 'stupid'],
#       dtype='<U62'), array(['books', 'cant', 'for', 'hairy', 'harry', 'is', 'it', 'otters',
#        'potter', 'read', 'real', 'sucks', 'the', 'who', 'wussies'],
#       dtype='<U62'), array(['and', 'be', 'because', 'but', 'fun', 'harry', 'here', 'is', 'it',
#        'love', 'much', 'people', 'place', 'potter', 'really', 'serious',
#        'so', 'still', 'take', 'to', 'want', 'where'],
#       dtype='<U62'), array(['awesome', 'cant', 'code', 'da', 'it', 'read', 'the', 'to', 'vinci',
#        'wait', 'was'],
#       dtype='<U62'), array(['awesome', 'code', 'da', 'the', 'vinci', 'was'],
#       dtype='<U62'), array(['code', 'da', 'sucks', 'vinci'],
#       dtype='<U62'), array(['brokeback', 'love', 'mountain'],
#       dtype='<U62'), array(['awesome', 'have', 'impossible', 'is', 'just', 'mission', 'new',
#        'say', 'that', 'the', 'to'],
#       dtype='<U62'), array(['code', 'da', 'sucked', 'vinci'],
#       dtype='<U62'), array(['impossible', 'mission', 'rocks'],
#       dtype='<U62'), array(['but', 'cruise', 'films', 'hate', 'impossible', 'its', 'like',
#        'mission', 'movies', 'the', 'tom', 'weird'],
#       dtype='<U62'), array(['beautiful', 'brokeback', 'mountain', 'was'],
#       dtype='<U62'), array(['awesome', 'brokeback', 'mountain'],
#       dtype='<U62'), array(['anyway', 'brokeback', 'love', 'mountain', 'thats', 'why'],
#       dtype='<U62'), array(['impossible', 'like', 'mission', 'one', 'th'],
#       dtype='<U62'), array(['awesome', 'brokeback', 'mountain', 'so', 'was'],
#       dtype='<U62'), array(['and', 'brokeback', 'mountain', 'movie', 'oh', 'terrible', 'was'],
#       dtype='<U62'), array(['brokeback', 'dudeee', 'loved', 'mountain'],
#       dtype='<U62'), array(['and', 'code', 'combining', 'da', 'from', 'gary', 'gin', 'opinion',
#        'review', 'sucks', 'the', 'vinci', 'zen'],
#       dtype='<U62'), array(['25', 'code', 'da', 'heard', 'much', 'only', 'soo', 'stars',
#        'sucked', 'vinci'],
#       dtype='<U62'), array(['brokeback', 'fucking', 'horrible', 'is', 'mountain'],
#       dtype='<U62'), array(['acne', 'and', 'brokeback', 'got', 'hes', 'likeyeah', 'love',
#        'mountain'],
#       dtype='<U62')]

# %% [markdown]
# # Deep Neural Network
#
#
# Consists of :
# <ul>
# <li>Input layer </li>
# <li>Hidden layer with 300 neurons</li>
# <li>Output softmax layer, which outputs the likelyhood of a class: [1,0]</li>
# </ul>

# %% [markdown]
# <img src="./data/nn-architecture.png"/>

# %%
tf.reset_default_graph()
input_data = tflearn.input_data(shape=[None, num_features])
init_weights = tflearn.initializations.truncated_normal(shape=None,dtype=tf.float32, seed=None)
layer1 = tflearn.layers.fully_connected(input_data,300,activation='sigmoid',weights_init=init_weights,regularizer='L2')
dp = tflearn.dropout(layer1,0.5)
net  =tflearn.layers.fully_connected(dp , 2,activation='softmax',regularizer='L2')
net = tflearn.regression(net, optimizer='adam', loss='categorical_crossentropy')
model = tflearn.DNN(net,tensorboard_verbose=3)

# %%
model.fit(trX,trY,n_epoch=10,show_metric=True)
evl = model.evaluate(testX,testY)
print("Evaluation: ",evl)
# Out:
# Training Step: 839  | total loss: 0.10739 | time: 5.976s
# | Adam | epoch: 010 | loss: 0.10739 - acc: 0.9725 -- iter: 5312/5315
# Training Step: 840  | total loss: 0.10491 | time: 6.046s
# | Adam | epoch: 010 | loss: 0.10491 - acc: 0.9722 -- iter: 5315/5315
# --
# Evaluation:  [0.98702031454706296]

# %%
from sklearn.metrics import roc_curve, auc
from sklearn import metrics
import matplotlib.pyplot as plt
def auc_curve():
    test_y=testY[:,0]
    pred = []
    i=0
    for t in testX:
        p = model.predict([t])
        p_toarray = np.asarray(p)[0]
        if p_toarray[0]>p_toarray[1]:
            pred.append(1.0)
        else:
            pred.append(0.0)
    print(metrics.classification_report(test_y.astype(float), np.asarray(pred)))
    print(metrics.confusion_matrix(test_y.astype(float), pred))
    fpr, tpr, thresholds = metrics.roc_curve(test_y, np.asarray(pred))
    roc_auc = auc(fpr, tpr)
    print('AUC = %0.4f'% roc_auc)
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b',
    label='AUC = %0.2f'% roc_auc)
    plt.legend(loc='lower right')
    plt.plot([0,1],[0,1],'r--')
    plt.xlim([-0.1,1.2])
    plt.ylim([-0.1,1.2])
    plt.ylabel('True Positive Sentiment Rate')
    plt.xlabel('False Positive Sentiment Rate')
    plt.show()
    

auc_curve()
# Out:
#              precision    recall  f1-score   support
#
#         0.0       0.99      0.99      0.99       791
#         1.0       0.99      0.99      0.99       981
#
# avg / total       0.99      0.99      0.99      1772
#
# [[780  11]
#  [  8 973]]
# AUC = 0.9890

# %% [markdown]
# # Inspecting training data

# %% [markdown]
# ### Positive sentiment

# %%
for t in training_data[training_data["positive"] ==1]["tweet"].head(10):
    print("Tweet:",t)
    enc = vect.transform([t]).toarray()
    p = model.predict(enc)
    print(np.asarray(p)[0])
    print("sentiment:",sentiment(np.asarray(p)[0]))
    print('--------')
# Out:
# Tweet: the da vinci code book is just awesome.
#
# [ 0.95302999  0.04696997]
# sentiment: positive
# --------
# Tweet: this was the first clive cussler i've ever read, but even books like relic, and da vinci code were more plausible than this.
#
# [ 0.87887669  0.12112329]
# sentiment: positive
# --------
# Tweet: i liked the da vinci code a lot.
#
# [ 0.72634131  0.27365869]
# sentiment: positive
# --------
# Tweet: i liked the da vinci code a lot.
#
# [ 0.72634131  0.27365869]
# sentiment: positive
# --------
# Tweet: i liked the da vinci code but it ultimatly didn't seem to hold it's own.
#
# [ 0.80330151  0.19669852]
# sentiment: positive
# --------
# Tweet: that's not even an exaggeration ) and at midnight we went to wal-mart to buy the da vinci code, which is amazing of course.
#
# [ 0.27423972  0.72576028]
# sentiment: negative
# --------
# Tweet: i loved the da vinci code, but now i want something better and different!..
#
# [ 0.91149944  0.08850054]
# sentiment: positive
# --------
# Tweet: i thought da vinci code was great, same with kite runner.
#
# [ 0.57611811  0.42388189]
# sentiment: positive
# --------
# Tweet: the da vinci code is actually a good movie...
#
# [ 0.4105213   0.58947867]
# sentiment: negative
# --------
# Tweet: i thought the da vinci code was a pretty good book.
#
# [ 0.72837681  0.27162322]
# sentiment: positive
# --------

# %% [markdown]
# ### Negative sentiment

# %%
for t in training_data[training_data["positive"] ==0]["tweet"].head(10):
    print("Tweet:",t)
    enc = vect.transform([t]).toarray()
    p = model.predict(enc)
    print(np.asarray(p)[0])
    print("sentiment:",sentiment(np.asarray(p)[0]))
    print('--------')
# Out:
# Tweet: i feeel like aaa reetard
#
# [ 0.57383108  0.42616895]
# sentiment: positive
# --------
# Tweet: da vinci code was a terrible movie.
#
# [ 0.46458665  0.53541332]
# sentiment: negative
# --------
# Tweet: then again, the da vinci code is super shitty movie, and it made like 700 million.
#
# [ 0.49910405  0.50089592]
# sentiment: negative
# --------
# Tweet: the da vinci code comes out tomorrow, which sucks.
#
# [ 0.41503838  0.58496159]
# sentiment: negative
# --------
# Tweet: i thought the da vinci code movie was really boring.
#
# [ 0.47030842  0.52969158]
# sentiment: negative
# --------
# Tweet: god, yahoo games has this truly-awful looking da vinci code-themed skin on it's chessboard right now.
#
# [ 0.49093878  0.50906122]
# sentiment: negative
# --------
# Tweet: da vinci code does suck.
#
# [ 0.46278223  0.53721774]
# sentiment: negative
# --------
# Tweet: and better...-we all know da vinci code is bogus and inaccurate.
#
# [ 0.43719253  0.56280756]
# sentiment: negative
# --------
# Tweet: last time, da vinci code is also a bit disappointing to me, because many things written in the book is never mentioned in movie.
#
# [ 0.468481  0.531519]
# sentiment: negative
# --------
# Tweet: and better...-we all know da vinci code is bogus and inaccurate.
#
# [ 0.43719253  0.56280756]
# sentiment: negative
# --------

# %% [markdown]
# ### Custom data

# %%
testing_tweets = ["this was ok","I like this product but I am not satisfied","I FEEEL LIKE AAA REETARD"
]
for t in testing_tweets:
    print("Tweet:",t)
    enc = vect.transform([t]).toarray()
    p = model.predict(enc)
    print(np.asarray(p)[0])
    print("sentiment:",sentiment(np.asarray(p)[0]))
    print('--------')
# Out:
# Tweet: this was ok
# [ 0.51919967  0.48080033]
# sentiment: positive
# --------
# Tweet: I like this product but I am not satisfied
# [ 0.5688349   0.43116507]
# sentiment: positive
# --------
# Tweet: I FEEEL LIKE AAA REETARD
# [ 0.57383108  0.42616895]
# sentiment: positive
# --------

# %%
print(vect.transform(["satisfied"]))
