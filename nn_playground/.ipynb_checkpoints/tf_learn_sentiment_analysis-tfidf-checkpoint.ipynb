# %% [markdown]
# # Sentiment Analysis using twitter data
#
# Simple Deep Neural Network, that predicts tweet sentiment. The model can be greatly improved using various <br/>
# word vectorization techniques and Recurrent Neural Networks.

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
from sklearn.model_selection import train_test_split
import tflearn as tflearn
from nltk.corpus import stopwords
import preprocessor as p
import re
import numpy as np
from sklearn import preprocessing
import tensorflow as tf

# %%
test_path = "./data/twitter_test.txt"
training_path = "./data/twitter_data.txt"

def all_stop_words():
    stop_words = stopwords.words('english')
    add_stopwords = [",", "*" , ")" , "(" ,".","theres","know","one","though","vinci","ive","da","book","im","went",
                    "potter","brokeback","mountain","harry","code","mission","impossible","movie","movies","i","ya",
                    "yet","yall"]
    for w in add_stopwords:
        stop_words.append(w)
    return stop_words


stop_words = all_stop_words()
def training_data_df(path):
    
    training_data = open(path,mode='r')
    training_array =[]
    for d in training_data:
        training_dict = {}
        sent_tweet_array = d.split('\t')
        training_dict['tweet'] = sent_tweet_array[1].lower()
        training_dict['cleaned_tweet'] =remove_stop_words(sent_tweet_array[1].lower())
        training_dict['positive'] =int(sent_tweet_array[0])
        training_array.append(training_dict)
    training_df = pd.DataFrame(training_array)
    return training_df

def sentiment(sentiment_prob):
    if sentiment_prob[0]>sentiment_prob[1]:
        return "positive"
    return "negative"

def remove_stop_words(tweet_text):
    tweet_text = re.sub(r'[?|$|.|!]',r'',tweet_text)
    tweet_text = re.sub(r'[^a-zA-Z0-9 ]',r'',tweet_text)
    result = ""
    for word in tweet_text.split():            
        if word not in stop_words:
            result = result +" "+word.lower()

    return result.lstrip()

def get_word_frequency(tweet_list):
    word_dict = {} 
    result_array=[]
    for tw in tweet_list:
        for word in tw.split():
            if word in word_dict.keys():
                word_dict[word] = word_dict[word]+1
                continue
            word_dict[word] = 1
    for k in word_dict.keys():
        result_array.append({'word':k, 'count':word_dict[k]})
    return pd.DataFrame(result_array,columns=['count','word'])


def common_pos_words(df_data):
    return common_words_filter(df_data,1)

def common_neg_words(df_data):
    return common_words_filter(df_data,0)

def common_words_filter(df_data,sent):
    pos_tweet =df_data[df_data["positive"] ==sent]
    all_tweets = pos_tweet["tweet"].str.cat(sep='|')
    common_words=[]
    for pos_tw in pos_tweet["tweet"]:
        for tw in all_tweets.split('|'):
            if pos_tw == tw:
                continue
            tw_list = list(tw.split())
            pos_list = list(pos_tw.split())
            inter = list(set(tw_list).intersection(pos_list))
            for word in inter:
                if word not in common_words:
                    common_words.append(word)
    return common_words

# %%
training_data = training_data_df(training_path)
# test_data = training_data_df(test_path)
training_data["neg"] = training_data["positive"].apply(lambda x: 0 if x==1 else 1)
vect = CountVectorizer(stop_words=all_stop_words())
print("All data:",training_data.shape[0])
# print("Test data:",test_data.shape[0])
# Out:
# All data: 7086

# %%
training_data.head(10)
# Out:
#                                        cleaned_tweet  positive  \
# 0                                            awesome         1
# 1  first clive cussler ever read even books like ...         1
# 2                                          liked lot         1
# 3                                          liked lot         1
# 4                    liked ultimatly didnt seem hold         1
# 5  thats even exaggeration midnight walmart buy a...         1
# 6              loved want something better different         1
# 7                          thought great kite runner         1
# 8                                      actually good         1
# 9                                thought pretty good         1
#
#                                                tweet  neg
# 0          the da vinci code book is just awesome.\n    0
# 1  this was the first clive cussler i've ever rea...    0
# 2                 i liked the da vinci code a lot.\n    0
# 3                 i liked the da vinci code a lot.\n    0
# 4  i liked the da vinci code but it ultimatly did...    0
# 5  that's not even an exaggeration ) and at midni...    0
# 6  i loved the da vinci code, but now i want some...    0
# 7  i thought da vinci code was great, same with k...    0
# 8    the da vinci code is actually a good movie...\n    0
# 9  i thought the da vinci code was a pretty good ...    0

# %%
training_data = training_data[['positive','neg','cleaned_tweet', 'tweet']]
training_data.values
# Out:
# array([[1, 0, 'awesome', 'the da vinci code book is just awesome.\n'],
#        [1, 0,
#         'first clive cussler ever read even books like relic plausible',
#         "this was the first clive cussler i've ever read, but even books like relic, and da vinci code were more plausible than this.\n"],
#        [1, 0, 'liked lot', 'i liked the da vinci code a lot.\n'],
#        ...,
#        [0, 1, 'sit watching mtv awards reminded much despised',
#         'as i sit here, watching the mtv movie awards, i am reminded of how much i despised the movie brokeback mountain.\n'],
#        [0, 1, 'ok horrible',
#         'ok brokeback mountain is such a horrible movie.\n'],
#        [0, 1, 'oh terrible',
#         'oh, and brokeback mountain was a terrible movie.\n']], dtype=object)

# %% [markdown]
# ### One-hot Encode

# %%
vect.fit(training_data["cleaned_tweet"])
word_matrix = vect.transform(training_data["cleaned_tweet"]).toarray()
print(word_matrix.shape)
# Out:
# (7086, 2069)

# %%
num_features = word_matrix.shape[1]
print("Total features: ",num_features)
classes = training_data.values[:,:2]
# Out:
# Total features:  2069

# %%
trX,testX,trY,testY = train_test_split(word_matrix,classes)   
print("Training data:",trX.shape[0])
print("Test data:",testX.shape[0])
# Out:
# Training data: 5314
# Test data: 1772

# %%
print(vect.inverse_transform(testX))
# Out:
# [array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['consumed', 'meat', 'new', 'placebroke', 'quick', 'smoked',
#        'suckedlove', 'updatehavent', 'weekda', 'weekhavent'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['bonkers', 'love', 'sentry', 'station'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['ended', 'fer', 'going', 'good', 'really', 'runaway', 'sucked',
#        'timings', 'vacation', 'wanted', 'watch'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['ban', 'board', 'books', 'education', 'evil', 'georgia', 'heard',
#        'mother', 'seeking'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['damn', 'love'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['hate', 'used'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['cock', 'cut', 'dictate', 'mirror', 'mouth', 'opened', 'reply',
#        'speaking', 'suck'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['said', 'suck'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['although', 'lot', 'loved', 'well'],
#       dtype='<U62'), array(['gorgeous'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['gotta', 'icons', 'love'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['adorable', 'everything', 'love', 'scar'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['also', 'conversations', 'enjoys', 'especially', 'indepth',
#        'interested', 'intrigued', 'like', 'much', 'person', 'subjects'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['dads', 'stupid'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['al', 'boring', 'et', 'said'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['love', 'made', 'much', 'realize'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['black', 'gay', 'guy', 'hate', 'retarted', 'stupid'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['calls', 'chris', 'excellent', 'frenzied', 'garrett', 'laura',
#        'phone', 'see'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['awesome', 'freaking', 'instead', 'see'],
#       dtype='<U62'), array(['dont', 'see', 'sucked', 'wanna', 'way'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['get', 'like', 'much', 'rare'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['awesome', 'going', 'reading', 'series', 'start', 'story'],
#       dtype='<U62'), array(['love', 'much'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['debates', 'intellectual', 'love'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['egg', 'godawful', 'john', 'laid', 'major', 'woo'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['anyway', 'bout', 'ever', 'point', 'talkin', 'worthless'],
#       dtype='<U62'), array(['awesome', 'lah'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['beautiful', 'kept', 'last', 'read', 'saying', 'shes', 'student',
#        'year'],
#       dtype='<U62'), array(['hated'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['else', 'go', 'night', 'rented', 'see', 'showing', 'something',
#        'stupid', 'theater', 'time', 'try'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['didnt', 'hate', 'hated', 'much', 'passion', 'sam'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['desperately', 'film', 'lovethe', 'wanted'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['also', 'sucks'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['cruise', 'end', 'evil', 'facing', 'franchise', 'hope', 'may',
#        'richard', 'see', 'simmons'],
#       dtype='<U62'), array(['awesome', 'going', 'reading', 'series', 'start', 'story'],
#       dtype='<U62'), array(['black', 'gay', 'guy', 'hate', 'retarted', 'stupid'],
#       dtype='<U62'), array(['boycotting', 'fucking', 'iii', 'pretty', 'stupid', 'sure'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['ass', 'iii', 'lame', 'last', 'like', 'mi3', 'predictable', 'sucked'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['also', 'ask', 'books', 'dont', 'drawn', 'love', 'strangely',
#        'vampire'],
#       dtype='<U62'), array(['amazing', 'get', 'wrong'],
#       dtype='<U62'), array(['dads', 'stupid'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['16', 'aint', 'course', 'hillform', 'love', 'queer'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['chronological', 'cover', 'enough', 'even', 'explains', 'great',
#        'ground', 'oddly', 'short', 'story'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['love', 'omg', 'thank'],
#       dtype='<U62'), array(['actually', 'college', 'cucumber', 'either', 'immortal', 'iq',
#        'person', 'psychology', 'sad', 'student', 'sucked', 'talked',
#        'thesis', 'working', 'writer'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['hookup', 'miss'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['fuck', 'fucking', 'goth', 'hate', 'little', 'whiny'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['anyone', 'care', 'dont', 'says', 'shitty'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['betterwe', 'bogus', 'inaccurate'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['angels', 'awesome', 'demons', 'liked', 'pretty'],
#       dtype='<U62'), array(['add', 'anything', 'either', 'majorly', 'new', 'post', 'save',
#        'sucks', 'wont'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['black', 'gay', 'guy', 'hate', 'retarted', 'stupid'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['evilpinkmunky', 'gay', 'sucks'],
#       dtype='<U62'), array(['google', 'music', 'sucked', 'urls', 'use'],
#       dtype='<U62'), array(['also', 'see', 'sucked', 'totally'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['beautiful', 'thought', 'unbelievably'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['fucking', 'hate'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['terrible'],
#       dtype='<U62'), array(['desperately', 'film', 'lovethe', 'wanted'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['hate', 'really'],
#       dtype='<U62'), array(['depressing'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['hated'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['dont', 'go', 'iii', 'okay', 'please', 'see', 'sucked'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['bonkers', 'love', 'sentry', 'station'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['awesome', 'going', 'reading', 'series', 'start', 'story'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['desperately', 'film', 'lovethe', 'wanted'],
#       dtype='<U62'), array(['blasphying', 'boring', 'hated', 'jesus', 'made', 'name', 'passion',
#        'played', 'sad', 'wide', 'witha', 'world'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['beautiful', 'best', 'director', 'give', 'picture', 'receive',
#        'score', 'since', 'something'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['bonkers', 'love', 'sentry', 'station'],
#       dtype='<U62'), array(['dont', 'love', 'never', 'posts', 'probably', 'read', 'reading'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['evil', 'point'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['loved', 'oh'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['dads', 'stupid'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['critics', 'dislike', 'hate', 'homophobic'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['also', 'evil', 'hate', 'kids', 'people', 'read', 'shes', 'thinks',
#        'witchcraft'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['actually', 'awesome', 'cruise', 'didnt', 'like', 'moives',
#        'pretending', 'problem', 'see', 'stop', 'tom'],
#       dtype='<U62'), array(['awful', 'called', 'creatures', 'dementors', 'ignorant', 'true',
#        'villains'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awesome', 'codethat'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['happy', 'sucks'],
#       dtype='<U62'), array(['anything', 'christmas', 'enjoy', 'outside', 'reading', 'related',
#        'snowing', 'specifically', 'tree', 'watching', 'winter'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['black', 'gay', 'guy', 'hate', 'retarted', 'stupid'],
#       dtype='<U62'), array(['awesome', 'going', 'reading', 'series', 'start', 'story'],
#       dtype='<U62'), array(['books', 'cant', 'hairy', 'otters', 'read', 'real', 'sucks',
#        'wussies'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['black', 'gay', 'guy', 'hate', 'retarted', 'stupid'],
#       dtype='<U62'), array(['also', 'suck'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['depressing'],
#       dtype='<U62'), array(['bonkers', 'love', 'sentry', 'station'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['actually', 'even', 'hate', 'much', 'religious'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['grow', 'ill', 'liked', 'see', 'sorry'],
#       dtype='<U62'), array(['awesome', 'going', 'reading', 'series', 'start', 'story'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['hate', 'really'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['desperately', 'film', 'lovethe', 'wanted'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['freaking', 'love'],
#       dtype='<U62'), array(['dads', 'stupid'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['desperately', 'film', 'lovethe', 'wanted'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['anyway', 'books', 'caribbean', 'humor', 'love', 'pictures',
#        'pirates', 'quirky', 'sarcastic', 'sense', 'taking', 'writing'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['dads', 'stupid'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['awesome', 'awesomeness', 'begin', 'cannot', 'comprehend', 'even',
#        'explain', 'hardcore', 'power'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['hated'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['fandom', 'fic', 'lot', 'read', 'sure', 'terrible'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['desperately', 'film', 'lovethe', 'wanted'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['man', 'sucks'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['axes', 'buy', 'costume', 'crappy', 'decides', 'kenley', 'plastic',
#        'two'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['gonna', 'lie', 'sucked', 'well'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['hated'],
#       dtype='<U62'), array(['also', 'awesome', 'briefly', 'college', 'cowan', 'far',
#        'incredibly', 'independent', 'last', 'lazy', 'mrs', 'semester',
#        'spoke', 'study', 'take', 'would'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['crusade', 'despise', 'love', 'much', 'scientology', 'still', 'tom',
#        'want'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['also', 'awesome', 'books', 'brown', 'dan', 'got', 'really', 'two'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['enjoy', 'reading', 'series'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['00', 'also', 'bikes', 'hollywood', 'rented', 'rode', 'stupid'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['hate', 'love', 'neither', 'personally'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['dynamite', 'giants', 'good', 'least', 'loved', 'luck', 'napoleon',
#        'night', 'riding'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['absolutely', 'hated'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['expected', 'sucked'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['almost', 'friend', 'joke', 'liked', 'telling', 'thing', 'time'],
#       dtype='<U62'), array(['also', 'sexy'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['first', 'loved'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love', 'much', 'series', 'talk', 'try'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['bit', 'decided', 'iii', 'little', 'see', 'sucked'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['aside', 'crappy', 'gadgets', 'hoffman', 'nifty', 'phillip',
#        'pretty', 'seymore'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['altogether', 'cuz', 'even', 'freshman', 'getting', 'itz', 'lol',
#        'much', 'simply', 'suck', 'thinking'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['desperately', 'film', 'lovethe', 'wanted'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['beautiful', 'ever', 'tragically'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['anatomy', 'greys', 'love'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['headmistresss', 'highly', 'inappropriate', 'melandry', 'nc17',
#        'office', 'use'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['anything', 'didnt', 'miss', 'special', 'sucked'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['hated'],
#       dtype='<U62'), array(['liked'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['dads', 'stupid'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['hate', 'love', 'read', 'sorry'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['crappy', 'directed', 'extremely', 'incredible', 'say', 'visually',
#        'well'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['die', 'sucks',
#        'waaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa',
#        'well'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['dont', 'get', 'love', 'oscar', 'people', 'racism', 'talk', 'think',
#        'white', 'wins', 'wrong'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['hated'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['awesomegood', 'luck', 'sooo', 'tennis', 'tournament', 'ur'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['black', 'gay', 'guy', 'hate', 'retarted', 'stupid'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['film', 'love', 'really', 'wonderful'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['1brokeback', 'stupid'],
#       dtype='<U62'), array(['dads', 'stupid'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['becuase', 'stupid'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['stupid'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['amazing', 'bitch', 'cry', 'like', 'made'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['coherent', 'dogfucking', 'except', 'hate', 'less', 'much',
#        'phrase', 'retarded', 'uh', 'usage'],
#       dtype='<U62'), array(['awesome', 'going', 'reading', 'series', 'start', 'story'],
#       dtype='<U62'), array(['around', 'considered', 'dart', 'hooker', 'love', 'song', 'would'],
#       dtype='<U62'), array(['evil'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['man', 'miss', 'stuff'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['excellent', 'love', 'watching'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['ballz', 'codesucked'],
# ...
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['best', 'hate', 'thing', 'tried', 'watched'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['bonkers', 'love', 'sentry', 'station'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['awesome', 'say', 'thing'],
#       dtype='<U62'), array(['kinda', 'like'],
#       dtype='<U62'), array(['awesome', 'iii'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['editor', 'horrible', 'kid', 'letter', 'school', 'wrote'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['liked', 'lot'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['dance', 'hate', 'remix', 'song', 'theme'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['also', 'anime', 'food', 'friends', 'like', 'manga', 'music',
#        'reading', 'xd'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['dads', 'stupid'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['ass', 'damn', 'dumb', 'jessica', 'kick', 'pretty', 'yes'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['awesome', 'going', 'reading', 'series', 'start', 'story'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['ideas', 'interesting', 'story', 'sucked'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['good', 'like', 'sort', 'spy', 'thing', 'unpredictable'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['awesome', 'going', 'reading', 'series', 'start', 'story'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['arse', 'sucks'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['miss'],
#       dtype='<U62'), array(['heard', 'kinda', 'sucks'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['got', 'right', 'sold', 'stupid'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['film', 'fun', 'honest', 'making', 'mostly', 'terrible'],
#       dtype='<U62'), array(['going', 'stupid', 'thought'],
#       dtype='<U62'), array(['beatles', 'cool', 'deemed', 'degraw', 'drawing', 'gavin', 'like'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['anything', 'else', 'loathe', 'lord', 'nature', 'rings'],
#       dtype='<U62'), array(['awesome', 'fucking', 'pretty', 'say', 'three'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['dads', 'stupid'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['capote', 'love', 'much', 'shame', 'transamerica'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['dont', 'fact', 'like', 'online', 'quizzes', 'sucks'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['also', 'awesome'],
#       dtype='<U62'), array(['catch', 'didnt', 'dvds', 'end', 'france', 'instead', 'match',
#        'portugal', 'stupid', 'watched'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['desperately', 'film', 'lovethe', 'wanted'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['didnt', 'get', 'jenn', 'later', 'maybe', 'money', 'overslept',
#        'see', 'sucked', 'yeah'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['agree', 'corrupting', 'dont', 'every', 'homophobes', 'horrible',
#        'right', 'say', 'things', 'world'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['friends', 'iii', 'majorly', 'nice', 'sucked', 'things'],
#       dtype='<U62'), array(['absolutely', 'already', 'love', 'tell'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['better', 'definitely', 'first', 'loved', 'second', 'still'],
#       dtype='<U62'), array(['also', 'big', 'love', 'otp', 'shipping', 'side'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['also', 'loved', 'read', 'right'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['already', 'cos', 'couple', 'effort', 'never', 'sucks', 'think',
#        'times', 'took', 'watching'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['boring', 'died', 'hide', 'jack', 'life', 'live', 'nt', 'real',
#        'sad', 'tried', 'want'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['big', 'books', 'dork', 'good', 'love'],
#       dtype='<U62'), array(['apparently', 'cast', 'like', 'people', 'spells', 'want'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['loved', 'really'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['black', 'gay', 'guy', 'hate', 'retarted', 'stupid'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['like', 'really'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['beautiful', 'way'],
#       dtype='<U62'), array(['consider', 'dont', 'recently', 'shittiest', 'watched', 'whether'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['awesome', 'chris', 'friday', 'watched'],
#       dtype='<U62')]

# %%
print(vect.inverse_transform(trX))
# Out:
# [array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['absolutely', 'already', 'love', 'tell'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['stupid'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['backjill', 'iii', 'next', 'stayed', 'staying', 'sucks', 'way',
#        'weekendmission', 'whole'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['awesome', 'interesting', 'liked', 'pretty', 'yeah'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['awesome', 'going', 'reading', 'series', 'start', 'story'],
#       dtype='<U62'), array(['absurd', 'lot', 'loved', 'questions', 'raises', 'theological'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['10', 'hate', 'knights', 'tale', 'things'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['culture', 'like', 'picky', 'pop', 'stuff'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['dads', 'stupid'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['awesome', 'hey'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['awesome', 'bday', 'little', 'party', 'saw', 'vics'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['also', 'come', 'enjoy', 'new', 'really', 'rereading', 'right',
#        'series'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['excited', 'feel', 'house', 'love', 'proud', 'really', 'want'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['loved'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['dads', 'stupid'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['date', 'jamaica', 'like', 'love', 'queens', 'someone', 'wanna'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['absolutely', 'loathe'],
#       dtype='<U62'), array(['archive', 'challenge', 'copy', 'fandom', 'hate', 'mpreg',
#        'pastings', 'section'],
#       dtype='<U62'), array(['adversity', 'concocted', 'cowboys', 'film', 'gay', 'hollywood',
#        'offensive', 'overcoming', 'stupidest', 'two'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['better', 'camp', 'cool', 'experience', 'hide', 'land', 'places',
#        'pretty', 'setting', 'ten', 'times', 'want'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['awful', 'blog', 'give', 'go', 'kudos', 'talk', 'would'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['heard', 'sucked'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['still', 'sucks'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['enjoyed', 'good', 'sawyer', 'suppose', 'tom'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['black', 'gay', 'guy', 'hate', 'retarted', 'stupid'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['bonkers', 'love', 'sentry', 'station'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['black', 'gay', 'guy', 'hate', 'retarted', 'stupid'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['awesome', 'saw'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['absolutely', 'already', 'love', 'tell'],
#       dtype='<U62'), array(['desperately', 'film', 'lovethe', 'wanted'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['cruise', 'franchise', 'people', 'think', 'tired', 'tom'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['amazing'],
#       dtype='<U62'), array(['hate', 'related', 'things'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['kids', 'must', 'shiti', 'sick', 'sure'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['dads', 'stupid'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['claiming', 'drain', 'evil', 'going', 'people', 'reading', 'sick',
#        'someone', 'soooooo', 'world'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['balls', 'sucked'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['crap', 'piece', 'since'],
#       dtype='<U62'), array(['college', 'job', 'love', 'often', 'sort', 'try'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['could', 'everything', 'hate', 'hes', 'say', 'suppose'],
#       dtype='<U62'), array(['horrible', 'kinda', 'lol', 'mountainwhich', 'see'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['joiners', 'mybutthole', 'nasy', 'stupid', 'yuh'],
#       dtype='<U62'), array(['awesome', 'get', 'go', 'really'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['awesome', 'going', 'reading', 'series', 'start', 'story'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['enjoy', 'light', 'radio', 'turn'],
#       dtype='<U62'), array(['bonkers', 'love', 'sentry', 'station'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['energy', 'field', 'like', 'sucks', 'theatan'],
#       dtype='<U62'), array(['black', 'gay', 'guy', 'hate', 'retarted', 'stupid'],
#       dtype='<U62'), array(['love', 'mentioned', 'much'],
#       dtype='<U62'), array(['cock', 'exquisite', 'felt', 'nearly', 'none', 'still', 'sucking'],
#       dtype='<U62'), array(['black', 'gay', 'guy', 'hate', 'retarted', 'stupid'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['accompaniment', 'action', 'bangs', 'colourfully', 'fireworks',
#        'first', 'good', 'lit', 'played', 'sky', 'theme', 'whistles'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['awesome', 'going', 'reading', 'series', 'start', 'story'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['balls', 'sucked'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['erm', 'sucked'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['beautiful', 'days', 'haunted', 'seeing'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['even', 'loved', 'second', 'series'],
#       dtype='<U62'), array(['could', 'hatedthe', 'libarian', 'nans', 'rachel', 'said', 'told'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['bonkers', 'love', 'sentry', 'station'],
#       dtype='<U62'), array(['loved'],
#       dtype='<U62'), array(['awesomeyes', 'finally', 'going', 'saw', 'snuck', 'springers'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['desperately', 'film', 'lovethe', 'wanted'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['desperately', 'film', 'lovethe', 'wanted'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['clickfive', 'hate', 'love', 'much'],
#       dtype='<U62'), array(['love', 'really', 'sad'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['compared', 'good', 'invisible', 'man', 'sucks'],
#       dtype='<U62'), array(['ass', 'sucks'],
#       dtype='<U62'), array(['bonkers', 'love', 'sentry', 'station'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['death', 'lol', 'love', 'yeah'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['record', 'terrible'],
#       dtype='<U62'), array(['beautiful', 'sounds'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['black', 'gay', 'guy', 'hate', 'retarted', 'stupid'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['black', 'gay', 'guy', 'hate', 'retarted', 'stupid'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62'), array(['changed', 'hate', 'malaguena', 'much', 'russotti', 'screwed'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['ass', 'suck'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['evil', 'people', 'read', 'say'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['dumbest', 'ever', 'heard', 'new', 'probably', 'thing', 'track'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awesome', 'totally'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['absurd', 'classes', 'controversy', 'gaither', 'marcia', 'says',
#        'teaches', 'wiccanism'],
#       dtype='<U62'), array(['heard', 'sucks'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['awful', 'huge', 'loser', 'man', 'yes'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['finally', 'freakin', 'hahaha', 'search', 'shoes', 'stupid', 'think'],
#       dtype='<U62'), array(['awesome', 'going', 'reading', 'series', 'start', 'story'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['desperately', 'film', 'lovethe', 'wanted'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['class', 'hate', 'starting'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['awesome', 'iii'],
#       dtype='<U62'), array(['crashand', 'everyone', 'fabulous', 'havent', 'love', 'seen',
#        'tells'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['awesome', 'going', 'reading', 'series', 'start', 'story'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['better', 'different', 'genres', 'like', 'personally', 'two', 'yeah'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['awesome', 'friends', 'hey', 'iii', 'last', 'many', 'screening',
#        'special', 'week', 'well', 'wondering'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['doors', 'events', 'half', 'hour', 'infiltrate', 'love',
#        'officially', 'open', 'team', 'threegeneration', 'way'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['awesome', 'barnyard', 'lilo', 'love', 'stitch'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awesome', 'myselfike', 'pretty', 'say', 'stinkin'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awful', 'dinner', 'min', 'rosie'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['apparently', 'ass', 'even', 'film', 'sucks'],
#       dtype='<U62'), array(['ang', 'gyllenhaal', 'heath', 'jake', 'leder', 'lee', 'love', 'much'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['angels', 'days', 'demons', 'finished', 'got', 'hooked', 'like',
#        'read', 'two'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['awesome', 'hey'],
#       dtype='<U62'), array(['fact', 'far', 'go', 'hate', 'say', 'would'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['awesome', 'back', 'came', 'mom', 'watched'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['angels', 'awesome', 'demons', 'far', 'first', 'onto', 'read'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['alright', 'awesome'],
#       dtype='<U62'), array(['awesome', 'going', 'reading', 'series', 'start', 'story'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['desperately', 'film', 'lovethe', 'wanted'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['dads', 'stupid'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['going', 'suck'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['big', 'childrens', 'enjoyed', 'fan', 'glad', 'literature', 'yes'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['stupid'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['desperately', 'film', 'lovethe', 'wanted'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['dads', 'stupid'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['cruise', 'cuz', 'go', 'hate', 'may', 'new', 'see', 'think', 'tom'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['loved', 'recently'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['really', 'sucked'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['hate', 'think'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['horrible'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['depressing', 'extremely', 'hear', 'read', 'reviews'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['awesome', 'iii', 'period', 'really'],
#       dtype='<U62'), array(['flick', 'good'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['convo', 'dad', 'fallon', 'left', 'love', 'us'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['love', 'man'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['stinks'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['dads', 'stupid'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['evil', 'think'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['black', 'gay', 'guy', 'hate', 'retarted', 'stupid'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['even', 'hate'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['black', 'gay', 'guy', 'hate', 'retarted', 'stupid'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['actors', 'boring', 'cute', 'least', 'show', 'super', 'well'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['loved'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['cant', 'loved', 'wait'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['chessboard', 'codethemed', 'games', 'god', 'looking', 'right',
#        'skin', 'trulyawful', 'yahoo'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['awesome', 'going', 'reading', 'series', 'start', 'story'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['awesome', 'supper', 'watched'],
#       dtype='<U62'), array(['also', 'haircut', 'hate', 'lord', 'love', 'needs', 'rings'],
#       dtype='<U62'), array(['awesome', 'could', 'entitled', 'paper', 'wish', 'write'],
#       dtype='<U62'), array(['dads', 'stupid'],
#       dtype='<U62'), array(['awesome', 'going', 'reading', 'series', 'start', 'story'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['bonkers', 'love', 'sentry', 'station'],
#       dtype='<U62'), array(['anything', 'basically', 'crash', 'diversity', 'going', 'like',
#        'rent', 'something', 'unexpected', 'want'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['black', 'gay', 'guy', 'hate', 'retarted', 'stupid'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['angels', 'demons', 'like'],
#       dtype='<U62'), array(['afraid', 'amazes', 'children', 'going', 'people'],
#       dtype='<U62'), array(['fault', 'since'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['future', 'lets', 'like', 'machine', 'see'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['1984', 'hate', 'read'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['bonkers', 'love', 'sentry', 'station'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['conclusion', 'draw', 'hate', 'isnt', 'may', 'reading', 'review',
#        'true'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['codes', 'suck', 'supposed'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['astonishingly', 'fat', 'free', 'good', 'much', 'rent', 'worth'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['angel', 'awesome', 'better', 'books', 'browns', 'dan', 'demons',
#        'even', 'read', 'wanna'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['dads', 'stupid'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['depressing'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['christmas', 'cruise', 'missions', 'people', 'stupid', 'tom', 'trip'],
#       dtype='<U62'), array(['bonkers', 'love', 'sentry', 'station'],
# ...
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['anyways', 'awesome', 'lot', 'saw', 'three', 'tonight', 'us', 'well'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['beautiful', 'film'],
#       dtype='<U62'), array(['also', 'sexy'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['first', 'hated', 'long', 'lucky', 'placetheres', 'public',
#        'reaction', 'read', 'refusing', 'since'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['feeling', 'immensely', 'moralistic', 'never', 'tragic',
#        'wellexecuted'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['awesome', 'finished'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['desperately', 'film', 'lovethe', 'wanted'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['bentlys', 'butt', 'cool', 'except', 'incredibly', 'kinda', 'ok',
#        'part', 'paul', 'see', 'sucked'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['cruise', 'fact', 'freak', 'get', 'joke', 'loved', 'made', 'never',
#        'old', 'quip', 'tc', 'tom'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['gorgeous'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['along', 'conquering', 'evil', 'formed', 'friendships', 'good',
#        'story', 'way'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['betterwe', 'bogus', 'inaccurate'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['love', 'much', 'series', 'talk', 'try'],
#       dtype='<U62'), array(['arguments', 'bolsters', 'england', 'sucks', 'think'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['bonkers', 'love', 'sentry', 'station'],
#       dtype='<U62'), array(['beautiful', 'changes', 'film', 'nothing', 'still'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['believably', 'club', 'day', 'obnoxious', 'tonight', 'unbelievably'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['better', 'sucks', 'used'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['also', 'bible', 'evil', 'isnt', 'like', 'would'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['correct', 'lousy', 'prediction'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['hate', 'id', 'kattun', 'starred', 'watch'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['hating', 'saying', 'sucky'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['didnt', 'hold', 'liked', 'seem', 'ultimatly'],
#       dtype='<U62'), array(['boys', 'gay', 'love', 'sucked', 'think'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['deserved', 'dont', 'feel', 'honor', 'like', 'loved', 'really',
#        'see'],
#       dtype='<U62'), array(['attractive', 'beautiful', 'impressive', 'picturesque', 'place',
#        'quaintly'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['chinese', 'horrible', 'illegally', 'pirated', 'presented',
#        'subtitles', 'watched'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['awesome', 'read', 'way'],
#       dtype='<U62'), array(['6th', 'awesome', 'cant', 'comes', 'final', 'halfblood', 'prince',
#        'read', 'rereading', 'thinking', 'wait'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['awesome', 'wicked'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['fault', 'since'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['lol', 'love', 'thing'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['lol', 'sucked'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['devastate', 'included', 'love', 'would'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['awesome', 'going', 'reading', 'series', 'start', 'story'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['awesome', 'got', 'tickets', 'turned'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['began', 'ending', 'even', 'futile'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['sucks', 'thinking'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['events', 'love', 'series', 'tons', 'twilight', 'unfortunate'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['black', 'gay', 'guy', 'hate', 'retarted', 'stupid'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['even', 'see', 'sucked', 'worse'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['awesome', 'iii', 'saw'],
#       dtype='<U62'), array(['desperately', 'film', 'lovethe', 'wanted'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['awesome', 'idiots', 'make', 'many', 'people', 'protests',
#        'religion', 'sad', 'share'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['dads', 'stupid'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['childrens', 'first', 'like', 'never', 'portuguese', 'read',
#        'since', 'spanish', 'told'],
#       dtype='<U62'), array(['awesome', 'mocking'],
#       dtype='<U62'), array(['awesome', 'definately', 'seeing', 'worth'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['black', 'gay', 'guy', 'hate', 'retarted', 'stupid'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['bonkers', 'love', 'sentry', 'station'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62'), array(['hate', 'shit'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62')]

# %% [markdown]
# # Deep Neural Network
#
#
# Consists of :
# <ul>
# <li>Input layer </li>
# <li>Hidden layer with 300 neurons</li>
# <li>Output softmax layer, which outputs the likelyhood of a class: [1,0]</li>
# </ul>

# %% [markdown]
# <img src="./data/nn-architecture.png"/>

# %%
tf.reset_default_graph()
input_data = tflearn.input_data(shape=[None, num_features])
init_weights = tflearn.initializations.truncated_normal(shape=None,dtype=tf.float32, seed=None)
layer1 = tflearn.layers.fully_connected(input_data,300,activation='sigmoid',weights_init=init_weights,regularizer='L2')
net  =tflearn.layers.fully_connected(layer1 , 2,activation='softmax',regularizer='L2')
net = tflearn.regression(net, optimizer='adam', loss='categorical_crossentropy')
model = tflearn.DNN(net,tensorboard_verbose=3)

# %%
model.fit(trX,trY,n_epoch=10,show_metric=True)
evl = model.evaluate(testX,testY)
print("Evaluation: ",evl)
# Out:
# Training Step: 839  | total loss: 0.05911 | time: 5.412s
# | Adam | epoch: 010 | loss: 0.05911 - acc: 0.9960 -- iter: 5312/5314
# Training Step: 840  | total loss: 0.05743 | time: 5.479s
# | Adam | epoch: 010 | loss: 0.05743 - acc: 0.9964 -- iter: 5314/5314
# --
# Evaluation:  [0.99379232505643345]

# %%
from sklearn.metrics import roc_curve, auc
def auc_curve():
    test_y=testY[:,0]
    pred = []
    i=0
    for t in testX:
        p = model.predict([t])
        p_toarray = np.asarray(p)[0]
        if p_toarray[0]>p_toarray[1]:
            pred.append(1.0)
        else:
            pred.append(0.0)
    print(metrics.classification_report(test_y.astype(float), np.asarray(pred)))
    print(metrics.confusion_matrix(test_y.astype(float), pred))
    fpr, tpr, thresholds = metrics.roc_curve(test_y, np.asarray(pred))
    roc_auc = auc(fpr, tpr)
    print('AUC = %0.4f'% roc_auc)
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b',
    label='AUC = %0.2f'% roc_auc)
    plt.legend(loc='lower right')
    plt.plot([0,1],[0,1],'r--')
    plt.xlim([-0.1,1.2])
    plt.ylim([-0.1,1.2])
    plt.ylabel('True Positive Sentiment Rate')
    plt.xlabel('False Positive Sentiment Rate')
    plt.show()
    

auc_curve()
# Out:
#              precision    recall  f1-score   support
#
#         0.0       0.99      0.99      0.99       761
#         1.0       1.00      0.99      0.99      1011
#
# avg / total       0.99      0.99      0.99      1772
#
# [[ 756    5]
#  [   7 1004]]
# AUC = 0.9933

# %% [markdown]
# # Inspecting training data

# %% [markdown]
# ### Positive sentiment

# %%
for t in training_data[training_data["positive"] ==1]["tweet"].head(10):
    print("Tweet:",t)
    enc = vect.transform([t]).toarray()
    p = model.predict(enc)
    print(np.asarray(p)[0])
    print("sentiment:",sentiment(np.asarray(p)[0]))
    print('--------')
# Out:
# Tweet: the da vinci code book is just awesome.
#
# [ 0.97038788  0.02961217]
# sentiment: positive
# --------
# Tweet: this was the first clive cussler i've ever read, but even books like relic, and da vinci code were more plausible than this.
#
# [ 0.93533415  0.06466589]
# sentiment: positive
# --------
# Tweet: i liked the da vinci code a lot.
#
# [ 0.80056423  0.19943585]
# sentiment: positive
# --------
# Tweet: i liked the da vinci code a lot.
#
# [ 0.80056423  0.19943585]
# sentiment: positive
# --------
# Tweet: i liked the da vinci code but it ultimatly didn't seem to hold it's own.
#
# [ 0.77269202  0.22730799]
# sentiment: positive
# --------
# Tweet: that's not even an exaggeration ) and at midnight we went to wal-mart to buy the da vinci code, which is amazing of course.
#
# [ 0.62022918  0.37977079]
# sentiment: positive
# --------
# Tweet: i loved the da vinci code, but now i want something better and different!..
#
# [ 0.91257775  0.08742226]
# sentiment: positive
# --------
# Tweet: i thought da vinci code was great, same with kite runner.
#
# [ 0.55284309  0.44715688]
# sentiment: positive
# --------
# Tweet: the da vinci code is actually a good movie...
#
# [ 0.56884879  0.43115124]
# sentiment: positive
# --------
# Tweet: i thought the da vinci code was a pretty good book.
#
# [ 0.66133392  0.33866608]
# sentiment: positive
# --------

# %% [markdown]
# ### Negative sentiment

# %%
for t in training_data[training_data["positive"] ==0]["tweet"].head(10):
    print("Tweet:",t)
    enc = vect.transform([t]).toarray()
    p = model.predict(enc)
    print(np.asarray(p)[0])
    print("sentiment:",sentiment(np.asarray(p)[0]))
    print('--------')
# Out:
# Tweet: da vinci code was a terrible movie.
#
# [ 0.13090219  0.86909783]
# sentiment: negative
# --------
# Tweet: then again, the da vinci code is super shitty movie, and it made like 700 million.
#
# [ 0.80618703  0.19381297]
# sentiment: positive
# --------
# Tweet: the da vinci code comes out tomorrow, which sucks.
#
# [ 0.03794273  0.96205723]
# sentiment: negative
# --------
# Tweet: i thought the da vinci code movie was really boring.
#
# [ 0.0553035   0.94469649]
# sentiment: negative
# --------
# Tweet: god, yahoo games has this truly-awful looking da vinci code-themed skin on it's chessboard right now.
#
# [ 0.33391207  0.66608799]
# sentiment: negative
# --------
# Tweet: da vinci code does suck.
#
# [ 0.07236701  0.92763293]
# sentiment: negative
# --------
# Tweet: and better...-we all know da vinci code is bogus and inaccurate.
#
# [ 0.37601653  0.6239835 ]
# sentiment: negative
# --------
# Tweet: last time, da vinci code is also a bit disappointing to me, because many things written in the book is never mentioned in movie.
#
# [ 0.46054962  0.53945035]
# sentiment: negative
# --------
# Tweet: and better...-we all know da vinci code is bogus and inaccurate.
#
# [ 0.37601653  0.6239835 ]
# sentiment: negative
# --------
# Tweet: and better..-we all know da vinci code is bogus and inaccurate.
#
# [ 0.37601653  0.6239835 ]
# sentiment: negative
# --------

# %% [markdown]
# ### Custom data

# %%
testing_tweets = ["this was ok","I like this product but I am not satisfied","I FEEEL LIKE AAA REETARD"
]
for t in testing_tweets:
    print("Tweet:",t)
    enc = vect.transform([t]).toarray()
    p = model.predict(enc)
    print(np.asarray(p)[0])
    print("sentiment:",sentiment(np.asarray(p)[0]))
    print('--------')
# Out:
# Tweet: this was ok
# [ 0.29858521  0.70141476]
# sentiment: negative
# --------
# Tweet: I like this product but I am not satisfied
# [ 0.88018698  0.11981297]
# sentiment: positive
# --------
# Tweet: I FEEEL LIKE AAA REETARD
# [ 0.88018698  0.11981297]
# sentiment: positive
# --------

# %%
print(vect.transform(["satisfied"]))
