# %% [markdown]
# # Sentiment Analysis using twitter data
#
# Simple Deep Neural Network, that predicts tweet sentiment. The model can be greatly improved using various <br/>
# word vectorization techniques and Recurrent Neural Networks.

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
from sklearn.model_selection import train_test_split
import tflearn as tflearn
from nltk.corpus import stopwords
import preprocessor as p
import re
import numpy as np
from sklearn import preprocessing
import tensorflow as tf

# %%
test_path = "./data/twitter_test.txt"
training_path = "./data/twitter_data.txt"

def all_stop_words():
    stop_words = stopwords.words('english')
    add_stopwords = [",", "*" , ")" , "(" ,".","theres","know","one","though","vinci","ive","da","book","im","went",
                    "potter","brokeback","mountain","harry","code","mission","impossible","movie","movies","i","ya",
                    "yet","yall"]
    for w in add_stopwords:
        stop_words.append(w)
    return stop_words


stop_words = all_stop_words()
def training_data_df(path):
    
    training_data = open(path,mode='r')
    training_array =[]
    for d in training_data:
        training_dict = {}
        sent_tweet_array = d.split('\t')
        training_dict['tweet'] = sent_tweet_array[1].lower()
        training_dict['cleaned_tweet'] =remove_stop_words(sent_tweet_array[1].lower())
        training_dict['positive'] =int(sent_tweet_array[0])
        training_array.append(training_dict)
    training_df = pd.DataFrame(training_array)
    return training_df

def sentiment(sentiment_prob):
    if sentiment_prob[0]>sentiment_prob[1]:
        return "positive"
    return "negative"

def remove_stop_words(tweet_text):
    tweet_text = re.sub(r'[?|$|.|!]',r'',tweet_text)
    tweet_text = re.sub(r'[^a-zA-Z0-9 ]',r'',tweet_text)
    result = ""
    for word in tweet_text.split():            
        if word not in stop_words:
            result = result +" "+word.lower()

    return result.lstrip()

def get_word_frequency(tweet_list):
    word_dict = {} 
    result_array=[]
    for tw in tweet_list:
        for word in tw.split():
            if word in word_dict.keys():
                word_dict[word] = word_dict[word]+1
                continue
            word_dict[word] = 1
    for k in word_dict.keys():
        result_array.append({'word':k, 'count':word_dict[k]})
    return pd.DataFrame(result_array,columns=['count','word'])


def common_pos_words(df_data):
    return common_words_filter(df_data,1)

def common_neg_words(df_data):
    return common_words_filter(df_data,0)

def common_words_filter(df_data,sent):
    pos_tweet =df_data[df_data["positive"] ==sent]
    all_tweets = pos_tweet["tweet"].str.cat(sep='|')
    common_words=[]
    for pos_tw in pos_tweet["tweet"]:
        for tw in all_tweets.split('|'):
            if pos_tw == tw:
                continue
            tw_list = list(tw.split())
            pos_list = list(pos_tw.split())
            inter = list(set(tw_list).intersection(pos_list))
            for word in inter:
                if word not in common_words:
                    common_words.append(word)
    return common_words

# %%
training_data = training_data_df(training_path)
# test_data = training_data_df(test_path)
training_data["neg"] = training_data["positive"].apply(lambda x: 0 if x==1 else 1)
vect = CountVectorizer(stop_words=all_stop_words())
print("All data:",training_data.shape[0])
# print("Test data:",test_data.shape[0])
# Out:
# All data: 7087

# %%
training_data
# Out:
#                                           cleaned_tweet  positive  \
# 0                                feeel like aaa reetard         0
# 1                                               awesome         1
# 2     first clive cussler ever read even books like ...         1
# 3                                             liked lot         1
# 4                                             liked lot         1
# 5                       liked ultimatly didnt seem hold         1
# 6     thats even exaggeration midnight walmart buy a...         1
# 7                 loved want something better different         1
# 8                             thought great kite runner         1
# 9                                         actually good         1
# 10                                  thought pretty good         1
# 11                                  beautiful ever seen         1
# 12                                    amazing get wrong         1
# 13                               turn light radio enjoy         1
# 14                                          really good         1
# 15                                                 love         1
# 16                                                loved         1
# 17                                 night beautiful mind         1
# 18                                              awesome         1
# 19                                        thing enjoyed         1
# 20                                   slash amazing race         1
# 21                                            hey loved         1
# 22                                           also loved         1
# 23    really enjoyed thought would disappointed book...         1
# 24                                   like angels demons         1
# 25                                          really good         1
# 26                yeah awesome liked pretty interesting         1
# 27                                          really like         1
# 28                                              amazing         1
# 29                                              awesome         1
# ...                                                 ...       ...
# 7057                                   fucking horrible         0
# 7058                         snuck depressing ever seen         0
# 7059  helped bobbypin insanely cool hat head laughed...         0
# 7060                                        dads stupid         0
# 7061                                        oh terrible         0
# 7062                                             boring         0
# 7063                                  really depressing         0
# 7064     sit watching mtv awards reminded much despised         0
# 7065                                        ok horrible         0
# 7066                                        oh terrible         0
# 7067                                   fucking horrible         0
# 7068                         snuck depressing ever seen         0
# 7069  helped bobbypin insanely cool hat head laughed...         0
# 7070                                        dads stupid         0
# 7071                                        oh terrible         0
# 7072                                             boring         0
# 7073                                  really depressing         0
# 7074     sit watching mtv awards reminded much despised         0
# 7075                                        ok horrible         0
# 7076                                        oh terrible         0
# 7077                                   fucking horrible         0
# 7078                         snuck depressing ever seen         0
# 7079  helped bobbypin insanely cool hat head laughed...         0
# 7080                                        dads stupid         0
# 7081                                        oh terrible         0
# 7082                                             boring         0
# 7083                                  really depressing         0
# 7084     sit watching mtv awards reminded much despised         0
# 7085                                        ok horrible         0
# 7086                                        oh terrible         0
#
#                                                   tweet  neg
# 0                            i feeel like aaa reetard\n    1
# 1             the da vinci code book is just awesome.\n    0
# 2     this was the first clive cussler i've ever rea...    0
# 3                    i liked the da vinci code a lot.\n    0
# 4                    i liked the da vinci code a lot.\n    0
# 5     i liked the da vinci code but it ultimatly did...    0
# 6     that's not even an exaggeration ) and at midni...    0
# 7     i loved the da vinci code, but now i want some...    0
# 8     i thought da vinci code was great, same with k...    0
# 9       the da vinci code is actually a good movie...\n    0
# 10    i thought the da vinci code was a pretty good ...    0
# 11    the da vinci code is one of the most beautiful...    0
# 12    the da vinci code is an * amazing * book, do n...    0
# 13    then i turn on the light and the radio and enj...    0
# 14                 the da vinci code was really good.\n    0
# 15                           i love da vinci code....\n    0
# 16                            i loved da vinci code..\n    0
# 17    to night:: the da vinci code and a beautiful m...    0
# 18           the da vinci code is an awesome book....\n    0
# 19             thing is, i enjoyed the da vinci code.\n    0
# 20             very da vinci code slash amazing race.\n    0
# 21                   hey i loved the da vinci code!..\n    0
# 22                     also loved the da vinci code..\n    0
# 23    i really enjoyed the da vinci code but thought...    0
# 24    i do like angels and demons more then the da v...    0
# 25         the da vinci code was a really good movie.\n    0
# 26    yeah, da vinci code is an awesome movie i like...    0
# 27                   i really like the da vinci code.\n    0
# 28                          da vinci code is amazing.\n    0
# 29                   the da vinci code was awesome...\n    0
# ...                                                 ...  ...
# 7057         brokeback mountain is fucking horrible..\n    1
# 7058  then snuck into brokeback mountain, which is t...    1
# 7059  , she helped me bobbypin my insanely cool hat ...    1
# 7060  my dad's being stupid about brokeback mountain...    1
# 7061  oh, and brokeback mountain is a terrible movie...    1
# 7062                   brokeback mountain was boring.\n    1
# 7063     so brokeback mountain was really depressing.\n    1
# 7064  as i sit here, watching the mtv movie awards, ...    1
# 7065  ok brokeback mountain is such a horrible movie.\n    1
# 7066  oh, and brokeback mountain was a terrible movi...    1
# 7067         brokeback mountain is fucking horrible..\n    1
# 7068  then snuck into brokeback mountain, which is t...    1
# 7069  , she helped me bobbypin my insanely cool hat ...    1
# 7070  my dad's being stupid about brokeback mountain...    1
# 7071  oh, and brokeback mountain is a terrible movie...    1
# 7072                   brokeback mountain was boring.\n    1
# 7073     so brokeback mountain was really depressing.\n    1
# 7074  as i sit here, watching the mtv movie awards, ...    1
# 7075  ok brokeback mountain is such a horrible movie.\n    1
# 7076  oh, and brokeback mountain was a terrible movi...    1
# 7077         brokeback mountain is fucking horrible..\n    1
# 7078  then snuck into brokeback mountain, which is t...    1
# 7079  , she helped me bobbypin my insanely cool hat ...    1
# 7080  my dad's being stupid about brokeback mountain...    1
# 7081  oh, and brokeback mountain is a terrible movie...    1
# 7082                   brokeback mountain was boring.\n    1
# 7083     so brokeback mountain was really depressing.\n    1
# 7084  as i sit here, watching the mtv movie awards, ...    1
# 7085  ok brokeback mountain is such a horrible movie.\n    1
# 7086  oh, and brokeback mountain was a terrible movi...    1
#
# [7087 rows x 4 columns]

# %%
training_data = training_data[['positive','neg','cleaned_tweet', 'tweet']]
training_data.values
# Out:
# array([[0, 1, 'feeel like aaa reetard', 'i feeel like aaa reetard\n'],
#        [1, 0, 'awesome', 'the da vinci code book is just awesome.\n'],
#        [1, 0,
#         'first clive cussler ever read even books like relic plausible',
#         "this was the first clive cussler i've ever read, but even books like relic, and da vinci code were more plausible than this.\n"],
#        ...,
#        [0, 1, 'sit watching mtv awards reminded much despised',
#         'as i sit here, watching the mtv movie awards, i am reminded of how much i despised the movie brokeback mountain.\n'],
#        [0, 1, 'ok horrible',
#         'ok brokeback mountain is such a horrible movie.\n'],
#        [0, 1, 'oh terrible',
#         'oh, and brokeback mountain was a terrible movie.\n']], dtype=object)

# %% [markdown]
# ### One-hot Encode

# %%
vect.fit(training_data["cleaned_tweet"])
word_matrix = vect.transform(training_data["cleaned_tweet"]).toarray()
print(word_matrix.shape)
# Out:
# (7087, 2072)

# %%
num_features = word_matrix.shape[1]
print("Total features: ",num_features)
classes = training_data.values[:,:2]
# Out:
# Total features:  2072

# %%
trX,testX,trY,testY = train_test_split(word_matrix,classes)   
print("Training data:",trX.shape[0])
print("Test data:",testX.shape[0])
# Out:
# Training data: 5315
# Test data: 1772

# %%
print(vect.inverse_transform(testX))
# Out:
# []

# %%
print(vect.inverse_transform(trX))
# Out:
# [array(['idk', 'looked', 'stupid'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['absurd', 'lot', 'loved', 'questions', 'raises', 'theological'],
#       dtype='<U62'), array(['lol', 'sucked'],
#       dtype='<U62'), array(['desperately', 'film', 'lovethe', 'wanted'],
#       dtype='<U62'), array(['anyone', 'care', 'dont', 'says', 'shitty'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['horrible', 'looks', 'three'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['betterwe', 'bogus', 'inaccurate'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['admired', 'awesome', 'bachelor', 'cant', 'doesnt', 'jesus', 'mean'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['miss'],
#       dtype='<U62'), array(['awesome', 'going', 'reading', 'series', 'start', 'story'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['god', 'hated', 'see', 'thought', 'wrong'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['dads', 'stupid'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['loved'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['also', 'hate'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['evil'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['great', 'loved', 'personally', 'thriller'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['asshole', 'awesome', 'cruise', 'cuz', 'great', 'hate', 'saw',
#        'still', 'tom'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['dads', 'stupid'],
#       dtype='<U62'), array(['gotta', 'lol', 'luv'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['chinese', 'horrible', 'illegally', 'pirated', 'presented',
#        'subtitles', 'watched'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['horrible'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['loved'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['beautiful', 'oh'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['lol', 'love'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['hated', 'man'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['bonkers', 'love', 'sentry', 'station'],
#       dtype='<U62'), array(['hated'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['hate', 'omg'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['awesome', 'going', 'reading', 'series', 'start', 'story'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['absolutely', 'already', 'love', 'tell'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['10', 'hate', 'knights', 'tale', 'things'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['loved', 'really'],
#       dtype='<U62'), array(['man', 'miss', 'stuff'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['guys', 'kinda', 'muahahaahahah', 'omen', 'sucked', 'watch'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['beautiful', 'ever', 'tragically'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['love', 'mentioned', 'much'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['characters', 'gay', 'hated', 'main'],
#       dtype='<U62'), array(['stupid'],
#       dtype='<U62'), array(['awesome', 'crap', 'generally'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['depressing'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['awesome', 'going', 'reading', 'series', 'start', 'story'],
#       dtype='<U62'), array(['007', 'hate', 'love', 'playing'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['dads', 'stupid'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['7th', 'deciding', 'go', 'want'],
#       dtype='<U62'), array(['already', 'hate', 'sure', 'threw'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['first', 'loved'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['angels', 'bit', 'demons', 'end', 'good', 'kind', 'lost', 'loved',
#        'pretty', 'right', 'thought'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['awesome', 'well'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['bonkers', 'love', 'sentry', 'station'],
#       dtype='<U62'), array(['asleep', 'big', 'cold', 'fell', 'freezing', 'nearly', 'sucks',
#        'time', 'watching'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['betterwe', 'bogus', 'inaccurate'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['actually', 'hated', 'look', 'read'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awesome', 'going', 'reading', 'series', 'start', 'story'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['awesome', 'best', 'dorks', 'pretty'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['agree', 'corrupting', 'dont', 'every', 'homophobes', 'horrible',
#        'right', 'say', 'things', 'world'],
#       dtype='<U62'), array(['loved', 'seeing'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['hating', 'saying', 'sucky'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['bonkers', 'love', 'sentry', 'station'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['like', 'really'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['hated'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['awesome', 'going', 'reading', 'series', 'start', 'story'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['love', 'reading'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['also', 'haircut', 'hate', 'lord', 'love', 'needs', 'rings'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['awful', 'huge', 'loser', 'man', 'yes'],
#       dtype='<U62'), array(['awesome', 'going', 'reading', 'series', 'start', 'story'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['awesome', 'crap', 'fr', 'half', 'probable', 'sounds'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['bonkers', 'love', 'sentry', 'station'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['always', 'decided', 'ennis', 'happened', 'jack', 'life', 'loved',
#        'rest', 'spend', 'wondered', 'would'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['flat', 'iii', 'shipmates', 'sucked'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['fuck', 'fucking', 'goth', 'hate', 'little', 'whiny'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['black', 'gay', 'guy', 'hate', 'retarted', 'stupid'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['bonkers', 'love', 'sentry', 'station'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['enjoy', 'quizzes', 'taking'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['big', 'books', 'decent', 'enough', 'glad', 'got', 'kids',
#        'reading', 'thick'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['far', 'good', 'least', 'real', 'well'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['backjill', 'iii', 'next', 'stayed', 'staying', 'sucks', 'way',
#        'weekendmission', 'whole'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['creature', 'death', 'demeantor', 'fade', 'like', 'mouth', 'soul',
#        'suck'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['doesnt', 'end', 'hope', 'like'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['depressing', 'hell'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['6th', 'awesome', 'cant', 'comes', 'final', 'halfblood', 'prince',
#        'read', 'rereading', 'thinking', 'wait'],
#       dtype='<U62'), array(['agree', 'allegedly', 'blashpemies', 'bunch', 'contains', 'else',
#        'get', 'hell', 'heresies', 'loved', 'panties', 'people',
#        'ridiculous', 'think', 'whatever'],
#       dtype='<U62'), array(['broom', 'rides', 'sucks'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['kinda', 'sad', 'sucked'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['hate', 'id', 'kattun', 'starred', 'watch'],
#       dtype='<U62'), array(['black', 'gay', 'guy', 'hate', 'retarted', 'stupid'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['hahash', 'love', 'tooo'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['absolutely', 'already', 'love', 'tell'],
#       dtype='<U62'), array(['dads', 'stupid'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['found', 'german', 'great', 'read'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['desperately', 'film', 'lovethe', 'wanted'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['anyway', 'loved'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['actually', 'condemnation', 'entire', 'generalized', 'hollywood',
#        'industry', 'mob', 'part', 'people', 'rant', 'stupid', 'targeted',
#        'voted'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['desperately', 'film', 'lovethe', 'wanted'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['desperately', 'film', 'lovethe', 'wanted'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['ass', 'backward', 'dont', 'hear', 'mormon', 'news', 'terrible',
#        'want'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['gays', 'lol', 'love', 'loved'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['already', 'awesome'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['enjoy', 'reading', 'series'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['lousy', 'really'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['desperately', 'film', 'lovethe', 'wanted'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['loved', 'outta', 'three'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['damn', 'love'],
#       dtype='<U62'), array(['chance', 'fabulous', 'poem', 'prize', 'us', 'win', 'write'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['absolutely', 'hated'],
#       dtype='<U62'), array(['also', 'glad', 'hate', 'kind', 'lost'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['definately', 'didnt', 'suck', 'sucked', 'talking'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['could', 'hatedthe', 'libarian', 'nans', 'rachel', 'said', 'told'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['also', 'page', 'sucks', 'turner'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['case', 'loved'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['offence', 'suck'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['awesome', 'crazy', 'gay', 'husband', 'ian', 'mckellen', 'old',
#        'see'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['come', 'conclusion', 'hero', 'tragic'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['absolutely', 'already', 'love', 'tell'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['awesome', 'saw'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['black', 'gay', 'guy', 'hate', 'retarted', 'stupid'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['awesomest', 'books', 'ever', 'read', 'still'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['depressing', 'first', 'glad', 'see', 'time'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['amazing'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['awesome', 'got', 'tickets', 'turned'],
#       dtype='<U62'), array(['hate', 'hilarious', 'passion'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['dads', 'stupid'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['man', 'marvel', 'sucks', 'ultimate'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['dads', 'stupid'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['desperately', 'film', 'lovethe', 'wanted'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['boring', 'really', 'thought'],
#       dtype='<U62'), array(['betterwe', 'bogus', 'inaccurate'],
#       dtype='<U62'), array(['depressing', 'extremely'],
#       dtype='<U62'), array(['like', 'never', 'right', 'side', 'whos'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['character', 'favourite', 'liked', 'lines', 'ron'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['hate', 'love', 'read', 'sorry'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['desperately', 'film', 'lovethe', 'wanted'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['black', 'gay', 'guy', 'hate', 'retarted', 'stupid'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['consumed', 'meat', 'new', 'placebroke', 'quick', 'smoked',
#        'suckedlove', 'updatehavent', 'weekda', 'weekhavent'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['awesome', 'going', 'reading', 'series', 'start', 'story'],
#       dtype='<U62'), array(['anyone', 'awesome', 'care', 'differently', 'dont', 'says'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['also', 'come', 'enjoy', 'new', 'really', 'rereading', 'right',
#        'series'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['desperately', 'film', 'lovethe', 'wanted'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['attraction', 'due', 'favorite', 'friday', 'release', 'reopened',
#        'saturday', 'stupid', 'unable'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['action', 'agreed', 'decent', 'fit', 'generally', 'mi', 'name',
#        'terrible'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['depressing', 'even', 'ever'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['bobbypin', 'cool', 'cowboy', 'hat', 'head', 'helped', 'insanely',
#        'jokes', 'laughed', 'stupid'],
# ...
#        'monthly', 'tonight', 'tv', 'watch'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['aching', 'around', 'blonds', 'cock', 'draco', 'dragged',
#        'groaning', 'hips', 'making', 'malfoy', 'noises', 'panting', 'past',
#        'rockhard', 'sucked', 'throat', 'trousers', 'vigor', 'whimpering'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['although', 'lot', 'loved', 'well'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['doesnt', 'gift', 'hate', 'someone'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['cruise', 'franchise', 'people', 'think', 'tired', 'tom'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['2007', 'arent', 'awesome', 'costumes', 'finished', 'planning',
#        'two', 'unfortunately'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['also', 'loved', 'read', 'right'],
#       dtype='<U62'), array(['begin', 'better', 'hate', 'material', 'much', 'outshines', 'plain',
#        'reading', 'stupid', 'think'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['christianity', 'fabricated', 'jesus', 'la', 'worthless'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['daniel', 'fucking', 'hate', 'needs', 'slap', 'wotshisface'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['escapades', 'kate', 'kirsten', 'leah', 'love', 'tom', 'well'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['horrible'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['acceptable', 'becoming', 'either', 'great', 'homosexuality',
#        'love', 'think'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['awesome', 'besides', 'drowining', 'way'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['awards', 'despised', 'mtv', 'much', 'reminded', 'sit', 'watching'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['almost', 'beautiful', 'cried', 'derek', 'saw'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['1brokeback', 'stupid'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['ban', 'board', 'books', 'education', 'evil', 'georgia', 'heard',
#        'mother', 'seeking'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['700', 'like', 'made', 'million', 'shitty', 'super'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['guy', 'love', 'really', 'wacked'],
#       dtype='<U62'), array(['bonkers', 'love', 'sentry', 'station'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['actually', 'awesome', 'cruise', 'didnt', 'like', 'moives',
#        'pretending', 'problem', 'see', 'stop', 'tom'],
#       dtype='<U62'), array(['altogether', 'cuz', 'even', 'freshman', 'getting', 'itz', 'lol',
#        'much', 'simply', 'suck', 'thinking'],
#       dtype='<U62'), array(['bad', 'feel', 'films', 'go', 'hate', 'like', 'money', 'pocket',
#        'putting', 'really', 'see', 'since', 'theater'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['like'],
#       dtype='<U62'), array(['also', 'catcher', 'count', 'eyre', 'jane', 'love', 'series',
#        'suicides', 'tye', 'virgin', 'yeah'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['cocktail', 'gun', 'hated', 'ran', 'top'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['black', 'gay', 'guy', 'hate', 'retarted', 'stupid'],
#       dtype='<U62'), array(['astonishingly', 'fat', 'free', 'good', 'much', 'rent', 'worth'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['beautiful', 'kept', 'last', 'read', 'saying', 'shes', 'student',
#        'year'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['bonkers', 'love', 'sentry', 'station'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['club', 'latin', 'school', 'see', 'sucked'],
#       dtype='<U62'), array(['rocks'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['balls', 'see', 'sucked', 'totally'],
#       dtype='<U62'), array(['azkaban', 'dementors', 'joy', 'life', 'live', 'prisoner', 'see',
#        'suck', 'taking'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['alright', 'awesome'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love', 'lubb', 'luv'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['combining', 'gary', 'gin', 'opinion', 'review', 'sucks', 'zen'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['bonkers', 'love', 'sentry', 'station'],
#       dtype='<U62'), array(['love', 'much', 'people', 'worth'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['big', 'sucked', 'time'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['deep', 'love', 'profound', 'story'],
#       dtype='<U62'), array(['bonkers', 'love', 'sentry', 'station'],
#       dtype='<U62'), array(['black', 'gay', 'guy', 'hate', 'retarted', 'stupid'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62'), array(['awesome', 'last', 'stand'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['absolutely', 'awesome'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['boring'],
#       dtype='<U62'), array(['fucking', 'horrible'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['fandom', 'gift', 'het', 'id', 'love', 'nc17', 'requested',
#        'sivullinen'],
#       dtype='<U62'), array(['character', 'dies', 'hate', 'likes', 'main', 'person', 'type'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['going', 'ill', 'lol', 'suck', 'suncoast', 'weekend', 'working'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['cocktail', 'gun', 'hated', 'ran', 'top'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['anyways', 'awesome', 'lot', 'saw', 'three', 'tonight', 'us', 'well'],
#       dtype='<U62'), array(['christmas', 'like', 'scarf', 'type', 'would'],
#       dtype='<U62'), array(['hate'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['fun', 'love', 'much', 'people', 'place', 'really', 'serious',
#        'still', 'take', 'want'],
#       dtype='<U62'), array(['asian', 'got', 'himi', 'horses', 'hugged', 'loved', 'told',
#        'tourist', 'wranglers', 'yesterday'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['acne', 'got', 'hes', 'likeyeah', 'love'],
#       dtype='<U62'), array(['dudeee', 'loved'],
#       dtype='<U62'), array(['microsoft', 'news', 'sucks', 'suing', 'symantec'],
#       dtype='<U62'), array(['horrible'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['black', 'gay', 'guy', 'hate', 'retarted', 'stupid'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['carefully', 'crafted', 'hate', 'involve', 'jokes', 'loves',
#        'opinion', 'perhaps', 'popculture', 'revise', 'unless'],
#       dtype='<U62'), array(['awesome', 'cant', 'read', 'wait'],
#       dtype='<U62'), array(['depressing', 'really'],
#       dtype='<U62'), array(['really', 'suck'],
#       dtype='<U62'), array(['bitch', 'coz', 'goin', 'hella', 'hill', 'like', 'reality', 'said',
#        'silent', 'turned'],
#       dtype='<U62'), array(['bye', 'ok', 'quiz', 'sucks'],
#       dtype='<U62'), array(['oh', 'terrible'],
#       dtype='<U62'), array(['loved', 'man'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['gonna', 'hoot', 'like', 'watch'],
#       dtype='<U62'), array(['first', 'liked'],
#       dtype='<U62'), array(['friday', 'hung', 'kelsie', 'saw', 'sucked'],
#       dtype='<U62'), array(['anyway', 'love', 'thats'],
#       dtype='<U62'), array(['sucks'],
#       dtype='<U62'), array(['left', 'right', 'suck'],
#       dtype='<U62'), array(['always', 'crazy', 'guy', 'hates', 'knows', 'want'],
#       dtype='<U62'), array(['25', 'heard', 'much', 'soo', 'stars', 'sucked'],
#       dtype='<U62'), array(['desperately', 'film', 'lovethe', 'wanted'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['sucked'],
#       dtype='<U62'), array(['also', 'excellent'],
#       dtype='<U62'), array(['depressing', 'ever', 'seen', 'snuck'],
#       dtype='<U62'), array(['liked', 'really'],
#       dtype='<U62'), array(['good', 'soo'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['desperately', 'film', 'lovethe', 'wanted'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['dads', 'stupid'],
#       dtype='<U62'), array(['letting', 'sucked', 'way'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['action', 'awesome', 'little', 'looking', 'story', 'suspenseful',
#        'thats', 'way', 'youre'],
#       dtype='<U62'), array(['cleaning', 'dash', 'felicia', 'felicias', 'freakin', 'grabs',
#        'keys', 'like', 'mom', 'table'],
#       dtype='<U62'), array(['excellent'],
#       dtype='<U62'), array(['balls', 'sucked'],
#       dtype='<U62'), array(['suck'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['community', 'friends', 'good', 'joining', 'like', 'make', 'really',
#        'start', 'things', 'thought', 'would'],
#       dtype='<U62'), array(['beautiful'],
#       dtype='<U62'), array(['acting', 'case', 'color', 'eyes', 'hair', 'hopefully',
#        'overlooking', 'potters', 'trivia', 'us', 'wrong'],
#       dtype='<U62'), array(['energy', 'field', 'like', 'sucks', 'theatan'],
#       dtype='<U62'), array(['evil', 'people', 'read', 'say'],
#       dtype='<U62'), array(['awesome'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['absolutely', 'also', 'basic', 'cheap', 'dont', 'hated', 'horridly',
#        'like', 'normal', 'religious', 'standpoint', 'think', 'time',
#        'worth', 'writing'],
#       dtype='<U62'), array(['horrible', 'ok'],
#       dtype='<U62'), array(['love'],
#       dtype='<U62'), array(['love', 'shit'],
#       dtype='<U62')]

# %% [markdown]
# # Deep Neural Network
#
#
# Consists of :
# <ul>
# <li>Input layer </li>
# <li>Hidden layer with 300 neurons</li>
# <li>Output softmax layer, which outputs the likelyhood of a class: [1,0]</li>
# </ul>

# %% [markdown]
# <img src="./data/nn-architecture.png"/>

# %%
tf.reset_default_graph()
input_data = tflearn.input_data(shape=[None, num_features])
init_weights = tflearn.initializations.truncated_normal(shape=None,dtype=tf.float32, seed=None)
layer1 = tflearn.layers.fully_connected(input_data,300,activation='sigmoid',weights_init=init_weights,regularizer='L2')
net  =tflearn.layers.fully_connected(layer1 , 2,activation='softmax',regularizer='L2')
net = tflearn.regression(net, optimizer='adam', loss='categorical_crossentropy')
model = tflearn.DNN(net,tensorboard_verbose=3)

# %%
model.fit(trX,trY,n_epoch=5,show_metric=True)
evl = model.evaluate(testX,testY,)
print("Evaluation: ",evl)
# Out:
# ---------------------------------
# Run id: 3CTQNY
# Log directory: /tmp/tflearn_logs/simple_sentiment/
# INFO:tensorflow:Summary name Accuracy/ (raw) is illegal; using Accuracy/__raw_ instead.
# ---------------------------------
# Training samples: 5315
# Validation samples: 0
# --
# ---------------------------------------------------------------------------
# FailedPreconditionError                   Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      65             try:
# ---> 66                 next(self.gen)
#      67             except StopIteration:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tensorflow/python/framework/errors_impl.py in raise_exception_on_not_ok_status()
#     468           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 469           pywrap_tensorflow.TF_GetCode(status))
#     470   finally:
#
# FailedPreconditionError: Attempting to use uninitialized value FullyConnected/W
# 	 [[Node: FullyConnected/W/read = Identity[T=DT_FLOAT, _class=["loc:@FullyConnected/W"], _device="/job:localhost/replica:0/task:0/cpu:0"](FullyConnected/W)]]
#
# During handling of the above exception, another exception occurred:
#
# FailedPreconditionError                   Traceback (most recent call last)
# <ipython-input-24-44b3c4d752ee> in <module>()
# ----> 1 model.fit(trX,trY,n_epoch=5,show_metric=True)
#       2 evl = model.evaluate(testX,testY,)
#       3 print("Evaluation: ",evl)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tflearn/models/dnn.py in fit(self, X_inputs, Y_targets, n_epoch, validation_set, show_metric, batch_size, shuffle, snapshot_epoch, snapshot_step, excl_trainops, validation_batch_size, run_id, callbacks)
#     213                          excl_trainops=excl_trainops,
#     214                          run_id=run_id,
# --> 215                          callbacks=callbacks)
#     216
#     217     def predict(self, X):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tflearn/helpers/trainer.py in fit(self, feed_dicts, n_epoch, val_feed_dicts, show_metric, snapshot_step, snapshot_epoch, shuffle_all, dprep_dict, daug_dict, excl_trainops, run_id, callbacks)
#     331                                                        (bool(self.best_checkpoint_path) | snapshot_epoch),
#     332                                                        snapshot_step,
# --> 333                                                        show_metric)
#     334
#     335                             # Update training state
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tflearn/helpers/trainer.py in _train(self, training_step, snapshot_epoch, snapshot_step, show_metric)
#     772         tflearn.is_training(True, session=self.session)
#     773         _, train_summ_str = self.session.run([self.train, self.summ_op],
# --> 774                                              feed_batch)
#     775
#     776         # Retrieve loss value from summary string
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1033         except KeyError:
#    1034           pass
# -> 1035       raise type(e)(node_def, op, message)
#    1036
#    1037   def _extend_graph(self):
#
# FailedPreconditionError: Attempting to use uninitialized value FullyConnected/W
# 	 [[Node: FullyConnected/W/read = Identity[T=DT_FLOAT, _class=["loc:@FullyConnected/W"], _device="/job:localhost/replica:0/task:0/cpu:0"](FullyConnected/W)]]
#
# Caused by op 'FullyConnected/W/read', defined at:
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/runpy.py", line 170, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tornado/ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-23-4a0d9d710aa2>", line 7, in <module>
#     layer1 = tflearn.layers.fully_connected(input_data,300,activation='sigmoid',regularizer='L2')
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tflearn/layers/core.py", line 157, in fully_connected
#     restore=restore)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tensorflow/contrib/framework/python/ops/arg_scope.py", line 177, in func_with_args
#     return func(*args, **current_args)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tflearn/variables.py", line 65, in variable
#     validate_shape=validate_shape)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tensorflow/python/ops/variable_scope.py", line 988, in get_variable
#     custom_getter=custom_getter)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tensorflow/python/ops/variable_scope.py", line 890, in get_variable
#     custom_getter=custom_getter)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tensorflow/python/ops/variable_scope.py", line 348, in get_variable
#     validate_shape=validate_shape)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tensorflow/python/ops/variable_scope.py", line 333, in _true_getter
#     caching_device=caching_device, validate_shape=validate_shape)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tensorflow/python/ops/variable_scope.py", line 684, in _get_single_variable
#     validate_shape=validate_shape)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tensorflow/python/ops/variables.py", line 226, in __init__
#     expected_shape=expected_shape)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tensorflow/python/ops/variables.py", line 344, in _init_from_args
#     self._snapshot = array_ops.identity(self._variable, name="read")
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tensorflow/python/ops/gen_array_ops.py", line 1490, in identity
#     result = _op_def_lib.apply_op("Identity", input=input, name=name)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py", line 763, in apply_op
#     op_def=op_def)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 2395, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 1264, in __init__
#     self._traceback = _extract_stack()
#
# FailedPreconditionError (see above for traceback): Attempting to use uninitialized value FullyConnected/W
# 	 [[Node: FullyConnected/W/read = Identity[T=DT_FLOAT, _class=["loc:@FullyConnected/W"], _device="/job:localhost/replica:0/task:0/cpu:0"](FullyConnected/W)]]

# %%
from sklearn.metrics import roc_curve, auc
from sklearn import metrics
import matplotlib.pyplot as plt

def auc_curve():
    test_y=testY[:,0]
    pred = []
    i=0
    for t in testX:
        p = model.predict([t])
        p_toarray = np.asarray(p)[0]
        if p_toarray[0]>p_toarray[1]:
            pred.append(1.0)
        else:
            pred.append(0.0)
    print(metrics.classification_report(test_y.astype(float), np.asarray(pred)))
    print(metrics.confusion_matrix(test_y.astype(float), pred))
    fpr, tpr, thresholds = metrics.roc_curve(test_y, np.asarray(pred))
    roc_auc = auc(fpr, tpr)
    print('AUC = %0.4f'% roc_auc)
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b',
    label='AUC = %0.2f'% roc_auc)
    plt.legend(loc='lower right')
    plt.plot([0,1],[0,1],'r--')
    plt.xlim([-0.1,1.2])
    plt.ylim([-0.1,1.2])
    plt.ylabel('True Positive Sentiment Rate')
    plt.xlabel('False Positive Sentiment Rate')
    plt.show()
    

auc_curve()
# Out:
#              precision    recall  f1-score   support
#
#         0.0       0.99      1.00      0.99       759
#         1.0       1.00      1.00      1.00      1013
#
# avg / total       1.00      1.00      1.00      1772
#
# [[ 756    3]
#  [   5 1008]]
# AUC = 0.9956

# %% [markdown]
# # Inspecting training data

# %% [markdown]
# ### Positive sentiment

# %%
for t in training_data[training_data["positive"] ==1]["tweet"].head(10):
    print("Tweet:",t)
    enc = vect.transform([t]).toarray()
    p = model.predict(enc)
    print(np.asarray(p)[0])
    print("sentiment:",sentiment(np.asarray(p)[0]))
    print('--------')
# Out:
# Tweet: the da vinci code book is just awesome.
#
# [ 0.97416931  0.02583072]
# sentiment: positive
# --------
# Tweet: this was the first clive cussler i've ever read, but even books like relic, and da vinci code were more plausible than this.
#
# [ 0.93325323  0.06674684]
# sentiment: positive
# --------
# Tweet: i liked the da vinci code a lot.
#
# [ 0.83236736  0.16763271]
# sentiment: positive
# --------
# Tweet: i liked the da vinci code a lot.
#
# [ 0.83236736  0.16763271]
# sentiment: positive
# --------
# Tweet: i liked the da vinci code but it ultimatly didn't seem to hold it's own.
#
# [ 0.82067764  0.17932242]
# sentiment: positive
# --------
# Tweet: that's not even an exaggeration ) and at midnight we went to wal-mart to buy the da vinci code, which is amazing of course.
#
# [ 0.74903917  0.2509608 ]
# sentiment: positive
# --------
# Tweet: i loved the da vinci code, but now i want something better and different!..
#
# [ 0.92989308  0.07010695]
# sentiment: positive
# --------
# Tweet: i thought da vinci code was great, same with kite runner.
#
# [ 0.53135097  0.46864903]
# sentiment: positive
# --------
# Tweet: the da vinci code is actually a good movie...
#
# [ 0.64150345  0.35849664]
# sentiment: positive
# --------
# Tweet: i thought the da vinci code was a pretty good book.
#
# [ 0.68123788  0.31876206]
# sentiment: positive
# --------

# %% [markdown]
# ### Negative sentiment

# %%
for t in training_data[training_data["positive"] ==0]["tweet"].head(10):
    print("Tweet:",t)
    enc = vect.transform([t]).toarray()
    p = model.predict(enc)
    print(np.asarray(p)[0])
    print("sentiment:",sentiment(np.asarray(p)[0]))
    print('--------')
# Out:
# Tweet: i feeel like aaa reetard
#
# [ 0.86505324  0.13494678]
# sentiment: positive
# --------
# Tweet: da vinci code was a terrible movie.
#
# [ 0.15172426  0.84827572]
# sentiment: negative
# --------
# Tweet: then again, the da vinci code is super shitty movie, and it made like 700 million.
#
# [ 0.7555542   0.24444579]
# sentiment: positive
# --------
# Tweet: the da vinci code comes out tomorrow, which sucks.
#
# [ 0.05419291  0.9458071 ]
# sentiment: negative
# --------
# Tweet: i thought the da vinci code movie was really boring.
#
# [ 0.07497249  0.92502749]
# sentiment: negative
# --------
# Tweet: god, yahoo games has this truly-awful looking da vinci code-themed skin on it's chessboard right now.
#
# [ 0.25618708  0.74381298]
# sentiment: negative
# --------
# Tweet: da vinci code does suck.
#
# [ 0.09418462  0.90581542]
# sentiment: negative
# --------
# Tweet: and better...-we all know da vinci code is bogus and inaccurate.
#
# [ 0.38325629  0.61674374]
# sentiment: negative
# --------
# Tweet: last time, da vinci code is also a bit disappointing to me, because many things written in the book is never mentioned in movie.
#
# [ 0.27146858  0.72853142]
# sentiment: negative
# --------
# Tweet: and better...-we all know da vinci code is bogus and inaccurate.
#
# [ 0.38325629  0.61674374]
# sentiment: negative
# --------

# %% [markdown]
# ### Custom data

# %%
# testing_file = open(test_path,mode='r')
# testing_tweets=[]
# for x in testing_file:
#     s= remove_stop_words(x)
#     testing_tweets.append(s)
# testing_tweets=["It’s likely something has gone wrong with the product or experience you’re reviewing that isn’t \
# representative of what the company offers 99.9 per cent of the time", 
#                 "If you think they have a point, you’re probably best taking it down immediately",
#                "I was surprised that the material was a rough burlap instead of the linen listed in the ad. I do \
#                 still like \
#                 the way it looks as it's decorative so feel isn't that important to me anyways."]

testing_tweets=["Besides the tasty food, the service is incredible!",
                "Horrible service. Absolutely no sense of customer service and how to take an order. \
                Your order will never reach you.","Good food but very slow service, no matter what time of day you come. Even if you order over phone still prepare to wait at least 30 mnts or more."]

for t in testing_tweets:
    print("Tweet:",t)
    enc = vect.transform([t]).toarray()
    p = model.predict(enc)
    print(np.asarray(p)[0])
    print("sentiment:",sentiment(np.asarray(p)[0]))
    print('--------')
# Out:
# Tweet: Besides the tasty food, the service is incredible!
# [ 0.44431728  0.55568278]
# sentiment: negative
# --------
# Tweet: Horrible service. Absolutely no sense of customer service and how to take an order.                 Your order will never reach you.
# [ 0.10882268  0.89117736]
# sentiment: negative
# --------
# Tweet: Good food but very slow service, no matter what time of day you come. Even if you order over phone still prepare to wait at least 30 mnts or more.
# [ 0.78753704  0.21246295]
# sentiment: positive
# --------

# %%
print(vect.transform(["satisfied"]))
